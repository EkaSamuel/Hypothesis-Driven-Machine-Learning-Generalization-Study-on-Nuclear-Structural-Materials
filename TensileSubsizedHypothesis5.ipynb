# %% [markdown]
# # TABLE OF CONTENT

# %% [markdown]
# ### Initial Installation

# %%
# 1. Ensure ipywidgets is installed
# !conda install -c conda-forge ipywidgets -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# doneieving notices: -
# done
# doneing environment: |
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 25.5.1
#   latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=26.1.1
#
#
#
# # All requested packages already installed.

# %%
# 2. Ensure nodejs is installed (needed for JupyterLab extensions)
# !conda install -c conda-forge nodejs -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# doneing environment: -
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 25.5.1
#   latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=26.1.1
#
#
#
# # All requested packages already installed.

# %%
# !jupyter nbextension enable --py widgetsnbextension
# !jupyter nbextension install --py widgetsnbextension
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.
# ...

# %%
# !pip install ipywidgets
# !pip install widgetsnbextension

# %%
pip install ipywidgets jupyterlab_widgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# testing the widget slider

import ipywidgets as widgets
widgets.IntSlider(value=5, min=0, max=10, step=1, description='Slider:')
# Out:
# IntSlider(value=5, description='Slider:', max=10)

# %%
# testing the widget dropdown

import ipywidgets as widgets
from IPython.display import display, clear_output

dropdown = widgets.Dropdown(
    options=['Option 1', 'Option 2', 'Option 3'],
    description='Pick one:',
)
display(dropdown)
# Out:
# Dropdown(description='Pick one:', options=('Option 1', 'Option 2', 'Option 3'), value='Option 1')

# %%
# installing all other required libraries

# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install missingno
# !pip install scikit-learn
# !pip install statsmodels
# !pip install category_encoders
# !pip install xgboost
# !pip install lightgbm
# !pip install catboost
# !pip install shap
# !pip install lime
# !pip install optuna
# !pip install joblib
# !pip install tensorflow
# !pip install sqlalchemy mysql-connector-python
# !pip install scikit-optimize

# %%
# import all necessary libraries

import pandas as pd 
import numpy as np

import matplotlib. pyplot as plt
import seaborn as sns # Statistical data visualization 
import missingno as msno # Visualize missing data

from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import ( 
    RandomForestRegressor, 
    GradientBoostingRegressor,
    AdaBoostRegressor, 
    BaggingRegressor,
)

from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Lasso 
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, make_scorer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, OrdinalEncoder, FunctionTransformer 
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.base import BaseEstimator, TransformerMixin

from scipy.stats import zscore

import statsmodels.api as sm # Statistical regression analysis

import xgboost as xgb # Gradient boosting 
import lightgbm as lgb 
import catboost as cb

import shap # Model explainability 
import lime.lime_tabular as lime

import optuna # Hyperparameter optimization

import joblib # Model saving/loading

from sqlalchemy import create_engine

import IPython.display as widgets
from IPython.display import display
import ipywidgets as widgets

# %% [markdown]
# ### Data Ingestion

# %%
#read file
df = pd.read_csv('TensileSubsized3.csv')

# display first few rows
print(df.head())
# Out:
#    Reference Material         Material Group  \
# 0          1   SS304L  NSM, Rector Internals
# 1          1   SS304L  NSM, Rector Internals
# 2          1   FeCrAl     NSM, Fuel Cladding
# 3          1   FeCrAl     NSM, Fuel Cladding
# 4          1   FeCrAl     NSM, Fuel Cladding
#
#                    Chemistry & Alloy Family Microstructure Class  \
# 0                          Stainless Steels    Austenitic / FCC
# 1                          Stainless Steels    Austenitic / FCC
# 2  Fe-Based Ferritic High Temperature Alloy             Ferritic
# 3  Fe-Based Ferritic High Temperature Alloy             Ferritic
# 4  Fe-Based Ferritic High Temperature Alloy             Ferritic
#
#                         Nuclear Application C (wt.%)  Si (wt.%)  Mn (wt.%)  \
# 0                 Core Structural Materials     0.02       0.45        1.3
# 1                 Core Structural Materials     0.02       0.45        1.3
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# Read file
df = pd.read_csv('TensileSubsized3.csv')

# Reset index to start from 1
df.index = range(1, len(df) + 1)

# Display first few rows
print(df.head())
# Out:
#    Reference Material         Material Group  \
# 1          1   SS304L  NSM, Rector Internals
# 2          1   SS304L  NSM, Rector Internals
# 3          1   FeCrAl     NSM, Fuel Cladding
# 4          1   FeCrAl     NSM, Fuel Cladding
# 5          1   FeCrAl     NSM, Fuel Cladding
#
#                    Chemistry & Alloy Family Microstructure Class  \
# 1                          Stainless Steels    Austenitic / FCC
# 2                          Stainless Steels    Austenitic / FCC
# 3  Fe-Based Ferritic High Temperature Alloy             Ferritic
# 4  Fe-Based Ferritic High Temperature Alloy             Ferritic
# 5  Fe-Based Ferritic High Temperature Alloy             Ferritic
#
#                         Nuclear Application C (wt.%)  Si (wt.%)  Mn (wt.%)  \
# 1                 Core Structural Materials     0.02       0.45        1.3
# 2                 Core Structural Materials     0.02       0.45        1.3
# ...

# %%
df.tail()
# Out:
#       Reference Material Material Group Chemistry & Alloy Family  \
# 1046         24   SS316L          SS316         Stainless Steels
# 1047         24   SS316L          SS316         Stainless Steels
# 1048         24   SS316L          SS316         Stainless Steels
# 1049         24   SS316L          SS316         Stainless Steels
# 1050         24   SS316L          SS316         Stainless Steels
#
#      Microstructure Class        Nuclear Application C (wt.%)  Si (wt.%)  \
# 1046    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1047    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1048    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1049    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1050    Austenitic / FCC   Core Structural Materials     0.02       0.45
#
#       Mn (wt.%)  P (wt.%)  ...  Width (mm)  Aspect Ratio (L/W)  \
# 1046       1.25      0.04  ...         5.0                 7.6
# ...

# %%
# Remove rows where ALL columns are NaN
df = df.dropna(how='all')

# %%
df.tail()
# Out:
#       Reference Material Material Group Chemistry & Alloy Family  \
# 1046         24   SS316L          SS316         Stainless Steels
# 1047         24   SS316L          SS316         Stainless Steels
# 1048         24   SS316L          SS316         Stainless Steels
# 1049         24   SS316L          SS316         Stainless Steels
# 1050         24   SS316L          SS316         Stainless Steels
#
#      Microstructure Class        Nuclear Application C (wt.%)  Si (wt.%)  \
# 1046    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1047    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1048    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1049    Austenitic / FCC   Core Structural Materials     0.02       0.45
# 1050    Austenitic / FCC   Core Structural Materials     0.02       0.45
#
#       Mn (wt.%)  P (wt.%)  ...  Width (mm)  Aspect Ratio (L/W)  \
# 1046       1.25      0.04  ...         5.0                 7.6
# ...

# %%
len(df.columns)
# Out:
# 58

# %%
df.shape
# Out:
# (1050, 58)

# %%
df.columns.tolist()
# Out:
# ['Reference',
#  'Material',
#  'Material Group',
#  'Chemistry & Alloy Family',
#  'Microstructure Class',
#  'Nuclear Application',
#  'C (wt.%)',
#  'Si (wt.%)',
#  'Mn (wt.%)',
#  'P (wt.%)',
#  'S (wt.%)',
#  'Ni (wt.%)',
#  'Cr (wt.%)',
#  'Mo (wt.%)',
#  'Al (wt.%)',
#  'N (wt.%)',
#  'Ti (wt.%)',
#  'Fe (wt.%)',
#  'Nb (wt.%)',
#  'B (wt.%)',
#  'Cu (wt.%)',
#  'V (wt.%)',
#  'Mg (wt.%)',
#  'Y (wt.%)',
#  'Zr (wt.%)',
#  'Zn (wt.%)',
#  'W (wt.%)',
#  'Sn (wt.%)',
#  'Co (wt.%)',
#  'O (wt.,%)',
#  'Ta (wt.%)',
#  'H (wt.%)',
#  'Manufacturing',
#  'Treatment',
#  'Treatment Category',
#  'Post Treatment Temperature (C)',
#  'Post Treatment Time (h)',
#  'Cooling',
#  'Microstructure',
#  'Grain size (um)',
#  'Irradiation Dose (dpa)',
#  'Irradiation Temperature (C)',
#  'Irradiation Time (h)',
#  'Specimen Preparation',
#  'Specimen Size Type',
#  'Gauge Length (mm)',
#  'Thickness (mm)',
#  'Fillet Radius (mm)',
#  'Width (mm)',
#  'Aspect Ratio (L/W)',
# ...

# %%
pd.set_option('display.max_rows', None)   # show all rows
pd.set_option('display.max_columns', None) # show all columns
pd.set_option('display.expand_frame_repr', False) # avoid line wrapping



# Value Distribution and Percentage fraction

# Dropdown widget for column selection
col_selector = widgets.Dropdown(
    options=df.columns.tolist(),
    description='Column:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

# Output area to show value counts and percentages
output = widgets.Output()

# Callback function
def on_column_change(change):
    with output:
        output.clear_output()
        col = change['new']
        
        # Get counts and normalized percentages
        counts = df[col].value_counts()
        percentages = df[col].value_counts(normalize=True) * 100
        
        # Combine into a single DataFrame
        result = pd.DataFrame({
            'Count': counts,
            'Percentage (%)': percentages.round(2)
        })
        
        print(f"Value counts and percentages for column: {col}")
        display(result)

# Link dropdown to callback
col_selector.observe(on_column_change, names='value')

# Display the widget and output
display(col_selector, output)

# Trigger once at start
on_column_change({'new': col_selector.value})
# Out:
# Dropdown(description='Column:', layout=Layout(width='50%'), options=('Reference', 'Material', 'Material Group'…
# Output()

# %% [markdown]
# ### Data Manipulation

# %%
# Remove rows where ALL columns are NaN
df = df.dropna(how='all')

# 4. Missing Values
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Step 1: Get missing value counts and percentages
missing_values = df.isnull().sum()
missing_percent = (df.isna().mean() * 100).round(2)  # Round to 2 decimal places

# Step 2: Determine column types (numerical vs categorical)
column_types = df.dtypes.apply(lambda x: 'Numerical' if pd.api.types.is_numeric_dtype(x) else 'Categorical')

# Step 3: Combine into one DataFrame
missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    '% Missing': missing_percent,
    'Type': column_types
})

# Optional: Filter only columns with missing values
missing_df = missing_df[missing_df['Missing Values'] > 0]

# Display the result
display(missing_df)
# Out:
#                                  Missing Values  % Missing         Type
# C (wt.%)                                    263      25.05  Categorical
# Si (wt.%)                                   296      28.19    Numerical
# Mn (wt.%)                                   294      28.00    Numerical
# P (wt.%)                                    312      29.71    Numerical
# S (wt.%)                                    504      48.00    Numerical
# Ni (wt.%)                                    83       7.90    Numerical
# Cr (wt.%)                                    66       6.29    Numerical
# Mo (wt.%)                                   139      13.24    Numerical
# Al (wt.%)                                   982      93.52    Numerical
# N (wt.%)                                    660      62.86    Numerical
# Ti (wt.%)                                   704      67.05    Numerical
# Fe (wt.%)                                    55       5.24  Categorical
# ...

# %% [markdown]
# convert all parts per million (ppm) to percentages
#
# 1 wt.% = 10,000 ppm

# %% [markdown]
# #### for other early data manipulation
#
# 2. Check for Extremely Low-Variance Features
# Many ppm elements (e.g., trace impurities like B, H, O) may be almost constant in your dataset.
#
# Very low variance = unlikely to help prediction → candidate for dropping.
#
# Use:
#
# python
# Copy
# Edit
# from sklearn.feature_selection import VarianceThreshold
# selector = VarianceThreshold(threshold=1e-6)  # Adjust threshold
# 3. Log Transform (if highly skewed)
# ppm data often spans several orders of magnitude (e.g., 0.5 ppm to 5000 ppm).
#
# Applying log1p (log of value + 1) can:
#
# Reduce skewness
#
# Help models learn multiplicative relationships
#
# Example:
#
# python
# Copy
# Edit
# import numpy as np
# df['B (wt.%)'] = np.log1p(df['B (wt.%)'])
# 4. Scaling
# After unit conversion, scale all features together:
#
# StandardScaler (mean=0, std=1) for models like linear regression, neural nets.
#
# MinMaxScaler (0–1) for distance-based models like k-NN.
#
# This prevents large features from dominating due to their magnitude.
#
# 5. Handling Missing ppm Values
# If an element is below detection limit, ppm may be recorded as blank or zero:
#
# If it’s truly zero, keep it as 0.
#
# If it’s missing due to not being measured, impute (median is safer than mean for skewed data).
#
# Keep in mind: imputation can introduce bias if the missingness is systematic.
#
# 6. Consider Feature Engineering
# Ratios of ppm elements can be more predictive than absolute amounts for some metallurgy problems (e.g., Cr/Ni ratio).
#
# Grouping: Combine certain ppm elements into “trace impurity index”.
#
# ✅ Rule of Thumb:
# For machine learning, always bring ppm into the same scale and unit as other composition features before modeling. Otherwise, the algorithm might think that 500 ppm is "huge" compared to 0.5 wt.%, when in reality they’re almost the same magnitude in physical terms.

# %% [markdown]
# sequence of data manipulation is very important because you want to avoid data leakage or a situation where data modification afffects the integrity of other data in subsequent manipulations.
#
# its best to start from the least complex, gradually manipulate the dataset, and ensure each action was carried out without affecting the integrity of the dataset.

# %%
df.head()
# Out:
#    Reference Material         Material Group                  Chemistry & Alloy Family Microstructure Class                       Nuclear Application C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%) Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%) Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%) O (wt.,%)  Ta (wt.%)  H (wt.%) Manufacturing                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h) Cooling Microstructure  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Irradiation Time (h)      Specimen Preparation Specimen Size Type  Gauge Length (mm)  Thickness (mm)  Fillet Radius (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (R/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)  Ultimate Tensile Strength (MPa)  Uniform Elongation (%)  Total Elongation (%)
# ...

# %%
df.columns.tolist()
# Out:
# ['Reference',
#  'Material',
#  'Material Group',
#  'Chemistry & Alloy Family',
#  'Microstructure Class',
#  'Nuclear Application',
#  'C (wt.%)',
#  'Si (wt.%)',
#  'Mn (wt.%)',
#  'P (wt.%)',
#  'S (wt.%)',
#  'Ni (wt.%)',
#  'Cr (wt.%)',
#  'Mo (wt.%)',
#  'Al (wt.%)',
#  'N (wt.%)',
#  'Ti (wt.%)',
#  'Fe (wt.%)',
#  'Nb (wt.%)',
#  'B (wt.%)',
#  'Cu (wt.%)',
#  'V (wt.%)',
#  'Mg (wt.%)',
#  'Y (wt.%)',
#  'Zr (wt.%)',
#  'Zn (wt.%)',
#  'W (wt.%)',
#  'Sn (wt.%)',
#  'Co (wt.%)',
#  'O (wt.,%)',
#  'Ta (wt.%)',
#  'H (wt.%)',
#  'Manufacturing',
#  'Treatment',
#  'Treatment Category',
#  'Post Treatment Temperature (C)',
#  'Post Treatment Time (h)',
#  'Cooling',
#  'Microstructure',
#  'Grain size (um)',
#  'Irradiation Dose (dpa)',
#  'Irradiation Temperature (C)',
#  'Irradiation Time (h)',
#  'Specimen Preparation',
#  'Specimen Size Type',
#  'Gauge Length (mm)',
#  'Thickness (mm)',
#  'Fillet Radius (mm)',
#  'Width (mm)',
#  'Aspect Ratio (L/W)',
# ...

# %%
# Row Selection and Viewing

# Widgets to select row and column ranges
row_range = widgets.IntRangeSlider(
    value=[0, 15],
    min=0,
    max=len(df) - 1,
    step=1,
    description='Row Range:',
    continuous_update=False,
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='80%')
)

column_range = widgets.IntRangeSlider(
    value=[0, 10],
    min=0,
    max=len(df.columns) - 1,
    step=1,
    description='Column Range:',
    continuous_update=False,
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='80%')
)

# Output widget
subset_output = widgets.Output()

# Function to display selected subset only (no top/bottom prints)
def update_subset(change):
    if change['type'] == 'change' and change['name'] == 'value':
        subset_output.clear_output()
        with subset_output:
            row_start, row_end = row_range.value
            col_start, col_end = column_range.value
            subset = df.iloc[row_start:row_end+1, col_start:col_end+1]
            display(subset)

# Link sliders to update function
row_range.observe(update_subset, names='value')
column_range.observe(update_subset, names='value')

# Display interface
display(widgets.VBox([row_range, column_range, subset_output]))

# Trigger initial display
update_subset({'type': 'change', 'name': 'value'})

# %% [markdown]
# Test temperature is a critical information of any tensile test. therefore if test temperature is not given, assume it is room temperature.

# %%
df['Test Temperature (C)'] = df['Test Temperature (C)'].fillna(23)

# %% [markdown]
# for Treatment & Treatment category 21.52% of the rows have no entries. however, these span across 27 out of 45 materials & 8 out of 9 material groups. the non-missing entries span across 21 out of 45 materials and 7 out of 9 material groups. it might be possible to use an imputer, however best to enter "unknown" for now and discuss with experts.

# %%
df['Treatment'] = df['Treatment'].fillna('unknown')
df['Treatment Category'] = df['Treatment Category'].fillna('unknown')

# %% [markdown]
# where no PT temp is given, assume it is room temperature. use this to fill in the PT time as zero, i.e. no PT time.

# %%
# Replace NaN in 'Post Treatment Temperature (C)' with 23
df['Post Treatment Temperature (C)'] = df['Post Treatment Temperature (C)'].fillna(23)

# Where 'Post Treatment Temperature (C)' is 23, set 'Post Treatment Time (h)' to 0
df.loc[df['Post Treatment Temperature (C)'] == 23, 'Post Treatment Time (h)'] = 0

# %% [markdown]
# for Irradiation Temperature (C) & Irradiation Dose (dpa), both have 69.81% missing values. however, with radiation being such a critical attribute in nuclear research, it is difficult to forsee a situation where irradiation information will not be given if carried out on tensile sample. indeed 30.19% of irradiated samples are given. so we can assume that the missing values means there was no irradiation carried out on specimens - therefore NaN cells will be replaced with '0'.

# %%
# Replace NaN with 0 for the two specific columns
df[['Irradiation Temperature (C)', 'Irradiation Dose (dpa)']] = (
    df[['Irradiation Temperature (C)', 'Irradiation Dose (dpa)']].fillna(0)
)

# %% [markdown]
# necessary to drop columns with significantly high missing data.

# %% [markdown]
# cooling
# 96.67% missing
#
# of the not-missing cells, they span across 5 materials (A-213L, A-533B, F82H, SA508 C1.3, SS316L)
#
# So i tried to filter on these 5 materials to see if cooling entries exist for 100% of cases of these 5 materials
#
# - A-213L: 3 furnace, 1 air, 2 blank
# - A-533B: 3 furnace, 2 air, 1 blank
# - F82H: 2 furnace, 1 air, 1 blank
# - SA508 C1.3: all 11 cases are austenitizing-water quenching
# - SS316L: 10 furnance, 2 air, 45 blank
#
# with a total of 45 materials, it will be alot of work to input cooling for each, and it would be based on heavy assumption.
# delete cooling column

# %%
# Columns to drop
# missing values are too high

cols_to_drop = [
    'Irradiation Time (h)', # 99.90% missing
    'Microstructure',       # 98.95% missing
    'Cooling',              # 96.67% missing
    'Manufacturing',        # 89.33% missing
    'Aspect Ratio (R/W)',   # 85.81% missing
    'Fillet Radius (mm)',    # 84.19% missing
    'Specimen Preparation', # 80.10% missing
    'Specimen Size Type',   # 50.48% missing
]

# Drop only if they exist in the dataframe
df = df.drop(columns=[col for col in cols_to_drop if col in df.columns])

# %%
df.columns
# Out:
# Index(['Reference', 'Material', 'Material Group', 'Chemistry & Alloy Family',
#        'Microstructure Class', 'Nuclear Application', 'C (wt.%)', 'Si (wt.%)',
#        'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)', 'Ni (wt.%)', 'Cr (wt.%)',
#        'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)', 'Ti (wt.%)', 'Fe (wt.%)',
#        'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)', 'V (wt.%)', 'Mg (wt.%)',
#        'Y (wt.%)', 'Zr (wt.%)', 'Zn (wt.%)', 'W (wt.%)', 'Sn (wt.%)',
#        'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)', 'H (wt.%)', 'Treatment',
#        'Treatment Category', 'Post Treatment Temperature (C)',
#        'Post Treatment Time (h)', 'Grain size (um)', 'Irradiation Dose (dpa)',
#        'Irradiation Temperature (C)', 'Gauge Length (mm)', 'Thickness (mm)',
#        'Width (mm)', 'Aspect Ratio (L/W)', 'Aspect Ratio (T/W)',
#        'Test Temperature (C)', 'Strain Rate (1/s)', 'Yield Strength (MPa)',
#        'Ultimate Tensile Strength (MPa)', 'Uniform Elongation (%)',
#        'Total Elongation (%)'],
# ...

# %%
df.drop(columns=["Material Group", "Nuclear Application"], inplace=True)

# %%
df.columns
# Out:
# Index(['Reference', 'Material', 'Chemistry & Alloy Family',
#        'Microstructure Class', 'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)',
#        'P (wt.%)', 'S (wt.%)', 'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)',
#        'Al (wt.%)', 'N (wt.%)', 'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)',
#        'B (wt.%)', 'Cu (wt.%)', 'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)',
#        'Zr (wt.%)', 'Zn (wt.%)', 'W (wt.%)', 'Sn (wt.%)', 'Co (wt.%)',
#        'O (wt.,%)', 'Ta (wt.%)', 'H (wt.%)', 'Treatment', 'Treatment Category',
#        'Post Treatment Temperature (C)', 'Post Treatment Time (h)',
#        'Grain size (um)', 'Irradiation Dose (dpa)',
#        'Irradiation Temperature (C)', 'Gauge Length (mm)', 'Thickness (mm)',
#        'Width (mm)', 'Aspect Ratio (L/W)', 'Aspect Ratio (T/W)',
#        'Test Temperature (C)', 'Strain Rate (1/s)', 'Yield Strength (MPa)',
#        'Ultimate Tensile Strength (MPa)', 'Uniform Elongation (%)',
#        'Total Elongation (%)'],
#       dtype='object')

# %% [markdown]
# chemical composition data: modify the numbers which have text in them

# %%
# Handling values such as <40 ppm, 150-400ppm, <0.6 & applying to all chemical composition columns



import pandas as pd
import numpy as np
import re

def parse_chem_value(val):
    if pd.isna(val):
        return np.nan
    
    val_str = str(val).strip().lower()
    
    # Handle ppm ranges like "150-400ppm"
    range_match = re.match(r'(\d+(?:\.\d+)?)\s*-\s*(\d+(?:\.\d+)?)(?:\s*ppm)?', val_str)
    if range_match:
        low = float(range_match.group(1))
        high = float(range_match.group(2))
        ppm_avg = (low + high) / 2
        return ppm_avg / 10000  # ppm to wt.%
    
    # Handle less-than values e.g. "<40 ppm" or "<0.6"
    lt_match = re.match(r'<\s*(\d+(?:\.\d+)?)(?:\s*ppm)?', val_str)
    if lt_match:
        num = float(lt_match.group(1))
        if "ppm" in val_str:
            return num / 10000  # ppm to wt.%
        else:
            return num  # already wt.%
    
    # Handle single ppm values e.g. "200 ppm"
    ppm_match = re.match(r'(\d+(?:\.\d+)?)(?:\s*ppm)', val_str)
    if ppm_match:
        num = float(ppm_match.group(1))
        return num / 10000  # ppm to wt.%
    
    # Handle plain numbers (already wt.%)
    try:
        return float(val_str)
    except ValueError:
        return np.nan

# Columns to modify
cols_to_modify = [
    'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)',
    'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)',
    'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)',
    'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)', 'Zr (wt.%)', 'Zn (wt.%)',
    'W (wt.%)', 'Sn (wt.%)', 'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)',
    'H (wt.%)'
]

# Apply parsing function to each relevant column
for col in cols_to_modify:
    if col in df.columns:
        df[col] = df[col].apply(parse_chem_value)

# %% [markdown]
# as i was carrying out data manipulation on the chemical composition, i realised that Rows 589 to 610 of zirconium changed from become "bal" to "nan". so i created codes to calculate the numerical equivalent of "bal" for these rows and input into the dataset

# %%
# Define chemical composition columns
composition_cols = [
    'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)',
    'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)',
    'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)',
    'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)', 'Zn (wt.%)', 'W (wt.%)',
    'Sn (wt.%)', 'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)', 'H (wt.%)'
]

# Make sure we only keep the ones that exist in the dataframe
composition_cols = [col for col in composition_cols if col in df.columns]

# For rows 589–610 (inclusive), calculate balance for Zr
df.loc[589:610, 'Zr (wt.%)'] = 100 - df.loc[589:610, composition_cols].sum(axis=1)

# %% [markdown]
# now that all chemical compositon manipulations are complete, the last action is to replace all NaN compoistion values with 0 to show the element was not present or detected in the

# %%
# Identify chemical composition columns automatically
chem_cols = [col for col in df.columns if '(wt.%)' in col or '(wt.,%)' in col]

# Replace NaN with 0 in those columns only
df[chem_cols] = df[chem_cols].fillna(0)

# %%
# List of columns to modify
cols_to_fill = [
    'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)',
    'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)',
    'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)',
    'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)', 'Zr (wt.%)', 'Zn (wt.%)',
    'W (wt.%)', 'Sn (wt.%)', 'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)',
    'H (wt.%)'
]

# Ensure we only work on columns that actually exist in the file
existing_cols = [col for col in cols_to_fill if col in df.columns]

# Replace blank strings or spaces with NaN, then fill NaN with 0
df[existing_cols] = df[existing_cols].replace(['', ' '], pd.NA).fillna(0)

# %% [markdown]
# for some of the columns of lower percentage of missing figures, use KNN imputer to fill-in. investigate if they can be filled using other more obvious derivative means first, before using KNN imputer.

# %% [markdown]
# ASPECT RATIOS
#
# for Aspect Ratio (R/W)
# 85.81% missing - too high, remove column
#
# for Aspect Ratio (L/W)
# 29.81% missing - however, 8 rows have both Gauge Length (L) & Width (W)
#
# for Aspect Ratio (T/W)
# 20.86% missing - however, 19 rows have both Thickness (T) & Width (W)
#
# create formula to calculate Aspect Ratio (L/W) where L (Gauge Length (mm)) & W (Width (mm)) are simulateously not NaN or 0
# create formula to calculate Aspect Ration (T/W) where T (Thickness (mm)) & W (Width (mm)) are simulateously not NaN or 0
#
# use advanced technique to input the remaining missing values for Aspect Ratio (L/W) & Aspect Ratio (T/W)

# %%
import pandas as pd
import numpy as np

# Condition for Aspect Ratio (L/W): L and W are not NaN and not zero
mask_LW = (
    df['Gauge Length (mm)'].notna() & (df['Gauge Length (mm)'] != 0) &
    df['Width (mm)'].notna() & (df['Width (mm)'] != 0)
)

df.loc[mask_LW, 'Aspect Ratio (L/W)'] = df.loc[mask_LW, 'Gauge Length (mm)'] / df.loc[mask_LW, 'Width (mm)']

# Condition for Aspect Ratio (T/W): T and W are not NaN and not zero
mask_TW = (
    df['Thickness (mm)'].notna() & (df['Thickness (mm)'] != 0) &
    df['Width (mm)'].notna() & (df['Width (mm)'] != 0)
)

df.loc[mask_TW, 'Aspect Ratio (T/W)'] = df.loc[mask_TW, 'Thickness (mm)'] / df.loc[mask_TW, 'Width (mm)']

# %% [markdown]
# i noticed that my imputer was not working because infinity values were contained in the Width column. this is obviously wrong because every every specimen has a width

# %%
from sklearn.impute import KNNImputer

# Columns to impute
cols_to_impute = [
    'Grain size (um)',     # 27.14% missing
    'Width (mm)',          # 28.00% missing
    'Gauge Length (mm)',   # 29.05% missing
    'Strain Rate (1/s)',   # 6.38% missing
    'Thickness (mm)'       # 16.48% missing
]

# Initialize imputer (you can tune n_neighbors)
imputer = KNNImputer(n_neighbors=5)

# Apply imputation only on selected columns, keep others intact
df[cols_to_impute] = imputer.fit_transform(df[cols_to_impute])

# %%
# 4. Missing Values
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Step 1: Get missing value counts and percentages
missing_values = df.isnull().sum()
missing_percent = (df.isna().mean() * 100).round(2)  # Round to 2 decimal places

# Step 2: Determine column types (numerical vs categorical)
column_types = df.dtypes.apply(lambda x: 'Numerical' if pd.api.types.is_numeric_dtype(x) else 'Categorical')

# Step 3: Combine into one DataFrame
missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    '% Missing': missing_percent,
    'Type': column_types
})

# Optional: Filter only columns with missing values
missing_df = missing_df[missing_df['Missing Values'] > 0]

# Display the result
display(missing_df)
# Out:
#                                  Missing Values  % Missing       Type
# Post Treatment Time (h)                      23       2.19  Numerical
# Aspect Ratio (L/W)                          305      29.05  Numerical
# Aspect Ratio (T/W)                          211      20.10  Numerical
# Yield Strength (MPa)                        460      43.81  Numerical
# Ultimate Tensile Strength (MPa)             561      53.43  Numerical
# Uniform Elongation (%)                      797      75.90  Numerical
# Total Elongation (%)                        514      48.95  Numerical

# %%
from sklearn.impute import KNNImputer

# Include Post Treatment Time (h) with other numeric columns to help imputation
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Initialize KNN imputer
imputer = KNNImputer(n_neighbors=5)

# Fit-transform only numeric columns
df_numeric_imputed = imputer.fit_transform(df[numeric_cols])

# Convert back to DataFrame
df_numeric_imputed = pd.DataFrame(df_numeric_imputed, columns=numeric_cols)

# Replace only 'Post Treatment Time (h)' column with imputed values
df['Post Treatment Time (h)'] = df_numeric_imputed['Post Treatment Time (h)']

# %%
df.shape
# Out:
# (1050, 48)

# %%
df['Post Treatment Time (h)'] = df['Post Treatment Time (h)'].fillna(0)

# %%
# Select only numeric columns for imputation
numeric_df = df.select_dtypes(include=[np.number])

# Keep track of which columns we want to impute
cols_to_impute = ['Aspect Ratio (L/W)', 'Aspect Ratio (T/W)']

# Fit KNNImputer
imputer = KNNImputer(n_neighbors=23, weights="distance")

# Apply imputation
numeric_df[cols_to_impute] = imputer.fit_transform(numeric_df)[..., [numeric_df.columns.get_loc(c) for c in cols_to_impute]]

# Put the imputed numeric values back into df
for col in cols_to_impute:
    df[col] = numeric_df[col]

# %%
# 4. Missing Values
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# Step 1: Get missing value counts and percentages
missing_values = df.isnull().sum()
missing_percent = (df.isna().mean() * 100).round(2)  # Round to 2 decimal places

# Step 2: Determine column types (numerical vs categorical)
column_types = df.dtypes.apply(lambda x: 'Numerical' if pd.api.types.is_numeric_dtype(x) else 'Categorical')

# Step 3: Combine into one DataFrame
missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    '% Missing': missing_percent,
    'Type': column_types
})

# Optional: Filter only columns with missing values
missing_df = missing_df[missing_df['Missing Values'] > 0]

# Display the result
display(missing_df)
# Out:
#                                  Missing Values  % Missing       Type
# Yield Strength (MPa)                        460      43.81  Numerical
# Ultimate Tensile Strength (MPa)             561      53.43  Numerical
# Uniform Elongation (%)                      797      75.90  Numerical
# Total Elongation (%)                        514      48.95  Numerical

# %% [markdown]
# # TARGET FEATURES

# %% [markdown]
# ### 1. Yield Strength

# %% [markdown]
# 43.81% (460 out of 1050 records)
# - for accurate prediction, remove the missing

# %%
dfYS = df.dropna(subset=['Yield Strength (MPa)'])

# %%
# drop other target features
# update for each target feature

dfYS = dfYS.drop(columns=[
    'Ultimate Tensile Strength (MPa)',
    'Uniform Elongation (%)',
    'Total Elongation (%)',
    'Reference'
])

# %%
dfYS.shape
# Out:
# (590, 44)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import mean_squared_error, r2_score

# %%
dfYS.columns
# Out:
# Index(['Material', 'Chemistry & Alloy Family', 'Microstructure Class',
#        'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)',
#        'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)',
#        'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)',
#        'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)', 'Zr (wt.%)', 'Zn (wt.%)',
#        'W (wt.%)', 'Sn (wt.%)', 'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)',
#        'H (wt.%)', 'Treatment', 'Treatment Category',
#        'Post Treatment Temperature (C)', 'Post Treatment Time (h)',
#        'Grain size (um)', 'Irradiation Dose (dpa)',
#        'Irradiation Temperature (C)', 'Gauge Length (mm)', 'Thickness (mm)',
#        'Width (mm)', 'Aspect Ratio (L/W)', 'Aspect Ratio (T/W)',
#        'Test Temperature (C)', 'Strain Rate (1/s)', 'Yield Strength (MPa)'],
#       dtype='object')

# %% [markdown]
# ### YS Preprocessing

# %%
# ========================================
# 1. Remove duplicates
# ========================================
dfYS = dfYS.drop_duplicates()                      # update for each target feature

# %%
dfYS.shape                                          # update for each target feature
# Out:
# (585, 44)

# %% [markdown]
# #### Prepping settings from hypothesis 4 for hypothesis 5

# %%
# Filter rows where Chemistry & Alloy Family is 'Stainless Steels'
dfYS = dfYS[dfYS['Chemistry & Alloy Family'] == 'Stainless Steels']

# Display the shape and first few rows
print(f"Filtered rows: {dfYS.shape[0]}")
display(dfYS.head())
# Out:
# Filtered rows: 353
#    Material Chemistry & Alloy Family Microstructure Class  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)              Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)
# ...

# %%
# Filter rows where Chemistry & Alloy Family is either 'Stainless Steels' or 'Ferritic-Martensitic'
dfYS = dfYS[dfYS['Microstructure Class'].isin(['Tempered Martensitic'])]

# Display the shape and first few rows
print(f"Filtered rows: {dfYS.shape[0]}")
display(dfYS.head())
# Out:
# Filtered rows: 123
#    Material     Chemistry & Alloy Family  Microstructure Class  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)
# ...

# %%
# Define the microstructures to keep
selected_microstructures = [
    'Ferritic',
    'HCP solid solution',
    'Tempered Bainitic',
    'Ferrite + Pearlite',
    'α+β Structure',
    'Ferritic-Martensitic (dual phase)'
]

# Filter rows where Microstructure Class matches selected values
dfYS = dfYS[dfYS['Microstructure Class'].isin(selected_microstructures)]

# Display the shape and first few rows
print(f"Filtered rows: {dfYS.shape[0]}")
display(dfYS.head())
# Out:
# Filtered rows: 96
#   Material                  Chemistry & Alloy Family Microstructure Class  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)
# ...

# %%
dfYS = dfYS[dfYS['Material'] != 'SS316']

# %%
dfYS.shape
# Out:
# (246, 46)

# %%
# Filter rows where Chemistry & Alloy Family is either 'Stainless Steels' or 'Ferritic-Martensitic'
dfYS = dfYS[dfYS['Chemistry & Alloy Family'].isin(['Stainless Steels', 'Ferritic-Martensitic Steels'])]

# Display the shape and first few rows
print(f"Filtered rows: {dfYS.shape[0]}")
display(dfYS.head())
# Out:
# Filtered rows: 492
#   Material         Material Group     Chemistry & Alloy Family Microstructure Class                       Nuclear Application  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)
# ...

# %%
# Filter rows where Chemistry & Alloy Family is 'Stainless Steels'
dfYS = dfYS[dfYS['Microstructure Class'] == 'Ferritic-Martensitic']

# Display the shape and first few rows
print(f"Filtered rows: {dfYS.shape[0]}")
display(dfYS.head())
# Out:
# Filtered rows: 115
#    Material           Material Group     Chemistry & Alloy Family  Microstructure Class                                Nuclear Application  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)
# ...

# %%
# Filter rows where Chemistry & Alloy Family is either 'Stainless Steels' or 'Ferritic-Martensitic'
dfYS = dfYS[dfYS['Microstructure Class'].isin(['Ferritic', 'Ferritic-Martensitic', 'Ferrite + Pearlite', 'Refined Ferritic'])]

# Display the shape and first few rows
print(f"Filtered rows: {dfYS.shape[0]}")
display(dfYS.head())
# Out:
# Filtered rows: 137
#   Material      Material Group     Chemistry & Alloy Family Microstructure Class                       Nuclear Application  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)
# ...

# %% [markdown]
# #### Hold Out Material

# %% [markdown]
# ### USE THIS FOR HYPOTHESIS 5

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd

# Assume dfYS is your original dataframe
materials = dfYS['Material'].unique().tolist()

# Dropdown widget to select material
material_selector = widgets.Dropdown(
    options=materials,
    description='Select Material:',
    style={'description_width': 'initial'}
)

# Output area to show results
output = widgets.Output()

# Global variables
selected_material = None
df_holdout = None
df_remaining = None

# Function to split data based on selected material
def split_data(change):
    global selected_material, df_holdout, df_remaining
    with output:
        clear_output(wait=True)
        
        selected_material = material_selector.value
        
        # Create holdout and remaining datasets
        df_holdout = dfYS[dfYS['Material'] == selected_material].reset_index(drop=True)
        df_remaining = dfYS[dfYS['Material'] != selected_material].reset_index(drop=True)
        
        # Display shapes
        print(f"✅ Holdout Material: {selected_material}")
        print(f"Holdout shape: {df_holdout.shape}")
        print(f"Remaining data shape: {df_remaining.shape}")
        
        # Optionally show first few rows
        display(df_holdout.head(), df_remaining.head())


# Attach event listener
material_selector.observe(split_data, names='value')

# Display widgets and output
display(material_selector, output)

# Initial run
split_data(None)
# Out:
# Dropdown(description='Select Material:', options=('FeCrAl', 'Zircaloy-4', 'A-533B', 'SA508 C1.3 ', 'Ultra-fine…
# Output()

# %% [markdown]
# #### Outlier Removal

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
from sklearn.ensemble import IsolationForest
import numpy as np
import pandas as pd

# ---- Combined OutlierRemover Class ----
class OutlierRemover:
    def __init__(self, method='none', factor=1.5, z_thresh=3.0, iso_cont=0.05, max_outliers=None):
        self.method = method
        self.factor = factor
        self.z_thresh = z_thresh
        self.iso_cont = iso_cont
        self.max_outliers = max_outliers

    def fit_transform(self, df):
        if self.method == 'none':
            return df.copy(), df.iloc[0:0]

        numeric_df = df.select_dtypes(include=[np.number])

        if self.method == 'iqr':
            Q1 = numeric_df.quantile(0.25)
            Q3 = numeric_df.quantile(0.75)
            IQR = Q3 - Q1
            score = ((numeric_df < (Q1 - self.factor * IQR)) | (numeric_df > (Q3 + self.factor * IQR))).sum(axis=1)

        elif self.method == 'zscore':
            z = (numeric_df - numeric_df.mean()) / numeric_df.std()
            score = (np.abs(z) > self.z_thresh).sum(axis=1)

        elif self.method == 'isoforest':
            iso = IsolationForest(contamination=self.iso_cont, random_state=42)
            iso.fit(numeric_df)
            score = pd.Series(-iso.score_samples(numeric_df), index=df.index)

        else:
            return df.copy(), df.iloc[0:0]

        # Sort by score
        score_sorted_idx = score.sort_values(ascending=False).index
        if self.max_outliers:
            outlier_idx = score_sorted_idx[:self.max_outliers]
        else:
            outlier_idx = score[score > 0].index  # Keep all flagged rows

        df_clean = df.drop(outlier_idx)
        df_outliers = df.loc[outlier_idx]

        return df_clean, df_outliers


# ---- Widgets ----
method_selector = widgets.Dropdown(
    options=['none', 'zscore', 'iqr', 'isoforest'],
    value='none',
    description='Method:',
    style={'description_width': 'initial'}
)

factor_slider = widgets.FloatSlider(value=1.5, min=0.5, max=3.0, step=0.1, description='IQR Factor')
z_thresh_slider = widgets.FloatSlider(value=3.0, min=1.0, max=5.0, step=0.1, description='Z-score Threshold')
iso_cont_slider = widgets.FloatSlider(value=0.05, min=0.01, max=0.5, step=0.01, description='IsoForest Contamination')
max_outliers_slider = widgets.IntSlider(value=10, min=1, max=50, step=1, description='Top N Outliers')

show_full_checkbox = widgets.Checkbox(value=False, description='Show Full DataFrame')

output_area = widgets.Output()

# ---- Slider Visibility ----
def update_slider_visibility(change):
    method = change['new']
    factor_slider.layout.display = 'none'
    z_thresh_slider.layout.display = 'none'
    iso_cont_slider.layout.display = 'none'
    if method == 'iqr':
        factor_slider.layout.display = 'block'
    elif method == 'zscore':
        z_thresh_slider.layout.display = 'block'
    elif method == 'isoforest':
        iso_cont_slider.layout.display = 'block'

method_selector.observe(update_slider_visibility, names='value')
update_slider_visibility({'new': method_selector.value})  # Initialize

# ---- Apply Outlier Removal ----
def apply_outlier_removal(_):
    global dfYS_clean, dfYS_outliers
    
    # Use df_remaining if it exists, else default to dfYS
    try:
        data_to_process = df_remaining if 'df_remaining' in globals() and df_remaining is not None else dfYS
    except NameError:
        data_to_process = dfYS

    remover = OutlierRemover(
        method=method_selector.value,
        factor=factor_slider.value,
        z_thresh=z_thresh_slider.value,
        iso_cont=iso_cont_slider.value,
        max_outliers=max_outliers_slider.value
    )
    dfYS_clean, dfYS_outliers = remover.fit_transform(data_to_process)

    with output_area:
        clear_output(wait=True)
        print(f"Original shape: {data_to_process.shape}")
        print(f"New shape:      {dfYS_clean.shape}")
        print(f"Outliers shape: {dfYS_outliers.shape}")

        if show_full_checkbox.value:
            print("\n✅ Cleaned DataFrame (all rows):")
            display(HTML('<div style="max-height:300px; overflow:auto;">' + dfYS_clean.to_html() + '</div>'))
            print("\n🚩 Outliers (all rows):")
            display(HTML('<div style="max-height:300px; overflow:auto;">' + dfYS_outliers.to_html() + '</div>'))
        else:
            print("\n✅ Cleaned DataFrame (first 5 rows):")
            display(HTML(dfYS_clean.head().to_html()))
            print("\n🚩 Outliers (first 5 rows):")
            display(HTML(dfYS_outliers.head().to_html()))

# ---- Bind events ----
method_selector.observe(apply_outlier_removal, names='value')
factor_slider.observe(apply_outlier_removal, names='value')
z_thresh_slider.observe(apply_outlier_removal, names='value')
iso_cont_slider.observe(apply_outlier_removal, names='value')
max_outliers_slider.observe(apply_outlier_removal, names='value')
show_full_checkbox.observe(apply_outlier_removal, names='value')

# ---- Display UI ----
ui = widgets.VBox([method_selector, factor_slider, z_thresh_slider, iso_cont_slider,
                   max_outliers_slider, show_full_checkbox, output_area])
display(ui)

# Initial run
apply_outlier_removal(None)

# %%
# ========================================
# 3. Train-test split
# ========================================
X = dfYS_clean.drop(columns=['Yield Strength (MPa)'])             # update for each target feature
y = dfYS_clean['Yield Strength (MPa)']                            # update for each target feature

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

print(f"X_train shape: {X_train.shape}")
print(f"X_test  shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test  shape: {y_test.shape}")
# Out:
# X_train shape: (73, 43)
# X_test  shape: (9, 43)
# y_train shape: (73,)
# y_test  shape: (9,)

# %% [markdown]
# #### Feature Selector

# %%
import ipywidgets as widgets
from IPython.display import display
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression, chi2, VarianceThreshold

# Feature selection methods
feature_selection_methods = {
    'F Regression': f_regression,
    'Mutual Info Regression': mutual_info_regression,
    'Chi-Squared': chi2,
    'Variance Threshold': 'variance'
}

# Dropdown for method
method_selector = widgets.Dropdown(
    options=list(feature_selection_methods.keys()),
    value='Mutual Info Regression',
    description='Feature Selection Method:',
    style={'description_width': 'initial'}
)

# Slider for k (number of features)
k_selector = widgets.IntSlider(
    value=43,
    min=1,
    max=50,
    step=1,
    description='Number of Features (k):',
    style={'description_width': 'initial'}
)

display(method_selector, k_selector)
# Out:
# Dropdown(description='Feature Selection Method:', index=1, options=('F Regression', 'Mutual Info Regression', …
# IntSlider(value=43, description='Number of Features (k):', max=50, min=1, style=SliderStyle(description_width=…

# %% [markdown]
# #### Preprocessing Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# Identify numeric/categorical features
numeric_features = X_train.select_dtypes(include=np.number).columns
categorical_features = X_train.select_dtypes(exclude=np.number).columns

# Numeric pipeline
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('normalizer', MinMaxScaler())
])

# Categorical pipeline
categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# Column transformer
preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# Pipeline builder with dynamic feature selection
def build_pipeline(selected_method, k, model):
    from sklearn.feature_selection import SelectKBest, VarianceThreshold
    if selected_method == 'Variance Threshold':
        selector = VarianceThreshold(threshold=0.01)
    else:
        selector = SelectKBest(score_func=feature_selection_methods[selected_method], k=k)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('feature_selection', selector),
        ('model', model)
    ])
    return pipeline

# %% [markdown]
# ### YS Model Training

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor


models_params = {
    'RandomForest': (
        RandomForestRegressor(random_state=42),
        {
            'model__n_estimators': [50, 100, 150, 200, 300],
            'model__max_depth': [None, 5, 10, 15, 20, 30],
            'model__min_samples_split': [2, 5, 10],
            'model__min_samples_leaf': [1, 2, 4]
        }
    ),
    'DecisionTree': (
        DecisionTreeRegressor(random_state=42),
        {
            'model__max_depth': [None, 5, 10, 15, 20],
            'model__min_samples_split': [2, 5, 10, 15],
            'model__min_samples_leaf': [1, 2, 4, 6]
        }
    ),
    'SVR': (
        SVR(),
        {
            'model__kernel': ['linear', 'rbf', 'poly'],
            'model__C': [0.01, 0.1, 1, 5, 10, 50],
            'model__gamma': ['scale', 'auto']
        }
    ),
    'Lasso': (
        Lasso(random_state=42, max_iter=50000),
        {
            'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
        }
    ),
    'KNN': (
        KNeighborsRegressor(),
        {
            'model__n_neighbors': list(range(3, 16, 2)),  # 3,5,7,9,11,13,15
            'model__weights': ['uniform', 'distance'],
            'model__p': [1, 2]  # Manhattan and Euclidean
        }
    ),
    'GradientBoosting': (
        GradientBoostingRegressor(random_state=42),
        {
            'model__n_estimators': [100, 200, 300, 400],
            'model__learning_rate': [0.01, 0.05, 0.1, 0.2],
            'model__max_depth': [3, 5, 7],
            'model__min_samples_split': [2, 5, 10]
        }
    ),
    'AdaBoost': (
        AdaBoostRegressor(random_state=42),
        {
            'model__n_estimators': [50, 100, 200],
            'model__learning_rate': [0.01, 0.05, 0.1, 0.5, 1]
        }
    ),
    'Bagging': (
        BaggingRegressor(random_state=42),
        {
            'model__n_estimators': [10, 20, 50, 100, 200],
            'model__max_samples': [0.5, 0.7, 1.0],
            'model__max_features': [0.5, 0.7, 1.0]
        }
    )
}

# %%
cv_selector = widgets.Dropdown(
    options=['GridSearchCV', 'RandomizedSearchCV', 'BayesSearchCV'],
    value='GridSearchCV',
    description='CV Method:',
    style={'description_width': 'initial'}
)
display(cv_selector)
# Out:
# Dropdown(description='CV Method:', options=('GridSearchCV', 'RandomizedSearchCV', 'BayesSearchCV'), style=Desc…

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from skopt import BayesSearchCV
import numpy as np

# Store trained models, predictions, and search objects for later use
trained_models = {}
predictions = {}

def run_model_training(X_train, X_test, y_train, y_test, selected_method, selected_k, cv_method='GridSearchCV', n_iter=20):
    global trained_models, predictions
    trained_models.clear()
    predictions.clear()

    for name, (model, params) in models_params.items():
        print(f"🏋️ Training {name} using {cv_method}...")
        pipeline = build_pipeline(selected_method, selected_k, model)
        
        # Select CV method
        if cv_method == 'GridSearchCV':
            search = GridSearchCV(pipeline, params, cv=5, scoring='r2', n_jobs=-1)
        elif cv_method == 'RandomizedSearchCV':
            search = RandomizedSearchCV(pipeline, params, n_iter=n_iter, cv=5, scoring='r2', n_jobs=-1, random_state=42)
        else:  # BayesSearchCV
            search = BayesSearchCV(pipeline, params, n_iter=n_iter, cv=5, scoring='r2', n_jobs=-1, random_state=42)
        
        search.fit(X_train, y_train)
        y_pred = search.predict(X_test)
        
        trained_models[name] = search
        predictions[name] = {'y_test': y_test, 'y_pred': y_pred}

cv_choice = cv_selector.value
run_model_training(X_train, X_test, y_train, y_test, method_selector.value, k_selector.value, cv_method=cv_choice)
# Out:
# 🏋️ Training RandomForest using GridSearchCV...
# 🏋️ Training DecisionTree using GridSearchCV...
# 🏋️ Training SVR using GridSearchCV...
# 🏋️ Training Lasso using GridSearchCV...
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.045e+03, tolerance: 2.303e+02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.278e+03, tolerance: 1.988e+02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# ### YS Results

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import numpy as np

def evaluate_models():
    results = {}

    for name, data in predictions.items():
        y_test, y_pred = data['y_test'], data['y_pred']

        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(y_test, y_pred)
        mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
        r2 = r2_score(y_test, y_pred)

        # Store results for this model
        results[name] = {
            'Best Params': trained_models[name].best_params_,
            'MSE': mse,
            'RMSE': rmse,
            'MAE': mae,
            'MAPE (%)': mape,
            'R2 Score': r2
        }

    results_df = pd.DataFrame(results).T.sort_values(
        by='R2 Score',
        ascending=False
    )

    return results_df

final_results = evaluate_models()
print(final_results)
# Out:
#                                                         Best Params        MSE     RMSE      MAE MAPE (%) R2 Score
# Lasso                                         {'model__alpha': 0.1}  7874.5551  88.7387  63.4411   7.7307   0.8976
# DecisionTree      {'model__max_depth': 5, 'model__min_samples_le...  8606.1631  92.7694  69.2117   8.6861   0.8880
# AdaBoost          {'model__learning_rate': 0.01, 'model__n_estim... 10371.9905 101.8430  76.5689   9.8219   0.8651
# GradientBoosting  {'model__learning_rate': 0.01, 'model__max_dep... 11461.3731 107.0578  81.0174  10.2014   0.8509
# RandomForest      {'model__max_depth': 5, 'model__min_samples_le... 13551.9902 116.4130  80.9357   9.8842   0.8237
# KNN               {'model__n_neighbors': 9, 'model__p': 1, 'mode... 15236.0945 123.4346  91.6786  11.9694   0.8018
# Bagging           {'model__max_features': 0.5, 'model__max_sampl... 27508.3458 165.8564 109.2520  12.4453   0.6422
# ...

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-10, None))) * 100

def evaluate_with_kfold(X, y, model_pipeline, k=5):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    mae_scores, rmse_scores, mse_scores, mape_scores, r2_scores = [], [], [], [], []

    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model_pipeline.fit(X_train, y_train)
        y_pred = model_pipeline.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        mape = mean_absolute_percentage_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)

        mae_scores.append(mae)
        mse_scores.append(mse)
        rmse_scores.append(rmse)
        mape_scores.append(mape)
        r2_scores.append(r2)

    return {
        'MAE': (np.mean(mae_scores), np.std(mae_scores)),
        'MSE': (np.mean(mse_scores), np.std(mse_scores)),
        'RMSE': (np.mean(rmse_scores), np.std(rmse_scores)),
        'MAPE': (np.mean(mape_scores), np.std(mape_scores)),
        'R2': (np.mean(r2_scores), np.std(r2_scores))
    }

# ✅ Evaluate each best model from GridSearch
k = 9
X_full = X_train  # Full cleaned training data
y_full = y_train

cv_results = {}
for name, search_obj in trained_models.items():
    best_pipeline = search_obj.best_estimator_
    metrics = evaluate_with_kfold(X_full, y_full, best_pipeline, k=k)
    cv_results[name] = metrics
    print(f"\nModel: {name}")
    print(f"MAE:  {metrics['MAE'][0]:.4f} ± {metrics['MAE'][1]:.4f}")
    print(f"MSE:  {metrics['MSE'][0]:.4f} ± {metrics['MSE'][1]:.4f}")
    print(f"RMSE: {metrics['RMSE'][0]:.4f} ± {metrics['RMSE'][1]:.4f}")
    print(f"MAPE: {metrics['MAPE'][0]:.2f}% ± {metrics['MAPE'][1]:.2f}%")
    print(f"R²:   {metrics['R2'][0]:.4f} ± {metrics['R2'][1]:.4f}")
# Out:
# Model: RandomForest
# MAE:  38.2951 ± 12.0845
# MSE:  3762.4210 ± 3369.1770
# RMSE: 57.0930 ± 22.4233
# MAPE: 6.88% ± 1.24%
# R²:   0.8765 ± 0.0719
#
# Model: DecisionTree
# MAE:  40.2400 ± 19.3265
# MSE:  4952.9077 ± 7025.7745
# RMSE: 61.1066 ± 34.9125
# MAPE: 7.15% ± 2.07%
# R²:   0.8395 ± 0.1309
#
# Model: SVR
# MAE:  54.5933 ± 41.4783
# MSE:  15329.0410 ± 26286.9551
# RMSE: 90.8756 ± 84.0872
# MAPE: 9.12% ± 4.44%
# R²:   0.6816 ± 0.4518
#
# Model: Lasso
# MAE:  32.1507 ± 9.4470
# MSE:  2054.9722 ± 1207.2256
# RMSE: 42.9447 ± 14.5163
# MAPE: 6.47% ± 1.81%
# R²:   0.9077 ± 0.0620
#
# Model: KNN
# MAE:  45.1289 ± 22.5168
# MSE:  7185.7088 ± 10560.3596
# RMSE: 71.1949 ± 46.0109
# MAPE: 9.17% ± 4.63%
# R²:   0.7749 ± 0.1961
#
# Model: GradientBoosting
# MAE:  32.8630 ± 8.4719
# MSE:  2172.2888 ± 1331.0160
# RMSE: 44.8054 ± 12.8360
# MAPE: 6.91% ± 1.84%
# R²:   0.9035 ± 0.0773
#
# Model: AdaBoost
# MAE:  31.8902 ± 7.8351
# MSE:  2056.7659 ± 1201.2986
# RMSE: 43.4777 ± 12.9017
# ...

# %%
#### import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Custom MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-10, None))) * 100

# Evaluate with KFold and return per-fold results
def evaluate_with_kfold_detailed(X, y, model_pipeline, model_name, k=5):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)

    results = []
    fold = 1

    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model_pipeline.fit(X_train, y_train)
        y_pred = model_pipeline.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        mape = mean_absolute_percentage_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)

        results.append({
            'Model': model_name,
            'Fold': fold,
            'MAE': mae,
            'MSE': mse,
            'RMSE': rmse,
            'MAPE (%)': mape,
            'R²': r2
        })
        fold += 1

    return results

# ✅ Run evaluation for all trained models
k = 10
X_full = X_train
y_full = y_train

all_results = []

for name, search_obj in trained_models.items():
    best_pipeline = search_obj.best_estimator_
    fold_results = evaluate_with_kfold_detailed(X_full, y_full, best_pipeline, name, k=k)
    all_results.extend(fold_results)

# Convert to DataFrame for detailed per-fold view
df_kfold_results = pd.DataFrame(all_results)

# Display the DataFrame (per model, per fold)
import pandas as pd
pd.set_option('display.float_format', lambda x: f'{x:.4f}')
display(df_kfold_results)

# ✅ Summary (mean per model)
summary = df_kfold_results.groupby('Model').agg({
    'MAE': ['mean', 'std'],
    'MSE': ['mean', 'std'],
    'RMSE': ['mean', 'std'],
    'MAPE (%)': ['mean', 'std'],
    'R²': ['mean', 'std']
})
display(summary)
# Out:
#                Model  Fold      MAE        MSE     RMSE  MAPE (%)      R²
# 0       RandomForest     1  29.9082  2086.0515  45.6733    6.9218  0.9038
# 1       RandomForest     2  38.8560  5459.3566  73.8875    6.4614  0.9093
# 2       RandomForest     3  25.2596   884.0062  29.7322    5.4196  0.9717
# 3       RandomForest     4  34.9216  2753.9163  52.4778    6.9531  0.8042
# 4       RandomForest     5  34.1329  1453.8397  38.1293    6.5914  0.7721
# 5       RandomForest     6  17.7002   505.2538  22.4779    4.2858  0.9783
# 6       RandomForest     7  45.6792  4961.0941  70.4350    6.3948  0.8892
# 7       RandomForest     8  37.0237  2039.4177  45.1599    7.2392  0.9448
# 8       RandomForest     9  44.0936  3364.9506  58.0082    7.9558  0.8644
# 9       RandomForest    10  71.9915 11708.0678 108.2038   10.0956  0.8052
# 10      DecisionTree     1  30.0141  2252.0832  47.4561    6.9633  0.8962
# 11      DecisionTree     2  33.1708  3571.6403  59.7632    6.1205  0.9406
# ...

# %% [markdown]
# #### Prediction on Holdout Data

# %%
from sklearn.metrics import r2_score
import numpy as np

# Initialize best model tracking
best_r2 = -np.inf
best_model_name = None
best_pipeline = None

# Loop through predictions to find best R²
for name, data in predictions.items():
    r2 = r2_score(data['y_test'], data['y_pred'])
    if r2 > best_r2:
        best_r2 = r2
        best_model_name = name
        best_pipeline = trained_models[name].best_estimator_  # Store pipeline

# Print best model details
print(f"✅ Best model: {best_model_name} with R² = {best_r2:.4f}")
print("Best hyperparameters:")
print(trained_models[best_model_name].best_params_)
# Out:
# ✅ Best model: Lasso with R² = 0.8976
# Best hyperparameters:
# {'model__alpha': 0.1}

# %%
# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Yield Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Yield Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    
    # Full display
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print(f"\n📌 Predictions for Holdout Material: {selected_material}")
    display(df_results[['Material', target_column, 'Predicted Yield Strength (MPa)', 'Error', 'Absolute Error']])
    
    # Metrics
    mae = np.mean(df_results['Absolute Error'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, R² = {r2_holdout:.4f}")
else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for Holdout Material: Zr-2.5 Nb
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)    Error  Absolute Error
# 0   Zr-2.5 Nb              637.4200                        646.8977  -9.4777          9.4777
# 1   Zr-2.5 Nb              647.1000                        646.8977   0.2023          0.2023
# 2   Zr-2.5 Nb              605.0000                        646.8977 -41.8977         41.8977
# 3   Zr-2.5 Nb              633.3300                        646.8977 -13.5677         13.5677
# 4   Zr-2.5 Nb              601.2500                        654.4696 -53.2196         53.2196
# 5   Zr-2.5 Nb              647.9700                        654.4696  -6.4996          6.4996
# 6   Zr-2.5 Nb              645.0000                        654.4696  -9.4696          9.4696
# 7   Zr-2.5 Nb              633.3300                        654.4696 -21.1396         21.1396
# 8   Zr-2.5 Nb              768.0000                        654.4696 113.5304        113.5304
# ...

# %%
import matplotlib.pyplot as plt

# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Yield Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Yield Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    df_results['APE (%)'] = (df_results['Absolute Error'] / df_results[target_column]) * 100
    
    # Full display (all rows of holdout set)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print("\n📌 Predictions for All Holdout Materials:")
    display(df_results[['Material', target_column, 'Predicted Yield Strength (MPa)', 'Error', 'Absolute Error', 'APE (%)']])
    
    # Overall metrics
    mae = np.mean(df_results['Absolute Error'])
    mape = np.mean(df_results['APE (%)'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Overall Holdout Performance: MAE = {mae:.2f}, MAPE = {mape:.2f}%, R² = {r2_holdout:.4f}")
    
    # === Visualization ===
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Bar chart for MAPE across all holdout samples (with error bars)
    mape_mean = df_results['APE (%)'].mean()
    mape_std = df_results['APE (%)'].std()
    axes[0].bar(['MAPE'], [mape_mean], yerr=[mape_std], capsize=8, color='skyblue')
    axes[0].set_title("Average MAPE Across All Holdout Materials")
    axes[0].set_ylabel("MAPE (%)")
    
    # Boxplot of Errors (all holdout samples)
    axes[1].boxplot(df_results['Error'], vert=True, patch_artist=True)
    axes[1].set_title("Error Distribution Across All Holdout Materials")
    axes[1].set_ylabel("Prediction Error (MPa)")
    
    plt.tight_layout()
    plt.show()

else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for All Holdout Materials:
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)    Error  Absolute Error  APE (%)
# 0   Zr-2.5 Nb              637.4200                        646.8977  -9.4777          9.4777   1.4869
# 1   Zr-2.5 Nb              647.1000                        646.8977   0.2023          0.2023   0.0313
# 2   Zr-2.5 Nb              605.0000                        646.8977 -41.8977         41.8977   6.9252
# 3   Zr-2.5 Nb              633.3300                        646.8977 -13.5677         13.5677   2.1423
# 4   Zr-2.5 Nb              601.2500                        654.4696 -53.2196         53.2196   8.8515
# 5   Zr-2.5 Nb              647.9700                        654.4696  -6.4996          6.4996   1.0031
# 6   Zr-2.5 Nb              645.0000                        654.4696  -9.4696          9.4696   1.4682
# 7   Zr-2.5 Nb              633.3300                        654.4696 -21.1396         21.1396   3.3378
# ...

# %%
import matplotlib.pyplot as plt

# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Yield Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Yield Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    df_results['APE (%)'] = (df_results['Absolute Error'] / df_results[target_column]) * 100
    
    # Full display (all rows of holdout set)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print("\n📌 Predictions for All Holdout Materials:")
    display(df_results[['Material', target_column, 'Predicted Yield Strength (MPa)', 'Error', 'Absolute Error', 'APE (%)']])
    
    # Overall metrics - WITH MAPE STD
    mae = np.mean(df_results['Absolute Error'])
    mape = np.mean(df_results['APE (%)'])
    mape_std = np.std(df_results['APE (%)'])  # ADDED THIS LINE
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Overall Holdout Performance: MAE = {mae:.2f}, MAPE = {mape:.2f}% (± {mape_std:.2f}%), R² = {r2_holdout:.4f}")  # UPDATED
    
    # === Visualization ===
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Bar chart for MAPE across all holdout samples (with error bars)
    mape_mean = df_results['APE (%)'].mean()
    mape_std = df_results['APE (%)'].std()
    axes[0].bar(['MAPE'], [mape_mean], yerr=[mape_std], capsize=8, color='skyblue')
    axes[0].set_title("Average MAPE Across All Holdout Materials")
    axes[0].set_ylabel("MAPE (%)")
    
    # ADDED: Value label with std on the bar chart
    axes[0].text(0, mape_mean + mape_std + 0.5, f"{mape_mean:.1f}% ± {mape_std:.1f}%", 
                ha='center', va='bottom', fontsize=10, fontweight='bold')
    
    # Boxplot of Errors (all holdout samples)
    axes[1].boxplot(df_results['Error'], vert=True, patch_artist=True)
    axes[1].set_title("Error Distribution Across All Holdout Materials")
    axes[1].set_ylabel("Prediction Error (MPa)")
    
    plt.tight_layout()
    plt.show()

else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for All Holdout Materials:
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)    Error  Absolute Error  APE (%)
# 0   Zr-2.5 Nb              637.4200                        646.8977  -9.4777          9.4777   1.4869
# 1   Zr-2.5 Nb              647.1000                        646.8977   0.2023          0.2023   0.0313
# 2   Zr-2.5 Nb              605.0000                        646.8977 -41.8977         41.8977   6.9252
# 3   Zr-2.5 Nb              633.3300                        646.8977 -13.5677         13.5677   2.1423
# 4   Zr-2.5 Nb              601.2500                        654.4696 -53.2196         53.2196   8.8515
# 5   Zr-2.5 Nb              647.9700                        654.4696  -6.4996          6.4996   1.0031
# 6   Zr-2.5 Nb              645.0000                        654.4696  -9.4696          9.4696   1.4682
# 7   Zr-2.5 Nb              633.3300                        654.4696 -21.1396         21.1396   3.3378
# ...

# %%
import matplotlib.pyplot as plt

# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Yield Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Yield Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    df_results['APE (%)'] = (df_results['Absolute Error'] / df_results[target_column]) * 100  # percentage error
    
    # Full display
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print(f"\n📌 Predictions for Holdout Material: {selected_material}")
    display(df_results[['Material', target_column, 'Predicted Yield Strength (MPa)', 'Error', 'Absolute Error', 'APE (%)']])
    
    # Metrics
    mae = np.mean(df_results['Absolute Error'])
    mape = np.mean(df_results['APE (%)'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, MAPE = {mape:.2f}%, R² = {r2_holdout:.4f}")
    

    # === Visualization with error bars ===
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Bar chart for average MAPE with error bars
    mape_mean = df_results['APE (%)'].mean()
    mape_std = df_results['APE (%)'].std()  # variability
    axes[0].bar(['MAPE'], [mape_mean], yerr=[mape_std], capsize=8)
    axes[0].set_title(f"Average MAPE for {selected_material}")
    axes[0].set_ylabel("MAPE (%)")

    # Boxplot of Errors
    axes[1].boxplot(df_results['Error'], vert=True, patch_artist=True)
    axes[1].set_title(f"Error Distribution for {selected_material}")
    axes[1].set_ylabel("Prediction Error (MPa)")

    plt.tight_layout()
    plt.show()

    
else:
    print("❌ Holdout dataset or best model is not available.")

print(df_results[['Material', target_column, 
                  'Predicted Yield Strength (MPa)', 
                  'Error', 
                  'Absolute Error', 
                  'APE (%)']].to_string(index=False))
# Out:
# 📌 Predictions for Holdout Material: Zr-2.5 Nb
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)    Error  Absolute Error  APE (%)
# 0   Zr-2.5 Nb              637.4200                        646.8977  -9.4777          9.4777   1.4869
# 1   Zr-2.5 Nb              647.1000                        646.8977   0.2023          0.2023   0.0313
# 2   Zr-2.5 Nb              605.0000                        646.8977 -41.8977         41.8977   6.9252
# 3   Zr-2.5 Nb              633.3300                        646.8977 -13.5677         13.5677   2.1423
# 4   Zr-2.5 Nb              601.2500                        654.4696 -53.2196         53.2196   8.8515
# 5   Zr-2.5 Nb              647.9700                        654.4696  -6.4996          6.4996   1.0031
# 6   Zr-2.5 Nb              645.0000                        654.4696  -9.4696          9.4696   1.4682
# 7   Zr-2.5 Nb              633.3300                        654.4696 -21.1396         21.1396   3.3378
# ...

# %%
import matplotlib.pyplot as plt
from IPython.display import HTML

# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Yield Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Yield Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    df_results['APE (%)'] = (df_results['Absolute Error'] / df_results[target_column]) * 100  # percentage error
    
    # Full display (text mode, no scrolling)
    print(f"\n📌 Predictions for Holdout Material: {selected_material}")
    print(df_results[['Material', target_column, 
                      'Predicted Yield Strength (MPa)', 
                      'Error', 
                      'Absolute Error', 
                      'APE (%)']].to_string(index=False))
    
    # Metrics
    mae = np.mean(df_results['Absolute Error'])
    mape = np.mean(df_results['APE (%)'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, MAPE = {mape:.2f}%, R² = {r2_holdout:.4f}")
    

    # === Visualization with error bars ===
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Bar chart for average MAPE with error bars
    mape_mean = df_results['APE (%)'].mean()
    mape_std = df_results['APE (%)'].std()  # variability
    axes[0].bar(['MAPE'], [mape_mean], yerr=[mape_std], capsize=8, color="skyblue")
    axes[0].set_title(f"Average MAPE for {selected_material}")
    axes[0].set_ylabel("MAPE (%)")

    # Boxplot of Errors
    axes[1].boxplot(df_results['Error'], vert=True, patch_artist=True)
    axes[1].set_title(f"Error Distribution for {selected_material}")
    axes[1].set_ylabel("Prediction Error (MPa)")

    plt.tight_layout()
    plt.show()

else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for Holdout Material: Zr-2.5 Nb
#  Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)    Error  Absolute Error  APE (%)
# Zr-2.5 Nb              637.4200                        646.8977  -9.4777          9.4777   1.4869
# Zr-2.5 Nb              647.1000                        646.8977   0.2023          0.2023   0.0313
# Zr-2.5 Nb              605.0000                        646.8977 -41.8977         41.8977   6.9252
# Zr-2.5 Nb              633.3300                        646.8977 -13.5677         13.5677   2.1423
# Zr-2.5 Nb              601.2500                        654.4696 -53.2196         53.2196   8.8515
# Zr-2.5 Nb              647.9700                        654.4696  -6.4996          6.4996   1.0031
# Zr-2.5 Nb              645.0000                        654.4696  -9.4696          9.4696   1.4682
# Zr-2.5 Nb              633.3300                        654.4696 -21.1396         21.1396   3.3378
# ...

# %%
import matplotlib.pyplot as plt

# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Yield Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Yield Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    df_results['APE (%)'] = (df_results['Absolute Error'] / df_results[target_column]) * 100  # percentage error
    
    # Full display
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print(f"\n📌 Predictions for Holdout Material: {selected_material}")
    display(df_results[['Material', target_column, 'Predicted Yield Strength (MPa)', 'Error', 'Absolute Error', 'APE (%)']])
    
    # Metrics - ADDED MAPE STD HERE
    mae = np.mean(df_results['Absolute Error'])
    mape = np.mean(df_results['APE (%)'])
    mape_std = np.std(df_results['APE (%)'])  # ADDED THIS LINE
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    
    # Updated print statement with MAPE std
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, MAPE = {mape:.2f}% (± {mape_std:.2f}%), R² = {r2_holdout:.4f}")
    

    # === Visualization with error bars ===
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Bar chart for average MAPE with error bars
    mape_mean = df_results['APE (%)'].mean()
    mape_std = df_results['APE (%)'].std()  # variability
    axes[0].bar(['MAPE'], [mape_mean], yerr=[mape_std], capsize=8)
    axes[0].set_title(f"Average MAPE for {selected_material}")
    axes[0].set_ylabel("MAPE (%)")
    
    # ADDED: Value label with std on the bar chart
    axes[0].text(0, mape_mean + mape_std + 0.5, f"{mape_mean:.1f}% ± {mape_std:.1f}%", 
                ha='center', va='bottom', fontsize=10, fontweight='bold')

    # Boxplot of Errors
    axes[1].boxplot(df_results['Error'], vert=True, patch_artist=True)
    axes[1].set_title(f"Error Distribution for {selected_material}")
    axes[1].set_ylabel("Prediction Error (MPa)")

    plt.tight_layout()
    plt.show()

    
else:
    print("❌ Holdout dataset or best model is not available.")

print(df_results[['Material', target_column, 
                  'Predicted Yield Strength (MPa)', 
                  'Error', 
                  'Absolute Error', 
                  'APE (%)']].to_string(index=False))
# Out:
# 📌 Predictions for Holdout Material: Zr-2.5 Nb
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)    Error  Absolute Error  APE (%)
# 0   Zr-2.5 Nb              637.4200                        646.8977  -9.4777          9.4777   1.4869
# 1   Zr-2.5 Nb              647.1000                        646.8977   0.2023          0.2023   0.0313
# 2   Zr-2.5 Nb              605.0000                        646.8977 -41.8977         41.8977   6.9252
# 3   Zr-2.5 Nb              633.3300                        646.8977 -13.5677         13.5677   2.1423
# 4   Zr-2.5 Nb              601.2500                        654.4696 -53.2196         53.2196   8.8515
# 5   Zr-2.5 Nb              647.9700                        654.4696  -6.4996          6.4996   1.0031
# 6   Zr-2.5 Nb              645.0000                        654.4696  -9.4696          9.4696   1.4682
# 7   Zr-2.5 Nb              633.3300                        654.4696 -21.1396         21.1396   3.3378
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
df = pd.read_excel("01-HY5-YS-MAPE.xlsx")

plt.figure(figsize=(14, 8))

# Define positions for the bars
x = np.arange(len(df))  # X positions for each material
bar_width = 0.18  # Increased width for thicker bars

# Define colors for H5 series
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Create bars for each H5 variant (S1-S4) - all on holdout
# H5-S1
plt.bar(x - 1.5*bar_width,
        df['YS MAPE on holdout (H5-S1)'],
        yerr=df['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=7,
        label='H5-S1',
        color=colors[0],
        edgecolor='black',
        linewidth=0.8,
        alpha=0.9)

# H5-S2
plt.bar(x - 0.5*bar_width,
        df['YS MAPE on holdout (H5-S2)'],
        yerr=df['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=7,
        label='H5-S2',
        color=colors[1],
        edgecolor='black',
        linewidth=0.8,
        alpha=0.9)

# H5-S3
plt.bar(x + 0.5*bar_width,
        df['YS MAPE on holdout (H5-S3)'],
        yerr=df['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=7,
        label='H5-S3',
        color=colors[2],
        edgecolor='black',
        linewidth=0.8,
        alpha=0.9)

# H5-S4
plt.bar(x + 1.5*bar_width,
        df['YS MAPE on holdout (H5-S4)'],
        yerr=df['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=7,
        label='H5-S4',
        color=colors[3],
        edgecolor='black',
        linewidth=0.8,
        alpha=0.9)

# X-axis labels
plt.xticks(x, df['Material'], rotation=45, ha='right', fontsize=11)
plt.ylabel("YS MAPE (%)", fontsize=12, fontweight='bold')
plt.title("Yield Strength (YS) MAPE Comparison for H5 Variants (S1-S4) on Holdout", 
          fontsize=14, fontweight='bold', pad=20)
plt.legend(fontsize=11, title='H5 Variants', title_fontsize=12)
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add value labels on top of bars (optional)
for i in range(len(df)):
    for j, col in enumerate(['YS MAPE on holdout (H5-S1)', 
                            'YS MAPE on holdout (H5-S2)',
                            'YS MAPE on holdout (H5-S3)',
                            'YS MAPE on holdout (H5-S4)']):
        value = df.loc[i, col]
        std = df.loc[i, f'STD on holdout (H5-S{j+1})']
        # Position adjustment based on bar position
        x_pos = x[i] + (j - 1.5) * bar_width
        plt.text(x_pos, value + std + 0.5, f'{value:.1f}', 
                ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YS MAPE on holdout (H5-S3)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[482], line 44
#      31 plt.bar(x - 0.5*bar_width,
# ...

# %%
# OPTION 2: Horizontal bars (good for many materials)
fig, ax = plt.subplots(figsize=(12, 10))

# Use fewer bars per group for cleaner look
bar_height = 0.2
y_pos = np.arange(len(df))

# Create horizontal bars
bars_s1 = ax.barh(y_pos - 1.5*bar_height, df['YS MAPE on holdout (H5-S1)'],
                  xerr=df['STD on holdout (H5-S1)'],
                  height=bar_height, capsize=5,
                  label='H5-S1', color='#1f77b4', edgecolor='black')

bars_s2 = ax.barh(y_pos - 0.5*bar_height, df['YS MAPE on holdout (H5-S2)'],
                  xerr=df['STD on holdout (H5-S2)'],
                  height=bar_height, capsize=5,
                  label='H5-S2', color='#ff7f0e', edgecolor='black')

bars_s3 = ax.barh(y_pos + 0.5*bar_height, df['YS MAPE on holdout (H5-S3)'],
                  xerr=df['STD on holdout (H5-S3)'],
                  height=bar_height, capsize=5,
                  label='H5-S3', color='#2ca02c', edgecolor='black')

bars_s4 = ax.barh(y_pos + 1.5*bar_height, df['YS MAPE on holdout (H5-S4)'],
                  xerr=df['STD on holdout (H5-S4)'],
                  height=bar_height, capsize=5,
                  label='H5-S4', color='#d62728', edgecolor='black')

# Set y-axis labels
ax.set_yticks(y_pos)
ax.set_yticklabels(df['Material'], fontsize=11)
ax.set_xlabel("YS MAPE (%)", fontsize=12, fontweight='bold')
ax.set_title("YS MAPE Comparison for H5 Variants - Horizontal View", 
             fontsize=14, fontweight='bold', pad=20)
ax.legend(fontsize=11, title='H5 Variants', title_fontsize=12)
ax.grid(axis='x', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
x# OPTION 3: One material at a time for maximum bar thickness
for i, material in enumerate(df['Material']):
    fig, ax = plt.subplots(figsize=(10, 7))
    
    # Get data for this specific material
    row = df.iloc[i]
    
    categories = ['H5-S1', 'H5-S2', 'H5-S3', 'H5-S4']
    values = [
        row['YS MAPE on holdout (H5-S1)'],
        row['YS MAPE on holdout (H5-S2)'],
        row['YS MAPE on holdout (H5-S3)'],
        row['YS MAPE on holdout (H5-S4)']
    ]
    errors = [
        row['STD on holdout (H5-S1)'],
        row['STD on holdout (H5-S2)'],
        row['STD on holdout (H5-S3)'],
        row['STD on holdout (H5-S4)']
    ]
    
    # Create single bar chart for this material
    x_pos = np.arange(len(categories))
    bars = ax.bar(x_pos, values, yerr=errors, capsize=10, 
                  width=0.7, color=colors, edgecolor='black', 
                  linewidth=1.2, alpha=0.9)
    
    ax.set_xticks(x_pos)
    ax.set_xticklabels(categories, fontsize=12, fontweight='bold')
    ax.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
    ax.set_title(f"YS MAPE for {material} - H5 Variants Comparison", 
                 fontsize=15, fontweight='bold', pad=15)
    ax.grid(axis='y', alpha=0.3)
    
    # Add value labels on top of bars
    for j, (v, e) in enumerate(zip(values, errors)):
        ax.text(j, v + e + 0.2, f'{v:.2f} ± {e:.2f}', 
                ha='center', va='bottom', fontsize=11,
                bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    plt.show()
    break  # Remove this to show all materials
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YS MAPE on holdout (H5-S3)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[483], line 12
#       6 row = df.iloc[i]
# ...

# %%
# OPTION 4: Compare two variants at a time
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

combinations = [
    ('H5-S1', 'H5-S2'),
    ('H5-S3', 'H5-S4'),
    ('H5-S1', 'H5-S3'),
    ('H5-S2', 'H5-S4')
]

for idx, (var1, var2) in enumerate(combinations):
    ax = axes[idx]
    bar_width = 0.35
    x = np.arange(len(df))
    
    # Bars for first variant
    ax.bar(x - bar_width/2, df[f'YS MAPE on holdout ({var1})'],
           yerr=df[f'STD on holdout ({var1})'],
           width=bar_width, capsize=6, label=var1,
           color=colors[idx % 2], edgecolor='black', alpha=0.8)
    
    # Bars for second variant
    ax.bar(x + bar_width/2, df[f'YS MAPE on holdout ({var2})'],
           yerr=df[f'STD on holdout ({var2})'],
           width=bar_width, capsize=6, label=var2,
           color=colors[idx % 2 + 2], edgecolor='black', alpha=0.8)
    
    ax.set_xticks(x)
    ax.set_xticklabels(df['Material'], rotation=45, ha='right', fontsize=9)
    ax.set_ylabel("YS MAPE (%)")
    ax.set_title(f"{var1} vs {var2} Comparison")
    ax.legend()
    ax.grid(axis='y', alpha=0.3)

plt.suptitle("Pairwise Comparison of H5 Variants", fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# OPTION 3: One material at a time for maximum bar thickness
# Define colors here for Option 3
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Blue, Orange, Green, Red

for i, material in enumerate(df['Material']):
    fig, ax = plt.subplots(figsize=(10, 7))
    
    # Get data for this specific material
    row = df.iloc[i]
    
    categories = ['H5-S1', 'H5-S2', 'H5-S3', 'H5-S4']
    values = [
        row['YS MAPE on holdout (H5-S1)'],
        row['YS MAPE on holdout (H5-S2)'],
        row['YS MAPE on holdout (H5-S3)'],
        row['YS MAPE on holdout (H5-S4)']
    ]
    errors = [
        row['STD on holdout (H5-S1)'],
        row['STD on holdout (H5-S2)'],
        row['STD on holdout (H5-S3)'],
        row['STD on holdout (H5-S4)']
    ]
    
    # Create single bar chart for this material
    x_pos = np.arange(len(categories))
    bars = ax.bar(x_pos, values, yerr=errors, capsize=10, 
                  width=0.7, color=colors, edgecolor='black', 
                  linewidth=1.2, alpha=0.9)
    
    ax.set_xticks(x_pos)
    ax.set_xticklabels(categories, fontsize=12, fontweight='bold')
    ax.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
    ax.set_title(f"YS MAPE for {material} - H5 Variants Comparison", 
                 fontsize=15, fontweight='bold', pad=15)
    ax.grid(axis='y', alpha=0.3)
    
    # Add value labels on top of bars
    for j, (v, e) in enumerate(zip(values, errors)):
        ax.text(j, v + e + 0.2, f'{v:.2f} ± {e:.2f}', 
                ha='center', va='bottom', fontsize=11,
                bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))
    
    # Set y-axis limit to ensure all bars are visible
    max_value = max([v + e for v, e in zip(values, errors)])
    ax.set_ylim(0, max_value * 1.15)  # Add 15% padding at top
    
    plt.tight_layout()
    plt.show()
    # Remove the break statement to show all materials
    # break  # Remove this to show all materials
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1791], line 46
#      44 # Set y-axis limit to ensure all bars are visible
#      45 max_value = max([v + e for v, e in zip(values, errors)])
# ---> 46 ax.set_ylim(0, max_value * 1.15)  # Add 15% padding at top
#      48 plt.tight_layout()
#      49 plt.show()
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_base.py:4017, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    4015         raise TypeError("Cannot pass both 'top' and 'ymax'")
#    4016     top = ymax
# -> 4017 return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axis.py:1228, in Axis._set_lim(self, v0, v1, emit, auto)
#    1226 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
df = pd.read_excel("01-HY5-YS-MAPE.xlsx")

plt.figure(figsize=(12, 7))

# Define positions for the bars - only 2 bars per material
x = np.arange(len(df))  # X positions for each material
bar_width = 0.35  # Thick bars since we only have 2

# Colors for S3 and S4
colors = ['#2ca02c', '#d62728']  # Green for S3, Red for S4

# H5-S3 bars
plt.bar(x - bar_width/2,
        df['YS MAPE on holdout (H5-S3)'],
        yerr=df['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=colors[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars
plt.bar(x + bar_width/2,
        df['YS MAPE on holdout (H5-S4)'],
        yerr=df['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=colors[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
plt.xticks(x, df['Material'], rotation=45, ha='right', fontsize=11)
plt.ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
plt.title("Yield Strength (YS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout", 
          fontsize=15, fontweight='bold', pad=20)
plt.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
plt.grid(axis='y', alpha=0.3, linestyle='--')

# Add value labels on top of bars
for i in range(len(df)):
    # S3 value
    s3_value = df.loc[i, 'YS MAPE on holdout (H5-S3)']
    s3_std = df.loc[i, 'STD on holdout (H5-S3)']
    plt.text(x[i] - bar_width/2, s3_value + s3_std + 0.3, 
             f'{s3_value:.2f}±{s3_std:.2f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))
    
    # S4 value
    s4_value = df.loc[i, 'YS MAPE on holdout (H5-S4)']
    s4_std = df.loc[i, 'STD on holdout (H5-S4)']
    plt.text(x[i] + bar_width/2, s4_value + s4_std + 0.3, 
             f'{s4_value:.2f}±{s4_std:.2f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: S1 vs S2 from 01-HY5-YS-MAPE.xlsx
# ============================================================================
print("=== CHART 1: H5-S1 vs H5-S2 ===")

# Load first file
df1 = pd.read_excel("01-HY5-YS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Colors for S1 and S2
colors1 = ['#1f77b4', '#ff7f0e']  # Blue for S1, Orange for S2

# H5-S1 bars
ax1.bar(x1 - bar_width/2,
        df1['YS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=8,
        label='H5-S1',
        color=colors1[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S2 bars
ax1.bar(x1 + bar_width/2,
        df1['YS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=8,
        label='H5-S2',
        color=colors1[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=11)
ax1.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
ax1.set_title("Yield Strength (YS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

# Add value labels on top of bars
for i in range(len(df1)):
    # S1 value
    s1_value = df1.loc[i, 'YS MAPE on holdout (H5-S1)']
    s1_std = df1.loc[i, 'STD on holdout (H5-S1)']
    ax1.text(x1[i] - bar_width/2, s1_value + s1_std + 0.3, 
             f'{s1_value:.2f}±{s1_std:.2f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))
    
    # S2 value
    s2_value = df1.loc[i, 'YS MAPE on holdout (H5-S2)']
    s2_std = df1.loc[i, 'STD on holdout (H5-S2)']
    ax1.text(x1[i] + bar_width/2, s2_value + s2_std + 0.3, 
             f'{s2_value:.2f}±{s2_std:.2f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: S3 vs S4 from 02-HY5-YS-MAPE.xlsx
# ============================================================================
print("\n=== CHART 2: H5-S3 vs H5-S4 ===")

# Load second file
df2 = pd.read_excel("02-HY5-YS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x2 = np.arange(len(df2))

# Colors for S3 and S4
colors2 = ['#2ca02c', '#d62728']  # Green for S3, Red for S4

# H5-S3 bars
ax2.bar(x2 - bar_width/2,
        df2['YS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=colors2[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars
ax2.bar(x2 + bar_width/2,
        df2['YS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=colors2[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=11)
ax2.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
ax2.set_title("Yield Strength (YS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

# Add value labels on top of bars
for i in range(len(df2)):
    # S3 value
    s3_value = df2.loc[i, 'YS MAPE on holdout (H5-S3)']
    s3_std = df2.loc[i, 'STD on holdout (H5-S3)']
    ax2.text(x2[i] - bar_width/2, s3_value + s3_std + 0.3, 
             f'{s3_value:.2f}±{s3_std:.2f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))
    
    # S4 value
    s4_value = df2.loc[i, 'YS MAPE on holdout (H5-S4)']
    s4_std = df2.loc[i, 'STD on holdout (H5-S4)']
    ax2.text(x2[i] + bar_width/2, s4_value + s4_std + 0.3, 
             f'{s4_value:.2f}±{s4_std:.2f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()
# Out:
# === CHART 1: H5-S1 vs H5-S2 ===
# === CHART 2: H5-S3 vs H5-S4 ===

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: S1 vs S2 from 01-HY5-YS-MAPE.xlsx
# ============================================================================

# Load first file
df1 = pd.read_excel("01-HY5-YS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Colors for S1 and S2
colors1 = ['#1f77b4', '#ff7f0e']  # Blue for S1, Orange for S2

# H5-S1 bars
ax1.bar(x1 - bar_width/2,
        df1['YS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=8,
        label='H5-S1',
        color=colors1[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S2 bars
ax1.bar(x1 + bar_width/2,
        df1['YS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=8,
        label='H5-S2',
        color=colors1[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=14)
ax1.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
ax1.set_title("Yield Strength (YS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: S3 vs S4 from 02-HY5-YS-MAPE.xlsx
# ============================================================================

# Load second file
df2 = pd.read_excel("02-HY5-YS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x2 = np.arange(len(df2))

# Colors for S3 and S4
colors2 = ['#2ca02c', '#d62728']  # Green for S3, Red for S4

# H5-S3 bars
ax2.bar(x2 - bar_width/2,
        df2['YS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=colors2[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars
ax2.bar(x2 + bar_width/2,
        df2['YS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=colors2[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=14)
ax2.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
ax2.set_title("Yield Strength (YS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: S1 vs S2 from 01-HY5-YS-MAPE.xlsx
# ============================================================================

# Load first file
df1 = pd.read_excel("01-HY5-YS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Consistent colors for all H5 variants
# Using matplotlib's default color cycle for consistency
colors = plt.cm.tab10(np.arange(4))  # Get 4 colors from tab10 colormap
# Or define specific consistent colors:
consistent_colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Blue, Orange, Green, Red

# H5-S1 bars (Blue)
ax1.bar(x1 - bar_width/2,
        df1['YS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=8,
        label='H5-S1',
        color=consistent_colors[0],  # Blue for S1
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S2 bars (Orange)
ax1.bar(x1 + bar_width/2,
        df1['YS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=8,
        label='H5-S2',
        color=consistent_colors[1],  # Orange for S2
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=14)
ax1.set_ylabel("YS MAPE (%)", fontsize=14)
ax1.set_title("Yield Strength (YS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: S3 vs S4 from 02-HY5-YS-MAPE.xlsx
# ============================================================================

# Load second file
df2 = pd.read_excel("02-HY5-YS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x2 = np.arange(len(df2))

# H5-S3 bars (Green) - using same color array
ax2.bar(x2 - bar_width/2,
        df2['YS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=consistent_colors[2],  # Green for S3 (index 2)
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars (Red) - using same color array
ax2.bar(x2 + bar_width/2,
        df2['YS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=consistent_colors[3],  # Red for S4 (index 3)
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=14)
ax2.set_ylabel("YS MAPE (%)", fontsize=14)
ax2.set_title("Yield Strength (YS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: S1 vs S2 from 01-HY5-YS-MAPE.xlsx
# ============================================================================

# Load first file
df1 = pd.read_excel("01-HY5-YS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Colors for S1 and S2 (Blue and Orange)
colors = ['#1f77b4', '#ff7f0e']  # Blue for S1, Orange for S2

# H5-S1 bars
ax1.bar(x1 - bar_width/2,
        df1['YS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=8,
        label='H5-S1',
        color=colors[0],  # Blue
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S2 bars
ax1.bar(x1 + bar_width/2,
        df1['YS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=8,
        label='H5-S2',
        color=colors[1],  # Orange
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=11)
ax1.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
ax1.set_title("Yield Strength (YS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: S3 vs S4 from 02-HY5-YS-MAPE.xlsx
# ============================================================================

# Load second file
df2 = pd.read_excel("02-HY5-YS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x2 = np.arange(len(df2))

# USING THE SAME BLUE AND ORANGE COLORS FOR S3 AND S4 TOO
# H5-S3 bars (now Blue - same as S1)
ax2.bar(x2 - bar_width/2,
        df2['YS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=colors[0],  # Same Blue as S1
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars (now Orange - same as S2)
ax2.bar(x2 + bar_width/2,
        df2['YS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=colors[1],  # Same Orange as S2
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=11)
ax2.set_ylabel("YS MAPE (%)", fontsize=13, fontweight='bold')
ax2.set_title("Yield Strength (YS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-YS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: UTS S1 vs S2 from 01-HY5-UTS-MAPE.xlsx
# ============================================================================

# Load first file
df1 = pd.read_excel("01-HY5-UTS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Colors for S1 and S2 (Blue and Orange)
colors = ['#1f77b4', '#ff7f0e']  # Blue for S1, Orange for S2

# H5-S1 bars
ax1.bar(x1 - bar_width/2,
        df1['UTS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=8,
        label='H5-S1',
        color=colors[0],  # Blue
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S2 bars
ax1.bar(x1 + bar_width/2,
        df1['UTS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=8,
        label='H5-S2',
        color=colors[1],  # Orange
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=14)
ax1.set_ylabel("UTS MAPE (%)", fontsize=14)
ax1.set_title("Ultimate Tensile Strength (UTS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-UTS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: UTS S3 vs S4 from 02-HY5-UTS-MAPE.xlsx
# ============================================================================

# Load second file
df2 = pd.read_excel("02-HY5-UTS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x2 = np.arange(len(df2))

# USING THE SAME BLUE AND ORANGE COLORS FOR S3 AND S4 TOO
# H5-S3 bars (now Blue - same as S1)
ax2.bar(x2 - bar_width/2,
        df2['UTS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=colors[0],  # Same Blue as S1
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars (now Orange - same as S2)
ax2.bar(x2 + bar_width/2,
        df2['UTS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=colors[1],  # Same Orange as S2
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=14)
ax2.set_ylabel("UTS MAPE (%)", fontsize=14)
ax2.set_title("Ultimate Tensile Strength (UTS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-UTS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: UTS S1 vs S2 from 01-HY5-UTS-MAPE.xlsx
# ============================================================================

# Load first file
df1 = pd.read_excel("01-HY5-UTS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Colors for S1 and S2
colors1 = ['#1f77b4', '#ff7f0e']  # Blue for S1, Orange for S2

# H5-S1 bars
ax1.bar(x1 - bar_width/2,
        df1['UTS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width,
        capsize=8,
        label='H5-S1',
        color=colors1[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S2 bars
ax1.bar(x1 + bar_width/2,
        df1['UTS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width,
        capsize=8,
        label='H5-S2',
        color=colors1[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=14)
ax1.set_ylabel("UTS MAPE (%)", fontsize=14)
ax1.set_title("Ultimate Tensile Strength (UTS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-UTS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: UTS S3 vs S4 from 02-HY5-UTS-MAPE.xlsx
# ============================================================================

# Load second file
df2 = pd.read_excel("02-HY5-UTS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(12, 7))

# Define positions for the bars
x2 = np.arange(len(df2))

# Colors for S3 and S4
colors2 = ['#2ca02c', '#d62728']  # Green for S3, Red for S4

# H5-S3 bars
ax2.bar(x2 - bar_width/2,
        df2['UTS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width,
        capsize=8,
        label='H5-S3',
        color=colors2[0],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# H5-S4 bars
ax2.bar(x2 + bar_width/2,
        df2['UTS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width,
        capsize=8,
        label='H5-S4',
        color=colors2[1],
        edgecolor='black',
        linewidth=1.2,
        alpha=0.9)

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=14)
ax2.set_ylabel("UTS MAPE (%)", fontsize=14)
ax2.set_title("Ultimate Tensile Strength (UTS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-UTS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=14)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
# ALTERNATIVE: Show both UTS charts side by side in one figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Common settings
bar_width = 0.35

# ===== CHART 1: UTS S1 vs S2 =====
x1 = np.arange(len(df1))

# H5-S1 bars
ax1.bar(x1 - bar_width/2, df1['UTS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width, capsize=7, label='H5-S1',
        color='#1f77b4', edgecolor='black', alpha=0.9)

# H5-S2 bars
ax1.bar(x1 + bar_width/2, df1['UTS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width, capsize=7, label='H5-S2',
        color='#ff7f0e', edgecolor='black', alpha=0.9)

ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=10)
ax1.set_ylabel("UTS MAPE (%)", fontsize=12, fontweight='bold')
ax1.set_title("UTS: H5-S1 vs H5-S2\n(File: 01-HY5-UTS-MAPE)", fontsize=13, fontweight='bold')
ax1.legend(fontsize=11)
ax1.grid(axis='y', alpha=0.3)

# ===== CHART 2: UTS S3 vs S4 =====
x2 = np.arange(len(df2))

# H5-S3 bars
ax2.bar(x2 - bar_width/2, df2['UTS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width, capsize=7, label='H5-S3',
        color='#2ca02c', edgecolor='black', alpha=0.9)

# H5-S4 bars
ax2.bar(x2 + bar_width/2, df2['UTS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width, capsize=7, label='H5-S4',
        color='#d62728', edgecolor='black', alpha=0.9)

ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=10)
ax2.set_ylabel("UTS MAPE (%)", fontsize=12, fontweight='bold')
ax2.set_title("UTS: H5-S3 vs H5-S4\n(File: 02-HY5-UTS-MAPE)", fontsize=13, fontweight='bold')
ax2.legend(fontsize=11)
ax2.grid(axis='y', alpha=0.3)

# Main title for the entire figure
plt.suptitle("Ultimate Tensile Strength (UTS) MAPE Comparison Across H5 Variants", 
             fontsize=16, fontweight='bold', y=1.02)

plt.tight_layout()
plt.show()

# %%
# BONUS: All 4 charts in one figure (YS and UTS)
fig, axes = plt.subplots(2, 2, figsize=(22, 14))
bar_width = 0.35

# Load YS data again for comparison
ys_df1 = pd.read_excel("01-HY5-YS-MAPE.xlsx")
ys_df2 = pd.read_excel("02-HY5-YS-MAPE.xlsx")

# Chart 1: YS S1 vs S2
ax1 = axes[0, 0]
x1 = np.arange(len(ys_df1))
ax1.bar(x1 - bar_width/2, ys_df1['YS MAPE on holdout (H5-S1)'],
        yerr=ys_df1['STD on holdout (H5-S1)'],
        width=bar_width, capsize=6, label='H5-S1',
        color='#1f77b4', edgecolor='black', alpha=0.9)
ax1.bar(x1 + bar_width/2, ys_df1['YS MAPE on holdout (H5-S2)'],
        yerr=ys_df1['STD on holdout (H5-S2)'],
        width=bar_width, capsize=6, label='H5-S2',
        color='#ff7f0e', edgecolor='black', alpha=0.9)
ax1.set_xticks(x1)
ax1.set_xticklabels(ys_df1['Material'], rotation=45, ha='right', fontsize=9)
ax1.set_ylabel("YS MAPE (%)", fontsize=11, fontweight='bold')
ax1.set_title("Yield Strength: H5-S1 vs H5-S2", fontsize=12, fontweight='bold')
ax1.legend(fontsize=10)
ax1.grid(axis='y', alpha=0.3)

# Chart 2: YS S3 vs S4
ax2 = axes[0, 1]
x2 = np.arange(len(ys_df2))
ax2.bar(x2 - bar_width/2, ys_df2['YS MAPE on holdout (H5-S3)'],
        yerr=ys_df2['STD on holdout (H5-S3)'],
        width=bar_width, capsize=6, label='H5-S3',
        color='#2ca02c', edgecolor='black', alpha=0.9)
ax2.bar(x2 + bar_width/2, ys_df2['YS MAPE on holdout (H5-S4)'],
        yerr=ys_df2['STD on holdout (H5-S4)'],
        width=bar_width, capsize=6, label='H5-S4',
        color='#d62728', edgecolor='black', alpha=0.9)
ax2.set_xticks(x2)
ax2.set_xticklabels(ys_df2['Material'], rotation=45, ha='right', fontsize=9)
ax2.set_ylabel("YS MAPE (%)", fontsize=11, fontweight='bold')
ax2.set_title("Yield Strength: H5-S3 vs H5-S4", fontsize=12, fontweight='bold')
ax2.legend(fontsize=10)
ax2.grid(axis='y', alpha=0.3)

# Chart 3: UTS S1 vs S2
ax3 = axes[1, 0]
x3 = np.arange(len(df1))
ax3.bar(x3 - bar_width/2, df1['UTS MAPE on holdout (H5-S1)'],
        yerr=df1['STD on holdout (H5-S1)'],
        width=bar_width, capsize=6, label='H5-S1',
        color='#1f77b4', edgecolor='black', alpha=0.9)
ax3.bar(x3 + bar_width/2, df1['UTS MAPE on holdout (H5-S2)'],
        yerr=df1['STD on holdout (H5-S2)'],
        width=bar_width, capsize=6, label='H5-S2',
        color='#ff7f0e', edgecolor='black', alpha=0.9)
ax3.set_xticks(x3)
ax3.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=9)
ax3.set_ylabel("UTS MAPE (%)", fontsize=11, fontweight='bold')
ax3.set_title("Ultimate Tensile Strength: H5-S1 vs H5-S2", fontsize=12, fontweight='bold')
ax3.legend(fontsize=10)
ax3.grid(axis='y', alpha=0.3)

# Chart 4: UTS S3 vs S4
ax4 = axes[1, 1]
x4 = np.arange(len(df2))
ax4.bar(x4 - bar_width/2, df2['UTS MAPE on holdout (H5-S3)'],
        yerr=df2['STD on holdout (H5-S3)'],
        width=bar_width, capsize=6, label='H5-S3',
        color='#2ca02c', edgecolor='black', alpha=0.9)
ax4.bar(x4 + bar_width/2, df2['UTS MAPE on holdout (H5-S4)'],
        yerr=df2['STD on holdout (H5-S4)'],
        width=bar_width, capsize=6, label='H5-S4',
        color='#d62728', edgecolor='black', alpha=0.9)
ax4.set_xticks(x4)
ax4.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=9)
ax4.set_ylabel("UTS MAPE (%)", fontsize=11, fontweight='bold')
ax4.set_title("Ultimate Tensile Strength: H5-S3 vs H5-S4", fontsize=12, fontweight='bold')
ax4.legend(fontsize=10)
ax4.grid(axis='y', alpha=0.3)

plt.suptitle("Yield Strength (YS) and Ultimate Tensile Strength (UTS) MAPE Comparison", 
             fontsize=18, fontweight='bold', y=1.02)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ============================================================================
# CHART 1: UTS S1 vs S2 from 01-HY5-UTS-MAPE.xlsx
# ============================================================================

# Load first file
df1 = pd.read_excel("01-HY5-UTS-MAPE.xlsx")

# Create Chart 1
fig1, ax1 = plt.subplots(figsize=(14, 8))

# Define positions for the bars
x1 = np.arange(len(df1))
bar_width = 0.35  # Thick bars for 2-series comparison

# Colors for S1 and S2
colors1 = ['#1f77b4', '#ff7f0e']  # Blue for S1, Orange for S2

# H5-S1 bars
bars_s1 = ax1.bar(x1 - bar_width/2,
                  df1['UTS MAPE on holdout (H5-S1)'],
                  yerr=df1['STD on holdout (H5-S1)'],
                  width=bar_width,
                  capsize=8,
                  label='H5-S1',
                  color=colors1[0],
                  edgecolor='black',
                  linewidth=1.2,
                  alpha=0.9)

# H5-S2 bars
bars_s2 = ax1.bar(x1 + bar_width/2,
                  df1['UTS MAPE on holdout (H5-S2)'],
                  yerr=df1['STD on holdout (H5-S2)'],
                  width=bar_width,
                  capsize=8,
                  label='H5-S2',
                  color=colors1[1],
                  edgecolor='black',
                  linewidth=1.2,
                  alpha=0.9)

# Add data labels on top of bars
for i, (s1_val, s1_std, s2_val, s2_std) in enumerate(zip(
    df1['UTS MAPE on holdout (H5-S1)'],
    df1['STD on holdout (H5-S1)'],
    df1['UTS MAPE on holdout (H5-S2)'],
    df1['STD on holdout (H5-S2)']
)):
    # S1 label
    ax1.text(x1[i] - bar_width/2, s1_val + s1_std + 0.2, 
             f'{s1_val:.1f}±{s1_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold')
    
    # S2 label
    ax1.text(x1[i] + bar_width/2, s2_val + s2_std + 0.2, 
             f'{s2_val:.1f}±{s2_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold')

# X-axis labels
ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=11)
ax1.set_ylabel("UTS MAPE (%)", fontsize=13, fontweight='bold')
ax1.set_title("Ultimate Tensile Strength (UTS) MAPE Comparison: H5-S1 vs H5-S2 on Holdout\n(File: 01-HY5-UTS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax1.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
ax1.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# ============================================================================
# CHART 2: UTS S3 vs S4 from 02-HY5-UTS-MAPE.xlsx
# ============================================================================

# Load second file
df2 = pd.read_excel("02-HY5-UTS-MAPE.xlsx")

# Create Chart 2
fig2, ax2 = plt.subplots(figsize=(14, 8))

# Define positions for the bars
x2 = np.arange(len(df2))

# Colors for S3 and S4
colors2 = ['#2ca02c', '#d62728']  # Green for S3, Red for S4

# H5-S3 bars
bars_s3 = ax2.bar(x2 - bar_width/2,
                  df2['UTS MAPE on holdout (H5-S3)'],
                  yerr=df2['STD on holdout (H5-S3)'],
                  width=bar_width,
                  capsize=8,
                  label='H5-S3',
                  color=colors2[0],
                  edgecolor='black',
                  linewidth=1.2,
                  alpha=0.9)

# H5-S4 bars
bars_s4 = ax2.bar(x2 + bar_width/2,
                  df2['UTS MAPE on holdout (H5-S4)'],
                  yerr=df2['STD on holdout (H5-S4)'],
                  width=bar_width,
                  capsize=8,
                  label='H5-S4',
                  color=colors2[1],
                  edgecolor='black',
                  linewidth=1.2,
                  alpha=0.9)

# Add data labels on top of bars
for i, (s3_val, s3_std, s4_val, s4_std) in enumerate(zip(
    df2['UTS MAPE on holdout (H5-S3)'],
    df2['STD on holdout (H5-S3)'],
    df2['UTS MAPE on holdout (H5-S4)'],
    df2['STD on holdout (H5-S4)']
)):
    # S3 label
    ax2.text(x2[i] - bar_width/2, s3_val + s3_std + 0.2, 
             f'{s3_val:.1f}±{s3_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold')
    
    # S4 label
    ax2.text(x2[i] + bar_width/2, s4_val + s4_std + 0.2, 
             f'{s4_val:.1f}±{s4_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold')

# X-axis labels
ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=11)
ax2.set_ylabel("UTS MAPE (%)", fontsize=13, fontweight='bold')
ax2.set_title("Ultimate Tensile Strength (UTS) MAPE Comparison: H5-S3 vs H5-S4 on Holdout\n(File: 02-HY5-UTS-MAPE.xlsx)", 
              fontsize=14, fontweight='bold', pad=20)
ax2.legend(fontsize=12, title='H5 Variants', title_fontsize=12)
ax2.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
# ALTERNATIVE: Show both UTS charts side by side in one figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(22, 9))

# Common settings
bar_width = 0.35

# ===== CHART 1: UTS S1 vs S2 =====
x1 = np.arange(len(df1))

# H5-S1 bars
bars1 = ax1.bar(x1 - bar_width/2, df1['UTS MAPE on holdout (H5-S1)'],
                yerr=df1['STD on holdout (H5-S1)'],
                width=bar_width, capsize=7, label='H5-S1',
                color='#1f77b4', edgecolor='black', alpha=0.9)

# H5-S2 bars
bars2 = ax1.bar(x1 + bar_width/2, df1['UTS MAPE on holdout (H5-S2)'],
                yerr=df1['STD on holdout (H5-S2)'],
                width=bar_width, capsize=7, label='H5-S2',
                color='#ff7f0e', edgecolor='black', alpha=0.9)

# Add data labels for S1 vs S2
for i, (s1_val, s1_std, s2_val, s2_std) in enumerate(zip(
    df1['UTS MAPE on holdout (H5-S1)'],
    df1['STD on holdout (H5-S1)'],
    df1['UTS MAPE on holdout (H5-S2)'],
    df1['STD on holdout (H5-S2)']
)):
    # S1 label with background for better visibility
    ax1.text(x1[i] - bar_width/2, s1_val + s1_std + 0.3, 
             f'{s1_val:.1f}±{s1_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))
    
    # S2 label with background
    ax1.text(x1[i] + bar_width/2, s2_val + s2_std + 0.3, 
             f'{s2_val:.1f}±{s2_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))

ax1.set_xticks(x1)
ax1.set_xticklabels(df1['Material'], rotation=45, ha='right', fontsize=10)
ax1.set_ylabel("UTS MAPE (%)", fontsize=12, fontweight='bold')
ax1.set_title("UTS: H5-S1 vs H5-S2\n(File: 01-HY5-UTS-MAPE)", fontsize=13, fontweight='bold')
ax1.legend(fontsize=11)
ax1.grid(axis='y', alpha=0.3)

# ===== CHART 2: UTS S3 vs S4 =====
x2 = np.arange(len(df2))

# H5-S3 bars
bars3 = ax2.bar(x2 - bar_width/2, df2['UTS MAPE on holdout (H5-S3)'],
                yerr=df2['STD on holdout (H5-S3)'],
                width=bar_width, capsize=7, label='H5-S3',
                color='#2ca02c', edgecolor='black', alpha=0.9)

# H5-S4 bars
bars4 = ax2.bar(x2 + bar_width/2, df2['UTS MAPE on holdout (H5-S4)'],
                yerr=df2['STD on holdout (H5-S4)'],
                width=bar_width, capsize=7, label='H5-S4',
                color='#d62728', edgecolor='black', alpha=0.9)

# Add data labels for S3 vs S4
for i, (s3_val, s3_std, s4_val, s4_std) in enumerate(zip(
    df2['UTS MAPE on holdout (H5-S3)'],
    df2['STD on holdout (H5-S3)'],
    df2['UTS MAPE on holdout (H5-S4)'],
    df2['STD on holdout (H5-S4)']
)):
    # S3 label with background
    ax2.text(x2[i] - bar_width/2, s3_val + s3_std + 0.3, 
             f'{s3_val:.1f}±{s3_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))
    
    # S4 label with background
    ax2.text(x2[i] + bar_width/2, s4_val + s4_std + 0.3, 
             f'{s4_val:.1f}±{s4_std:.1f}', 
             ha='center', va='bottom', fontsize=9, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.2', facecolor='white', alpha=0.8))

ax2.set_xticks(x2)
ax2.set_xticklabels(df2['Material'], rotation=45, ha='right', fontsize=10)
ax2.set_ylabel("UTS MAPE (%)", fontsize=12, fontweight='bold')
ax2.set_title("UTS: H5-S3 vs H5-S4\n(File: 02-HY5-UTS-MAPE)", fontsize=13, fontweight='bold')
ax2.legend(fontsize=11)
ax2.grid(axis='y', alpha=0.3)

# Main title for the entire figure
plt.suptitle("Ultimate Tensile Strength (UTS) MAPE Comparison Across H5 Variants", 
             fontsize=16, fontweight='bold', y=1.02)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score

# Find best model based on R² on test set
best_r2 = -np.inf
best_model_name = None

for name, data in predictions.items():
    r2 = r2_score(data['y_test'], data['y_pred'])
    if r2 > best_r2:
        best_r2 = r2
        best_model_name = name

print(f"✅ Best model: {best_model_name} with R² = {best_r2:.4f}")
print("Best hyperparameters:", trained_models[best_model_name].best_params_)
# Out:
# ✅ Best model: RandomForest with R² = 0.6542
# Best hyperparameters: {'model__max_depth': 5, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 150}

# %%
X_holdout = df_holdout.drop(columns=['Yield Strength (MPa)'])
y_holdout_true = df_holdout['Yield Strength (MPa)']

# %%
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np
import pandas as pd
from IPython.display import display

# Ensure df_holdout and df_remaining are set by the holdout selector logic
if df_holdout is not None and len(df_holdout) > 0:
    
    # Define the target column dynamically
    target_column = 'Yield Strength (MPa)'  # Change if needed
    
    # Drop target column and the holdout selection column (if present) from features
    exclude_cols = [target_column]
    if selected_column in df_holdout.columns:
        exclude_cols.append(selected_column)
    
    X_holdout = df_holdout.drop(columns=exclude_cols)
    y_holdout = df_holdout[target_column]
    
    # Get the best trained pipeline
    best_pipeline = trained_models[best_model_name]
    
    # Predict on holdout
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted ' + target_column] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted ' + target_column]
    df_results['Absolute Error'] = df_results['Error'].abs()
    
    # Display full results without truncation
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print(f"\n📌 Predictions for Holdout based on {selected_column} = {selected_attributes}")
    display(df_results[[selected_column, target_column, 'Predicted ' + target_column, 'Error', 'Absolute Error']])
    
    # Compute and display metrics
    mae = mean_absolute_error(y_holdout, y_holdout_pred)
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, R² = {r2_holdout:.4f}")
else:
    print("❌ Holdout dataset is empty or not defined.")
# Out:
# 📌 Predictions for Holdout based on None = []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1588], line 38
#      35 pd.set_option('display.width', None)
#      37 print(f"\n📌 Predictions for Holdout based on {selected_column} = {selected_attributes}")
# ---> 38 display(df_results[[selected_column, target_column, 'Predicted ' + target_column, 'Error', 'Absolute Error']])
#      40 # Compute and display metrics
#      41 mae = mean_absolute_error(y_holdout, y_holdout_pred)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np
import pandas as pd
from IPython.display import display

# Ensure df_holdout is prepared from the holdout selection logic
if df_holdout is not None and len(df_holdout) > 0:
    
    # Define the target column (can be Yield Strength or UTS)
    target_column = 'Yield Strength (MPa)'  # Change if needed
    
    # Exclude the target column and the column used for selection
    exclude_cols = [target_column]
    if selected_column in df_holdout.columns:
        exclude_cols.append(selected_column)
    
    # Prepare features and target
    X_holdout = df_holdout.drop(columns=exclude_cols)
    y_holdout = df_holdout[target_column]
    
    # Get best trained model
    best_pipeline = trained_models[best_model_name]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted ' + target_column] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted ' + target_column]
    df_results['Absolute Error'] = df_results['Error'].abs()
    
    # Show full results
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print(f"\n📌 Predictions for Holdout based on {selected_column} = {selected_attributes}")
    display(df_results[['Material', target_column, 'Predicted ' + target_column, 'Error', 'Absolute Error']])
    
    # Metrics
    mae = mean_absolute_error(y_holdout, y_holdout_pred)
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, R² = {r2_holdout:.4f}")
else:
    print("❌ Holdout dataset is empty or not defined.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[212], line 14
#      12 # Exclude the target column and the column used for selection
#      13 exclude_cols = [target_column]
# ---> 14 if selected_column in df_holdout.columns:
#      15     exclude_cols.append(selected_column)
#      17 # Prepare features and target
#
# NameError: name 'selected_column' is not defined

# %%
# Ensure X_holdout and y_holdout are prepared from df_holdout
X_holdout = df_holdout.drop(columns=['Yield Strength (MPa)', 'Material'])
y_holdout = df_holdout['Yield Strength (MPa)']

# Get the best trained model (already trained)
best_pipeline = trained_models[best_model_name]

# Predict on holdout set
y_holdout_pred = best_pipeline.predict(X_holdout)

# Combine results for inspection
df_results = df_holdout.copy()
df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
df_results['Error'] = df_results['Yield Strength (MPa)'] - df_results['Predicted Yield Strength (MPa)']

# Display predictions with error
display(df_results[['Material', 'Yield Strength (MPa)', 'Predicted Yield Strength (MPa)', 'Error']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 9
#       6 best_pipeline = trained_models[best_model_name]
#       8 # Predict on holdout set
# ----> 9 y_holdout_pred = best_pipeline.predict(X_holdout)
#      11 # Combine results for inspection
#      12 df_results = df_holdout.copy()
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_search.py:598, in BaseSearchCV.predict(self, X)
#     580 """Call predict on the estimator with the best found parameters.
#     581
#     582 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     595     the best found parameters.
#     596 """
#     597 check_is_fitted(self)
# --> 598 return self.best_estimator_.predict(X)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/pipeline.py:787, in Pipeline.predict(self, X, **params)
# ...

# %%
# Get best trained model
best_pipeline = trained_models[best_model_name]

# Predict
y_holdout_pred = best_pipeline.predict(X_holdout)

# Combine results for inspection
df_results = df_holdout.copy()
df_results['Predicted Yield Strength (MPa)'] = y_holdout_pred
df_results['Error'] = df_results['Yield Strength (MPa)'] - df_results['Predicted Yield Strength (MPa)']

# Display results
import pandas as pd
display(df_results[['Material', 'Yield Strength (MPa)', 'Predicted Yield Strength (MPa)', 'Error']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 5
#       2 best_pipeline = trained_models[best_model_name]
#       4 # Predict
# ----> 5 y_holdout_pred = best_pipeline.predict(X_holdout)
#       7 # Combine results for inspection
#       8 df_results = df_holdout.copy()
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/model_selection/_search.py:598, in BaseSearchCV.predict(self, X)
#     580 """Call predict on the estimator with the best found parameters.
#     581
#     582 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     595     the best found parameters.
#     596 """
#     597 check_is_fitted(self)
# --> 598 return self.best_estimator_.predict(X)
#
# File /opt/anaconda3/lib/python3.13/site-packages/sklearn/pipeline.py:787, in Pipeline.predict(self, X, **params)
#     785 if not _routing_enabled():
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Predicted vs Actual plot
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x=df_results['Yield Strength (MPa)'], 
    y=df_results['Predicted Yield Strength (MPa)'],
    hue=df_results['Material'],  # optional: color by Material
    palette='tab10',
    s=70
)
plt.plot(
    [df_results['Yield Strength (MPa)'].min(), df_results['Yield Strength (MPa)'].max()],
    [df_results['Yield Strength (MPa)'].min(), df_results['Yield Strength (MPa)'].max()],
    color='red', linestyle='--', label='Ideal: y=x'
)
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title(f'Predicted vs Actual - {best_model_name}', fontsize=14)
plt.legend()
plt.tight_layout()
plt.show()

# %%
print(df_remaining.columns.tolist())
# Out:
# ['Material', 'Material Group', 'Chemistry & Alloy Family', 'Microstructure Class', 'Nuclear Application', 'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)', 'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)', 'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)', 'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)', 'Zr (wt.%)', 'Zn (wt.%)', 'W (wt.%)', 'Sn (wt.%)', 'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)', 'H (wt.%)', 'Treatment', 'Treatment Category', 'Post Treatment Temperature (C)', 'Post Treatment Time (h)', 'Grain size (um)', 'Irradiation Dose (dpa)', 'Irradiation Temperature (C)', 'Gauge Length (mm)', 'Thickness (mm)', 'Width (mm)', 'Aspect Ratio (L/W)', 'Aspect Ratio (T/W)', 'Test Temperature (C)', 'Strain Rate (1/s)', 'Yield Strength (MPa)']

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd

target_col = "Yield Strength (MPa)"  # your actual target column

results = []

for mat in dfYS["Material"].unique():
    # Split holdout vs remaining
    df_holdout = dfYS[dfYS["Material"] == mat].reset_index(drop=True)
    df_remaining = dfYS[dfYS["Material"] != mat].reset_index(drop=True)
    
    # ✅ Only drop target col, keep Material + features (pipeline may need them)
    X_rem = df_remaining.drop(columns=[target_col])
    y_rem = df_remaining[target_col]
    
    X_hold = df_holdout.drop(columns=[target_col])
    y_hold = df_holdout[target_col]

    # Train best pipeline
    best_model_name = summary.index[0]  # best by CV results
    best_pipeline = trained_models[best_model_name].best_estimator_
    best_pipeline.fit(X_rem, y_rem)

    # Predict on holdout material
    y_pred = best_pipeline.predict(X_hold)

    # Metrics
    mse = mean_squared_error(y_hold, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_hold, y_pred)
    mape = np.mean(np.abs((y_hold - y_pred) / np.clip(y_hold, 1e-10, None))) * 100
    r2 = r2_score(y_hold, y_pred)

    results.append({
        "Material": mat,
        "Holdout Size": len(df_holdout),
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "MAPE (%)": mape,
        "R²": r2
    })

df_holdout_results = pd.DataFrame(results)

# Sort by error
df_holdout_results = df_holdout_results.sort_values("MAPE (%)", ascending=False)

display(df_holdout_results.head(20))
# Out:
#      Material  Holdout Size        MSE     RMSE      MAE  MAPE (%)      R²
# 1        JFMS           103 17899.5137 133.7891 100.1117   19.6274 -0.0433
# 0        F82H             5   320.4288  17.9005  16.8287    3.5449 -0.2697
# 2  20MnNiMo55             7   209.2722  14.4662  12.0104    2.4932 -0.0896

# %% [markdown]
# ### 2. Ultimate Tensile Strength

# %%
dfUTS = df.dropna(subset=['Ultimate Tensile Strength (MPa)'])

# %%
# drop other target features
# update for each target feature

dfUTS = dfUTS.drop(columns=[
    'Yield Strength (MPa)',
    'Uniform Elongation (%)',
    'Total Elongation (%)',
    'Reference'
])

# %%
dfUTS.shape
# Out:
# (489, 44)

# %%
dfUTS.columns
# Out:
# Index(['Material', 'Chemistry & Alloy Family', 'Microstructure Class',
#        'C (wt.%)', 'Si (wt.%)', 'Mn (wt.%)', 'P (wt.%)', 'S (wt.%)',
#        'Ni (wt.%)', 'Cr (wt.%)', 'Mo (wt.%)', 'Al (wt.%)', 'N (wt.%)',
#        'Ti (wt.%)', 'Fe (wt.%)', 'Nb (wt.%)', 'B (wt.%)', 'Cu (wt.%)',
#        'V (wt.%)', 'Mg (wt.%)', 'Y (wt.%)', 'Zr (wt.%)', 'Zn (wt.%)',
#        'W (wt.%)', 'Sn (wt.%)', 'Co (wt.%)', 'O (wt.,%)', 'Ta (wt.%)',
#        'H (wt.%)', 'Treatment', 'Treatment Category',
#        'Post Treatment Temperature (C)', 'Post Treatment Time (h)',
#        'Grain size (um)', 'Irradiation Dose (dpa)',
#        'Irradiation Temperature (C)', 'Gauge Length (mm)', 'Thickness (mm)',
#        'Width (mm)', 'Aspect Ratio (L/W)', 'Aspect Ratio (T/W)',
#        'Test Temperature (C)', 'Strain Rate (1/s)',
#        'Ultimate Tensile Strength (MPa)'],
#       dtype='object')

# %% [markdown]
# ### UTS Processing

# %%
# ========================================
# 1. Remove duplicates
# ========================================
dfUTS = dfUTS.drop_duplicates()                      # update for each target feature

# %%
dfUTS.shape
# Out:
# (479, 44)

# %% [markdown]
# #### run cells for hypothesis 5

# %%
dfUTS = dfUTS[dfUTS['Chemistry & Alloy Family'] == 'Stainless Steels']

print(f"Filtered rows: {dfUTS.shape[0]}")
display(dfUTS.head())
# Out:
# Filtered rows: 280
#    Material Chemistry & Alloy Family Microstructure Class  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)              Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Ultimate Tensile Strength (MPa)
# ...

# %%
dfUTS = dfUTS[dfUTS['Microstructure Class'] == 'Tempered Martensitic']

print(f"Filtered rows: {dfUTS.shape[0]}")
display(dfUTS.head())
# Out:
# Filtered rows: 81
#    Material     Chemistry & Alloy Family  Microstructure Class  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Ultimate Tensile Strength (MPa)
# ...

# %%
# Define the microstructures to keep
selected_microstructures = [
    'Ferritic',
    'HCP solid solution',
    'Tempered Bainitic',
    'Ferrite + Pearlite',
    'α+β Structure',
    'Ferritic-Martensitic (dual phase)'
]

# Filter rows where Microstructure Class matches selected values
dfUTS = dfUTS[dfUTS['Microstructure Class'].isin(selected_microstructures)]

# Display the shape and first few rows
print(f"Filtered rows: {dfUTS.shape[0]}")
display(dfUTS.head())
# Out:
# Filtered rows: 105
#   Material                  Chemistry & Alloy Family Microstructure Class  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Ultimate Tensile Strength (MPa)
# ...

# %%
dfUTS = dfUTS[dfUTS['Chemistry & Alloy Family'].isin(['Stainless Steels', 'Ferritic-Martensitic Steels'])]

print(f"Filtered rows: {dfUTS.shape[0]}")
display(dfUTS.head())
# Out:
# Filtered rows: 377
#   Material         Material Group     Chemistry & Alloy Family Microstructure Class                       Nuclear Application  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Ultimate Tensile Strength (MPa)
# ...

# %%
dfUTS = dfUTS[dfUTS['Microstructure Class'] == 'Ferritic-Martensitic']

print(f"Filtered rows: {dfUTS.shape[0]}")
display(dfUTS.head())
# Out:
# Filtered rows: 73
#    Material           Material Group     Chemistry & Alloy Family  Microstructure Class                                Nuclear Application  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Ultimate Tensile Strength (MPa)
# ...

# %%
dfUTS = dfUTS[dfUTS['Microstructure Class'].isin(['Ferritic', 'Ferritic-Martensitic', 'Ferrite + Pearlite', 'Refined Ferritic'])]

print(f"Filtered rows: {dfUTS.shape[0]}")
display(dfUTS.head())
# Out:
# Filtered rows: 95
#   Material      Material Group     Chemistry & Alloy Family Microstructure Class                       Nuclear Application  C (wt.%)  Si (wt.%)  Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  Mo (wt.%)  Al (wt.%)  N (wt.%)  Ti (wt.%)  Fe (wt.%)  Nb (wt.%)  B (wt.%)  Cu (wt.%)  V (wt.%)  Mg (wt.%)  Y (wt.%)  Zr (wt.%)  Zn (wt.%)  W (wt.%)  Sn (wt.%)  Co (wt.%)  O (wt.,%)  Ta (wt.%)  H (wt.%)                          Treatment Treatment Category  Post Treatment Temperature (C)  Post Treatment Time (h)  Grain size (um)  Irradiation Dose (dpa)  Irradiation Temperature (C)  Gauge Length (mm)  Thickness (mm)  Width (mm)  Aspect Ratio (L/W)  Aspect Ratio (T/W)  Test Temperature (C)  Strain Rate (1/s)  Ultimate Tensile Strength (MPa)
# ...

# %% [markdown]
# #### Hold Out Material

# %% [markdown]
# #### HYPOTHESIS 5

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd

# Assume dfUTS is your original dataframe
materials = dfUTS['Material'].unique().tolist()

# Dropdown widget to select material
material_selector = widgets.Dropdown(
    options=materials,
    description='Select Material:',
    style={'description_width': 'initial'}
)

# Output area to show results
output = widgets.Output()

# Global variables
selected_material = None
df_holdout = None
df_remaining = None

# Function to split data based on selected material
def split_data(change):
    global selected_material, df_holdout, df_remaining
    with output:
        clear_output(wait=True)
        
        selected_material = material_selector.value
        
        # Create holdout and remaining datasets
        df_holdout = dfUTS[dfUTS['Material'] == selected_material].reset_index(drop=True)
        df_remaining = dfUTS[dfUTS['Material'] != selected_material].reset_index(drop=True)
        
        # Display shapes
        print(f"✅ Holdout Material: {selected_material}")
        print(f"Holdout shape: {df_holdout.shape}")
        print(f"Remaining data shape: {df_remaining.shape}")
        
        # Optionally show first few rows
        display(df_holdout.head(), df_remaining.head())

# Attach event listener
material_selector.observe(split_data, names='value')

# Display widgets and output
display(material_selector, output)

# Initial run
split_data(None)
# Out:
# Dropdown(description='Select Material:', options=('FeCrAl', 'Zircaloy-4', 'A-533B', 'SA508 C1.3 ', 'Ultra-fine…
# Output()

# %% [markdown]
# #### HYPOTHESIS 3

# %% [markdown]
# #### OUTLIER REMOVAL

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
from sklearn.ensemble import IsolationForest
import numpy as np
import pandas as pd

# ---- Combined OutlierRemover Class ----
class OutlierRemover:
    def __init__(self, method='none', factor=1.5, z_thresh=3.0, iso_cont=0.05, max_outliers=None):
        self.method = method
        self.factor = factor
        self.z_thresh = z_thresh
        self.iso_cont = iso_cont
        self.max_outliers = max_outliers

    def fit_transform(self, df):
        if self.method == 'none':
            return df.copy(), df.iloc[0:0]

        numeric_df = df.select_dtypes(include=[np.number])

        if self.method == 'iqr':
            Q1 = numeric_df.quantile(0.25)
            Q3 = numeric_df.quantile(0.75)
            IQR = Q3 - Q1
            score = ((numeric_df < (Q1 - self.factor * IQR)) | (numeric_df > (Q3 + self.factor * IQR))).sum(axis=1)

        elif self.method == 'zscore':
            z = (numeric_df - numeric_df.mean()) / numeric_df.std()
            score = (np.abs(z) > self.z_thresh).sum(axis=1)

        elif self.method == 'isoforest':
            iso = IsolationForest(contamination=self.iso_cont, random_state=42)
            iso.fit(numeric_df)
            score = pd.Series(-iso.score_samples(numeric_df), index=df.index)

        else:
            return df.copy(), df.iloc[0:0]

        # Sort by score
        score_sorted_idx = score.sort_values(ascending=False).index
        if self.max_outliers:
            outlier_idx = score_sorted_idx[:self.max_outliers]
        else:
            outlier_idx = score[score > 0].index  # Keep all flagged rows

        df_clean = df.drop(outlier_idx)
        df_outliers = df.loc[outlier_idx]

        return df_clean, df_outliers


# ---- Widgets ----
method_selector = widgets.Dropdown(
    options=['none', 'zscore', 'iqr', 'isoforest'],
    value='none',
    description='Method:',
    style={'description_width': 'initial'}
)

factor_slider = widgets.FloatSlider(value=1.5, min=0.5, max=3.0, step=0.1, description='IQR Factor')
z_thresh_slider = widgets.FloatSlider(value=3.0, min=1.0, max=5.0, step=0.1, description='Z-score Threshold')
iso_cont_slider = widgets.FloatSlider(value=0.05, min=0.01, max=0.5, step=0.01, description='IsoForest Contamination')
max_outliers_slider = widgets.IntSlider(value=10, min=1, max=50, step=1, description='Top N Outliers')

show_full_checkbox = widgets.Checkbox(value=False, description='Show Full DataFrame')

output_area = widgets.Output()

# ---- Slider Visibility ----
def update_slider_visibility(change):
    method = change['new']
    factor_slider.layout.display = 'none'
    z_thresh_slider.layout.display = 'none'
    iso_cont_slider.layout.display = 'none'
    if method == 'iqr':
        factor_slider.layout.display = 'block'
    elif method == 'zscore':
        z_thresh_slider.layout.display = 'block'
    elif method == 'isoforest':
        iso_cont_slider.layout.display = 'block'

method_selector.observe(update_slider_visibility, names='value')
update_slider_visibility({'new': method_selector.value})  # Initialize

# ---- Apply Outlier Removal ----
def apply_outlier_removal(_):
    global dfUTS_clean, dfUTS_outliers, df_remaining
    
    # CHECK: Use df_remaining if it exists, otherwise use dfUTS
    if 'df_remaining' in globals() and df_remaining is not None:
        data_to_clean = df_remaining
        data_source = "df_remaining (data after holdout removal)"
    else:
        data_to_clean = dfUTS
        data_source = "dfUTS (original data - no holdout split detected)"
    
    remover = OutlierRemover(
        method=method_selector.value,
        factor=factor_slider.value,
        z_thresh=z_thresh_slider.value,
        iso_cont=iso_cont_slider.value,
        max_outliers=max_outliers_slider.value
    )
    dfUTS_clean, dfUTS_outliers = remover.fit_transform(data_to_clean)

    with output_area:
        clear_output(wait=True)
        print(f"📊 Data Source: {data_source}")
        print(f"Input shape:    {data_to_clean.shape}")
        print(f"Cleaned shape:  {dfUTS_clean.shape}")
        print(f"Outliers shape: {dfUTS_outliers.shape}")
        print(f"Removed {data_to_clean.shape[0] - dfUTS_clean.shape[0]} rows as outliers")

        if show_full_checkbox.value:
            print("\n✅ Cleaned DataFrame (all rows):")
            display(HTML('<div style="max-height:300px; overflow:auto;">' + dfUTS_clean.to_html() + '</div>'))
            print("\n🚩 Outliers (all rows):")
            display(HTML('<div style="max-height:300px; overflow:auto;">' + dfUTS_outliers.to_html() + '</div>'))
        else:
            print("\n✅ Cleaned DataFrame (first 5 rows):")
            display(HTML(dfUTS_clean.head().to_html()))
            print("\n🚩 Outliers (first 5 rows):")
            display(HTML(dfUTS_outliers.head().to_html()))

# ---- Bind events ----
method_selector.observe(apply_outlier_removal, names='value')
factor_slider.observe(apply_outlier_removal, names='value')
z_thresh_slider.observe(apply_outlier_removal, names='value')
iso_cont_slider.observe(apply_outlier_removal, names='value')
max_outliers_slider.observe(apply_outlier_removal, names='value')
show_full_checkbox.observe(apply_outlier_removal, names='value')

# ---- Display UI ----
ui = widgets.VBox([method_selector, factor_slider, z_thresh_slider, iso_cont_slider,
                   max_outliers_slider, show_full_checkbox, output_area])
display(ui)

# Initial run
apply_outlier_removal(None)

# %%
from sklearn.model_selection import train_test_split

# ========================================
# 3. Train-test split
# ========================================
X = dfUTS_clean.drop(columns=['Ultimate Tensile Strength (MPa)'])  # Features
y = dfUTS_clean['Ultimate Tensile Strength (MPa)']                # Target

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

print(f"X_train shape: {X_train.shape}")
print(f"X_test  shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test  shape: {y_test.shape}")
# Out:
# X_train shape: (81, 43)
# X_test  shape: (9, 43)
# y_train shape: (81,)
# y_test  shape: (9,)

# %% [markdown]
# ### Feature selector

# %%
import ipywidgets as widgets
from IPython.display import display
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression, chi2, VarianceThreshold

# Feature selection methods
feature_selection_methods = {
    'F Regression': f_regression,
    'Mutual Info Regression': mutual_info_regression,
    'Chi-Squared': chi2,
    'Variance Threshold': 'variance'
}

# Dropdown for method
method_selector = widgets.Dropdown(
    options=list(feature_selection_methods.keys()),
    value='Mutual Info Regression',
    description='Feature Selection Method:',
    style={'description_width': 'initial'}
)

# Slider for k (number of features)
k_selector = widgets.IntSlider(
    value=34,
    min=1,
    max=50,
    step=1,
    description='Number of Features (k):',
    style={'description_width': 'initial'}
)

display(method_selector, k_selector)
# Out:
# Dropdown(description='Feature Selection Method:', index=1, options=('F Regression', 'Mutual Info Regression', …
# IntSlider(value=34, description='Number of Features (k):', max=50, min=1, style=SliderStyle(description_width=…

# %% [markdown]
# #### preprocessing pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# Identify numeric/categorical features
numeric_features = X_train.select_dtypes(include=np.number).columns
categorical_features = X_train.select_dtypes(exclude=np.number).columns

# Numeric pipeline
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
    ('normalizer', MinMaxScaler())
])

# Categorical pipeline
categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# Column transformer
preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# Pipeline builder with dynamic feature selection
def build_pipeline(selected_method, k, model):
    from sklearn.feature_selection import SelectKBest, VarianceThreshold
    if selected_method == 'Variance Threshold':
        selector = VarianceThreshold(threshold=0.01)
    else:
        selector = SelectKBest(score_func=feature_selection_methods[selected_method], k=k)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('feature_selection', selector),
        ('model', model)
    ])
    return pipeline

# %% [markdown]
# #### UTS Model Training

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor


models_params = {
    'RandomForest': (
        RandomForestRegressor(random_state=42),
        {
            'model__n_estimators': [50, 100, 150, 200, 300],
            'model__max_depth': [None, 5, 10, 15, 20, 30],
            'model__min_samples_split': [2, 5, 10],
            'model__min_samples_leaf': [1, 2, 4]
        }
    ),
    'DecisionTree': (
        DecisionTreeRegressor(random_state=42),
        {
            'model__max_depth': [None, 5, 10, 15, 20],
            'model__min_samples_split': [2, 5, 10, 15],
            'model__min_samples_leaf': [1, 2, 4, 6]
        }
    ),
    'SVR': (
        SVR(),
        {
            'model__kernel': ['linear', 'rbf', 'poly'],
            'model__C': [0.01, 0.1, 1, 5, 10, 50],
            'model__gamma': ['scale', 'auto']
        }
    ),
    'Lasso': (
        Lasso(random_state=42, max_iter=50000),
        {
            'model__alpha': [0.001, 0.01, 0.1, 1, 10, 100]
        }
    ),
    'KNN': (
        KNeighborsRegressor(),
        {
            'model__n_neighbors': list(range(3, 16, 2)),  # 3,5,7,9,11,13,15
            'model__weights': ['uniform', 'distance'],
            'model__p': [1, 2]  # Manhattan and Euclidean
        }
    ),
    'GradientBoosting': (
        GradientBoostingRegressor(random_state=42),
        {
            'model__n_estimators': [100, 200, 300, 400],
            'model__learning_rate': [0.01, 0.05, 0.1, 0.2],
            'model__max_depth': [3, 5, 7],
            'model__min_samples_split': [2, 5, 10]
        }
    ),
    'AdaBoost': (
        AdaBoostRegressor(random_state=42),
        {
            'model__n_estimators': [50, 100, 200],
            'model__learning_rate': [0.01, 0.05, 0.1, 0.5, 1]
        }
    ),
    'Bagging': (
        BaggingRegressor(random_state=42),
        {
            'model__n_estimators': [10, 20, 50, 100, 200],
            'model__max_samples': [0.5, 0.7, 1.0],
            'model__max_features': [0.5, 0.7, 1.0]
        }
    )
}

# %%
cv_selector = widgets.Dropdown(
    options=['GridSearchCV', 'RandomizedSearchCV', 'BayesSearchCV'],
    value='GridSearchCV',
    description='CV Method:',
    style={'description_width': 'initial'}
)
display(cv_selector)
# Out:
# Dropdown(description='CV Method:', options=('GridSearchCV', 'RandomizedSearchCV', 'BayesSearchCV'), style=Desc…

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from skopt import BayesSearchCV
import numpy as np

# Store trained models, predictions, and search objects for later use
trained_models = {}
predictions = {}

def run_model_training(X_train, X_test, y_train, y_test, selected_method, selected_k, cv_method='GridSearchCV', n_iter=20):
    global trained_models, predictions
    trained_models.clear()
    predictions.clear()

    for name, (model, params) in models_params.items():
        print(f"🏋️ Training {name} using {cv_method}...")
        pipeline = build_pipeline(selected_method, selected_k, model)
        
        # Select CV method
        if cv_method == 'GridSearchCV':
            search = GridSearchCV(pipeline, params, cv=5, scoring='r2', n_jobs=-1)
        elif cv_method == 'RandomizedSearchCV':
            search = RandomizedSearchCV(pipeline, params, n_iter=n_iter, cv=5, scoring='r2', n_jobs=-1, random_state=42)
        else:  # BayesSearchCV
            search = BayesSearchCV(pipeline, params, n_iter=n_iter, cv=5, scoring='r2', n_jobs=-1, random_state=42)
        
        search.fit(X_train, y_train)
        y_pred = search.predict(X_test)
        
        trained_models[name] = search
        predictions[name] = {'y_test': y_test, 'y_pred': y_pred}

cv_choice = cv_selector.value
run_model_training(X_train, X_test, y_train, y_test, method_selector.value, k_selector.value, cv_method=cv_choice)
# Out:
# 🏋️ Training RandomForest using GridSearchCV...
# 🏋️ Training DecisionTree using GridSearchCV...
# 🏋️ Training SVR using GridSearchCV...
# 🏋️ Training Lasso using GridSearchCV...
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.676e+04, tolerance: 3.577e+02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.029e+04, tolerance: 3.603e+02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# #### UTS Results

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd

def evaluate_models():
    results = {}
    for name, data in predictions.items():
        y_test, y_pred = data['y_test'], data['y_pred']
        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(y_test, y_pred)
        mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
        r2 = r2_score(y_test, y_pred)
        
        results[name] = {
            'Best Params': trained_models[name].best_params_,
            'MSE': mse,
            'RMSE': rmse,
            'MAE': mae,
            'MAPE (%)': mape,
            'R2 Score': r2
        }
    
    results_df = pd.DataFrame(results).T.sort_values(by='R2 Score', ascending=False)
    return results_df

final_results = evaluate_models()
print(final_results)
# Out:
#                                                         Best Params       MSE    RMSE     MAE MAPE (%) R2 Score
# Bagging           {'model__max_features': 0.7, 'model__max_sampl... 2385.5489 48.8421 36.1133   4.7957   0.9586
# RandomForest      {'model__max_depth': None, 'model__min_samples... 2926.5245 54.0974 36.2933   4.1348   0.9492
# Lasso                                           {'model__alpha': 1} 3604.7926 60.0399 44.1972   5.0866   0.9374
# KNN               {'model__n_neighbors': 11, 'model__p': 1, 'mod... 4676.8682 68.3876 37.9669   3.6121   0.9188
# SVR               {'model__C': 50, 'model__gamma': 'scale', 'mod... 4705.2461 68.5948 44.3578   4.8258   0.9183
# GradientBoosting  {'model__learning_rate': 0.01, 'model__max_dep... 5818.2528 76.2775 50.4717   5.6011   0.8989
# AdaBoost          {'model__learning_rate': 0.5, 'model__n_estima... 6633.8849 81.4487 56.2072   6.8581   0.8848
# ...

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-10, None))) * 100

def evaluate_with_kfold(X, y, model_pipeline, k=5):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    mae_scores, rmse_scores, mse_scores, mape_scores, r2_scores = [], [], [], [], []

    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model_pipeline.fit(X_train, y_train)
        y_pred = model_pipeline.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        mape = mean_absolute_percentage_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)

        mae_scores.append(mae)
        mse_scores.append(mse)
        rmse_scores.append(rmse)
        mape_scores.append(mape)
        r2_scores.append(r2)

    return {
        'MAE': (np.mean(mae_scores), np.std(mae_scores)),
        'MSE': (np.mean(mse_scores), np.std(mse_scores)),
        'RMSE': (np.mean(rmse_scores), np.std(rmse_scores)),
        'MAPE': (np.mean(mape_scores), np.std(mape_scores)),
        'R2': (np.mean(r2_scores), np.std(r2_scores))
    }

# ✅ Evaluate each best model from GridSearch
k = 5
X_full = X_train  # Full cleaned training data
y_full = y_train

cv_results = {}
for name, search_obj in trained_models.items():
    best_pipeline = search_obj.best_estimator_
    metrics = evaluate_with_kfold(X_full, y_full, best_pipeline, k=k)
    cv_results[name] = metrics
    print(f"\nModel: {name}")
    print(f"MAE:  {metrics['MAE'][0]:.4f} ± {metrics['MAE'][1]:.4f}")
    print(f"MSE:  {metrics['MSE'][0]:.4f} ± {metrics['MSE'][1]:.4f}")
    print(f"RMSE: {metrics['RMSE'][0]:.4f} ± {metrics['RMSE'][1]:.4f}")
    print(f"MAPE: {metrics['MAPE'][0]:.2f}% ± {metrics['MAPE'][1]:.2f}%")
    print(f"R²:   {metrics['R2'][0]:.4f} ± {metrics['R2'][1]:.4f}")
# Out:
# Model: RandomForest
# MAE:  44.7583 ± 13.9801
# MSE:  5844.0060 ± 3212.3415
# RMSE: 73.1771 ± 22.1159
# MAPE: 6.33% ± 2.32%
# R²:   0.8973 ± 0.0552
#
# Model: DecisionTree
# MAE:  42.2068 ± 9.7361
# MSE:  5820.0858 ± 2591.6761
# RMSE: 73.9655 ± 18.6867
# MAPE: 5.43% ± 1.62%
# R²:   0.8978 ± 0.0441
#
# Model: SVR
# MAE:  74.0872 ± 14.3051
# MSE:  14727.8500 ± 5467.9477
# RMSE: 119.0502 ± 23.5566
# MAPE: 9.65% ± 1.57%
# R²:   0.7177 ± 0.1358
#
# Model: Lasso
# MAE:  57.9507 ± 14.5553
# MSE:  8085.4629 ± 4306.1339
# RMSE: 86.7899 ± 23.5154
# MAPE: 7.79% ± 1.90%
# R²:   0.8492 ± 0.0944
#
# Model: KNN
# MAE:  40.8720 ± 10.0407
# MSE:  4907.1445 ± 2301.1491
# RMSE: 68.1313 ± 16.2872
# MAPE: 5.73% ± 1.92%
# R²:   0.9165 ± 0.0283
#
# Model: GradientBoosting
# MAE:  48.6619 ± 10.2335
# MSE:  6685.9210 ± 2828.7652
# RMSE: 79.6399 ± 18.5313
# MAPE: 7.73% ± 3.10%
# R²:   0.8845 ± 0.0411
#
# Model: AdaBoost
# MAE:  46.2867 ± 11.3773
# MSE:  5753.9553 ± 2554.6008
# RMSE: 73.9911 ± 16.7112
# ...

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-10, None))) * 100

def evaluate_with_kfold(X, y, model_pipeline, k=5):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    mae_scores, rmse_scores, mse_scores, mape_scores, r2_scores = [], [], [], [], []

    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model_pipeline.fit(X_train, y_train)
        y_pred = model_pipeline.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        mape = mean_absolute_percentage_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)

        mae_scores.append(mae)
        mse_scores.append(mse)
        rmse_scores.append(rmse)
        mape_scores.append(mape)
        r2_scores.append(r2)

    return {
        'MAE': (np.mean(mae_scores), np.std(mae_scores)),
        'MSE': (np.mean(mse_scores), np.std(mse_scores)),
        'RMSE': (np.mean(rmse_scores), np.std(rmse_scores)),
        'MAPE': (np.mean(mape_scores), np.std(mape_scores)),
        'R2': (np.mean(r2_scores), np.std(r2_scores))
    }

# ✅ Evaluate each best model from GridSearch
k = 5
X_full = X_train  # Full cleaned training data
y_full = y_train

cv_results = {}
for name, search_obj in trained_models.items():
    best_pipeline = search_obj.best_estimator_
    metrics = evaluate_with_kfold(X_full, y_full, best_pipeline, k=k)
    cv_results[name] = metrics
    print(f"\nModel: {name}")
    print(f"MAE:  {metrics['MAE'][0]:.4f} ± {metrics['MAE'][1]:.4f}")
    print(f"MSE:  {metrics['MSE'][0]:.4f} ± {metrics['MSE'][1]:.4f}")
    print(f"RMSE: {metrics['RMSE'][0]:.4f} ± {metrics['RMSE'][1]:.4f}")
    print(f"MAPE: {metrics['MAPE'][0]:.2f}% ± {metrics['MAPE'][1]:.2f}%")
    print(f"R²:   {metrics['R2'][0]:.4f} ± {metrics['R2'][1]:.4f}")
# Out:
# Model: RandomForest
# MAE:  44.7583 ± 13.9801
# MSE:  5844.0060 ± 3212.3415
# RMSE: 73.1771 ± 22.1159
# MAPE: 6.33% ± 2.32%
# R²:   0.8973 ± 0.0552
#
# Model: DecisionTree
# MAE:  42.2068 ± 9.7361
# MSE:  5820.0858 ± 2591.6761
# RMSE: 73.9655 ± 18.6867
# MAPE: 5.43% ± 1.62%
# R²:   0.8978 ± 0.0441
#
# Model: SVR
# MAE:  74.0872 ± 14.3051
# MSE:  14727.8500 ± 5467.9477
# RMSE: 119.0502 ± 23.5566
# MAPE: 9.65% ± 1.57%
# R²:   0.7177 ± 0.1358
#
# Model: Lasso
# MAE:  57.9507 ± 14.5553
# MSE:  8085.4629 ± 4306.1339
# RMSE: 86.7899 ± 23.5154
# MAPE: 7.79% ± 1.90%
# R²:   0.8492 ± 0.0944
#
# Model: KNN
# MAE:  40.8720 ± 10.0407
# MSE:  4907.1445 ± 2301.1491
# RMSE: 68.1313 ± 16.2872
# MAPE: 5.73% ± 1.92%
# R²:   0.9165 ± 0.0283
#
# Model: GradientBoosting
# MAE:  48.6619 ± 10.2335
# MSE:  6685.9210 ± 2828.7652
# RMSE: 79.6399 ± 18.5313
# MAPE: 7.73% ± 3.10%
# R²:   0.8845 ± 0.0411
#
# Model: AdaBoost
# MAE:  46.2867 ± 11.3773
# MSE:  5753.9553 ± 2554.6008
# RMSE: 73.9911 ± 16.7112
# ...

# %%
#### import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Custom MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-10, None))) * 100

# Evaluate with KFold and return per-fold results
def evaluate_with_kfold_detailed(X, y, model_pipeline, model_name, k=5):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)

    results = []
    fold = 1

    for train_idx, val_idx in kf.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model_pipeline.fit(X_train, y_train)
        y_pred = model_pipeline.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        mse = mean_squared_error(y_val, y_pred)
        rmse = np.sqrt(mse)
        mape = mean_absolute_percentage_error(y_val, y_pred)
        r2 = r2_score(y_val, y_pred)

        results.append({
            'Model': model_name,
            'Fold': fold,
            'MAE': mae,
            'MSE': mse,
            'RMSE': rmse,
            'MAPE (%)': mape,
            'R²': r2
        })
        fold += 1

    return results

# ✅ Run evaluation for all trained models
k = 10
X_full = X_train
y_full = y_train

all_results = []

for name, search_obj in trained_models.items():
    best_pipeline = search_obj.best_estimator_
    fold_results = evaluate_with_kfold_detailed(X_full, y_full, best_pipeline, name, k=k)
    all_results.extend(fold_results)

# Convert to DataFrame for detailed per-fold view
df_kfold_results = pd.DataFrame(all_results)

# Display the DataFrame (per model, per fold)
import pandas as pd
pd.set_option('display.float_format', lambda x: f'{x:.4f}')
display(df_kfold_results)

# ✅ Summary (mean per model)
summary = df_kfold_results.groupby('Model').agg({
    'MAE': ['mean', 'std'],
    'MSE': ['mean', 'std'],
    'RMSE': ['mean', 'std'],
    'MAPE (%)': ['mean', 'std'],
    'R²': ['mean', 'std']
})
display(summary)
# Out:
#                Model  Fold      MAE        MSE     RMSE  MAPE (%)     R²
# 0       RandomForest     1  19.7248   786.4099  28.0430    4.3718 0.9832
# 1       RandomForest     2  74.4784 11478.8431 107.1394   10.9745 0.8813
# 2       RandomForest     3  81.7506 15380.1533 124.0167   10.6541 0.5019
# 3       RandomForest     4  54.3990  6832.0144  82.6560    6.8473 0.9228
# 4       RandomForest     5  73.5629 11778.7060 108.5297    6.8444 0.8036
# 5       RandomForest     6  15.3329   447.6084  21.1568    1.9261 0.9799
# 6       RandomForest     7  18.1687   456.9644  21.3767    2.8059 0.9902
# 7       RandomForest     8  34.3797  2330.9605  48.2800    4.5872 0.9526
# 8       RandomForest     9  28.0630  1335.5617  36.5453    4.9118 0.9683
# 9       RandomForest    10  45.5573  7256.3120  85.1840    5.3151 0.8846
# 10      DecisionTree     1  21.6134   959.7026  30.9791    4.2964 0.9795
# 11      DecisionTree     2  77.5775 12391.8600 111.3187   11.1382 0.8719
# ...

# %%
from sklearn.metrics import r2_score
import numpy as np

# Initialize best model tracking
best_r2 = -np.inf
best_model_name = None
best_pipeline = None

# Loop through predictions to find best R²
for name, data in predictions.items():
    r2 = r2_score(data['y_test'], data['y_pred'])
    if r2 > best_r2:
        best_r2 = r2
        best_model_name = name
        best_pipeline = trained_models[name].best_estimator_  # Store pipeline

# Print best model details
print(f"✅ Best model: {best_model_name} with R² = {best_r2:.4f}")
print("Best hyperparameters:")
print(trained_models[best_model_name].best_params_)
# Out:
# ✅ Best model: Bagging with R² = 0.9586
# Best hyperparameters:
# {'model__max_features': 0.7, 'model__max_samples': 0.7, 'model__n_estimators': 20}

# %%
from sklearn.metrics import r2_score
import numpy as np

# Initialize best model tracking
best_r2 = -np.inf
best_model_name = None
best_pipeline = None

# Loop through predictions to find best R²
for name, data in predictions.items():
    r2 = r2_score(data['y_test'], data['y_pred'])
    if r2 > best_r2:
        best_r2 = r2
        best_model_name = name
        best_pipeline = trained_models[name].best_estimator_  # Store pipeline

# Print best model details
print(f"✅ Best model: {best_model_name} with R² = {best_r2:.4f}")
print("Best hyperparameters:")
print(trained_models[best_model_name].best_params_)
# Out:
# ✅ Best model: Bagging with R² = 0.9586
# Best hyperparameters:
# {'model__max_features': 0.7, 'model__max_samples': 0.7, 'model__n_estimators': 20}

# %%
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd

# Ensure holdout exists
if 'df_holdout' in globals() and df_holdout is not None and 'best_pipeline' in globals() and best_pipeline is not None:
    
    target_column = 'Ultimate Tensile Strength (MPa)'  # Change if needed
    
    # Prepare features and target
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Ultimate Tensile Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Ultimate Tensile Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    
    # Full display options
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    # Identify selection type for label
    selection_info = None
    if 'selected_material' in globals() and selected_material:
        selection_info = f"Material: {selected_material}"
    elif 'selected_column' in globals() and selected_attributes:
        selection_info = f"{selected_column} = {selected_attributes}"
    else:
        selection_info = "Custom Holdout"
    
    # Display results
    print(f"\n📌 Predictions for Holdout ({selection_info}):")
    display(df_results[['Material', target_column, 'Predicted Ultimate Tensile Strength (MPa)', 'Error', 'Absolute Error']])
    
    # Metrics
    mae = np.mean(df_results['Absolute Error'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, R² = {r2_holdout:.4f}")
else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for Holdout (Material: Zr-2.5 Nb):
#      Material  Ultimate Tensile Strength (MPa)  Predicted Ultimate Tensile Strength (MPa)     Error  Absolute Error
# 0   Zr-2.5 Nb                         836.5500                                   920.6945  -84.1445         84.1445
# 1   Zr-2.5 Nb                         828.3700                                   920.6945  -92.3245         92.3245
# 2   Zr-2.5 Nb                         836.7000                                   920.6945  -83.9945         83.9945
# 3   Zr-2.5 Nb                         734.2500                                   920.6945 -186.4445        186.4445
# 4   Zr-2.5 Nb                         828.6800                                   907.6445  -78.9645         78.9645
# 5   Zr-2.5 Nb                         838.0000                                   907.6445  -69.6445         69.6445
# 6   Zr-2.5 Nb                         845.0000                                   907.6445  -62.6445         62.6445
# ...

# %%
from sklearn.metrics import r2_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ensure holdout exists
if 'df_holdout' in globals() and df_holdout is not None and 'best_pipeline' in globals() and best_pipeline is not None:
    
    target_column = 'Ultimate Tensile Strength (MPa)'  # Change if needed
    
    # Prepare features and target
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Ultimate Tensile Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Ultimate Tensile Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    df_results['APE (%)'] = (df_results['Absolute Error'] / df_results[target_column]) * 100  # ADDED MAPE
    
    # Full display options
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    # Identify selection type for label
    selection_info = None
    if 'selected_material' in globals() and selected_material:
        selection_info = f"Material: {selected_material}"
    elif 'selected_column' in globals() and selected_attributes:
        selection_info = f"{selected_column} = {selected_attributes}"
    else:
        selection_info = "Custom Holdout"
    
    # Display results
    print(f"\n📌 Predictions for Holdout ({selection_info}):")
    display(df_results[['Material', target_column, 'Predicted Ultimate Tensile Strength (MPa)', 'Error', 'Absolute Error', 'APE (%)']])
    
    # Metrics - WITH MAPE AND STD
    mae = np.mean(df_results['Absolute Error'])
    mape = np.mean(df_results['APE (%)'])
    mape_std = np.std(df_results['APE (%)'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, MAPE = {mape:.2f}% (± {mape_std:.2f}%), R² = {r2_holdout:.4f}")
    
    # === ADDED: SEPARATE EVALUATION SUMMARY LINE FOR BEST PERFORMING ALGORITHM ===
    print(f"\n{'='*80}")
    print(f"🎯 EVALUATION SUMMARY FOR BEST PERFORMING ALGORITHM: {best_model_name}")
    print(f"{'='*80}")
    print(f"📊 Model: {best_model_name}")
    print(f"📊 Holdout Set: {selection_info}")
    print(f"📊 Samples: {len(df_results)}")
    print(f"📊 MAE: {mae:.2f} MPa")
    print(f"📊 MAPE: {mape:.2f}% ± {mape_std:.2f}%")
    print(f"📊 R² Score: {r2_holdout:.4f}")
    print(f"{'='*80}")
    
    # === ADDED: MAPE CHART WITH ERROR BARS ===
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # 1. MAPE Bar Chart with Error Bars
    axes[0].bar(['MAPE'], [mape], yerr=[mape_std], capsize=10, color='skyblue', alpha=0.8, edgecolor='black')
    axes[0].set_title(f"Mean Absolute Percentage Error (MAPE)\n{selection_info}", fontsize=12, fontweight='bold')
    axes[0].set_ylabel("MAPE (%)", fontsize=11)
    axes[0].grid(axis='y', alpha=0.3, linestyle='--')
    
    # Add value label with std
    axes[0].text(0, mape + mape_std + 0.5, f"{mape:.1f}% ± {mape_std:.1f}%", 
                ha='center', va='bottom', fontsize=10, fontweight='bold',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))
    
    # 2. Error Distribution Boxplot
    bp = axes[1].boxplot(df_results['Error'], vert=True, patch_artist=True, 
                        boxprops=dict(facecolor='lightcoral', alpha=0.7))
    axes[1].set_title(f"Error Distribution\n{selection_info}", fontsize=12, fontweight='bold')
    axes[1].set_ylabel("Prediction Error (MPa)", fontsize=11)
    axes[1].grid(axis='y', alpha=0.3, linestyle='--')
    
    # Add error statistics to boxplot
    error_mean = np.mean(df_results['Error'])
    error_std = np.std(df_results['Error'])
    error_stats_text = f"Mean: {error_mean:.1f} MPa\nStd: {error_std:.1f} MPa"
    axes[1].text(0.95, 0.95, error_stats_text, transform=axes[1].transAxes,
                fontsize=9, ha='right', va='top',
                bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8))
    
    # Overall title
    plt.suptitle(f"Holdout Model Performance: {best_model_name}", fontsize=14, fontweight='bold', y=1.02)
    
    plt.tight_layout()
    plt.show()
    
    # === ADDED: EXPORTABLE SUMMARY TABLE ===
    print(f"\n📄 EXPORTABLE SUMMARY TABLE:")
    print(f"{'='*80}")
    
    summary_table = pd.DataFrame({
        'Metric': ['Model', 'Holdout Set', 'Samples', 'MAE (MPa)', 'MAPE (%)', 'MAPE Std (%)', 'R² Score'],
        'Value': [best_model_name, selection_info, str(len(df_results)), 
                 f"{mae:.2f}", f"{mape:.2f}", f"{mape_std:.2f}", f"{r2_holdout:.4f}"]
    })
    
    print(summary_table.to_string(index=False, justify='left'))
    print(f"{'='*80}")

else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for Holdout (Material: Zr-2.5 Nb):
#      Material  Ultimate Tensile Strength (MPa)  Predicted Ultimate Tensile Strength (MPa)     Error  Absolute Error  APE (%)
# 0   Zr-2.5 Nb                         836.5500                                   920.6945  -84.1445         84.1445  10.0585
# 1   Zr-2.5 Nb                         828.3700                                   920.6945  -92.3245         92.3245  11.1453
# 2   Zr-2.5 Nb                         836.7000                                   920.6945  -83.9945         83.9945  10.0388
# 3   Zr-2.5 Nb                         734.2500                                   920.6945 -186.4445        186.4445  25.3925
# 4   Zr-2.5 Nb                         828.6800                                   907.6445  -78.9645         78.9645   9.5289
# 5   Zr-2.5 Nb                         838.0000                                   907.6445  -69.6445         69.6445   8.3108
# ...

# %%
# Ensure holdout exists
if df_holdout is not None and best_pipeline is not None:
    target_column = 'Ultimate Tensile Strength (MPa)'
    
    X_holdout = df_holdout.drop(columns=[target_column])
    y_holdout = df_holdout[target_column]
    
    # Predict
    y_holdout_pred = best_pipeline.predict(X_holdout)
    
    # Combine results
    df_results = df_holdout.copy()
    df_results['Predicted Ultimate Tensile Strength (MPa)'] = y_holdout_pred
    df_results['Error'] = df_results[target_column] - df_results['Predicted Ultimate Tensile Strength (MPa)']
    df_results['Absolute Error'] = df_results['Error'].abs()
    
    # Full display
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    
    print(f"\n📌 Predictions for Holdout Material: {selected_material}")
    display(df_results[['Material', target_column, 'Predicted Ultimate tensile Strength (MPa)', 'Error', 'Absolute Error']])
    
    # Metrics
    mae = np.mean(df_results['Absolute Error'])
    r2_holdout = r2_score(y_holdout, y_holdout_pred)
    print(f"\n✅ Holdout Performance: MAE = {mae:.2f}, R² = {r2_holdout:.4f}")
else:
    print("❌ Holdout dataset or best model is not available.")
# Out:
# 📌 Predictions for Holdout Material: Zr-2.5 Nb
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[574], line 23
#      20 pd.set_option('display.width', None)
#      22 print(f"\n📌 Predictions for Holdout Material: {selected_material}")
# ---> 23 display(df_results[['Material', target_column, 'Predicted Ultimate tensile Strength (MPa)', 'Error', 'Absolute Error']])
#      25 # Metrics
#      26 mae = np.mean(df_results['Absolute Error'])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
from sklearn.metrics import r2_score

# Find best model based on R² on test set
best_r2 = -np.inf
best_model_name = None

for name, data in predictions.items():
    r2 = r2_score(data['y_test'], data['y_pred'])
    if r2 > best_r2:
        best_r2 = r2
        best_model_name = name

print(f"✅ Best model: {best_model_name} with R² = {best_r2:.4f}")
print("Best hyperparameters:", trained_models[best_model_name].best_params_)

# %%
X_holdout = df_holdout.drop(columns=['Ultimate Tensile Strength (MPa)'])
y_holdout_true = df_holdout['Ultimate Tensile Strength (MPa)']

# %%
# Get best trained model
best_pipeline = trained_models[best_model_name]

# Predict
y_holdout_pred = best_pipeline.predict(X_holdout)

# Combine results for inspection
df_results = df_holdout.copy()
df_results['Predicted Ultimate Tensile Strength (MPa)'] = y_holdout_pred
df_results['Error'] = df_results['Ultimate Tensile Strength (MPa)'] - df_results['Predicted Ultimate Tensile Strength (MPa)']

# Display results
import pandas as pd
display(df_results[['Material', 'Ultimate Tensile Strength (MPa)', 
                    'Predicted Ultimate Tensile Strength (MPa)', 'Error']])
# Out:
#   Material  Ultimate Tensile Strength (MPa)  Predicted Ultimate Tensile Strength (MPa)   Error
# 0      P91                         696.2000                                   610.9533 85.2467
# 1      P91                         710.4000                                   610.9533 99.4467

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

def plot_predicted_vs_actual():
    n_models = len(predictions)
    cols = 3  # number of plots per row
    rows = math.ceil(n_models / cols)

    fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 5*rows), sharex=True, sharey=True)
    axes = axes.flatten()

    for ax, (name, data) in zip(axes, predictions.items()):
        sns.scatterplot(x=data['y_test'], y=data['y_pred'], ax=ax)
        ax.plot([data['y_test'].min(), data['y_test'].max()],
                [data['y_test'].min(), data['y_test'].max()],
                'r--', lw=2)
        ax.set_title(name, fontsize=14)
        ax.set_xlabel("Actual")
        ax.set_ylabel("Predicted")

    # Hide any unused axes
    for ax in axes[len(predictions):]:
        ax.set_visible(False)

    plt.tight_layout()
    plt.show()

plot_predicted_vs_actual()

# %%
def show_top_features(feature_names):
    for name, search in trained_models.items():
        print(f"\n📊 Top features for {name}:")
        model = search.best_estimator_.named_steps['model']
        
        # Tree-based models
        if hasattr(model, 'feature_importances_'):
            importances = model.feature_importances_
            sorted_idx = np.argsort(importances)[::-1]
            for idx in sorted_idx[:10]:  # top 10
                print(f"{feature_names[idx]}: {importances[idx]:.4f}")
        
        # Linear models
        elif hasattr(model, 'coef_'):
            coefs = np.abs(model.coef_)
            sorted_idx = np.argsort(coefs)[::-1]
            for idx in sorted_idx[:10]:
                print(f"{feature_names[idx]}: {coefs[idx]:.4f}")
        else:
            print("⚠️ Feature importance not available for this model.")

# Get feature names from preprocessing step
feature_names = trained_models[list(trained_models.keys())[0]].best_estimator_.named_steps['preprocessor'].get_feature_names_out()
show_top_features(feature_names)
# Out:
# 📊 Top features for RandomForest:
# num__Sn (wt.%): 0.6431
# num__Co (wt.%): 0.1819
# num__Post Treatment Time (h): 0.0540
# num__Ta (wt.%): 0.0226
# num__Ti (wt.%): 0.0178
# num__Irradiation Dose (dpa): 0.0178
# num__Cr (wt.%): 0.0171
# num__N (wt.%): 0.0123
# num__Mo (wt.%): 0.0120
# num__Nb (wt.%): 0.0091
#
# 📊 Top features for DecisionTree:
# num__Sn (wt.%): 0.7499
# num__Co (wt.%): 0.1234
# num__N (wt.%): 0.0722
# num__Post Treatment Time (h): 0.0540
# num__Post Treatment Temperature (C): 0.0005
# num__Width (mm): 0.0000
# num__Nb (wt.%): 0.0000
# num__Fe (wt.%): 0.0000
# num__Ti (wt.%): 0.0000
# num__Al (wt.%): 0.0000
#
# 📊 Top features for SVR:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[907], line 24
#      22 # Get feature names from preprocessing step
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_feature_importances(trained_models_dict, top_n=10):
    if not trained_models_dict:
        print("No trained models found.")
        return

    for name, search in trained_models_dict.items():
        try:
            model = search.best_estimator_.named_steps['model']

            # Get feature names from preprocessor
            feature_names = search.best_estimator_ \
                                .named_steps['preprocessor'] \
                                .get_feature_names_out()

            # Tree-based models
            if hasattr(model, 'feature_importances_'):
                importances = model.feature_importances_
                sorted_idx = np.argsort(importances)[::-1][:top_n]

            # Linear models
            elif hasattr(model, 'coef_'):
                importances = np.abs(model.coef_)
                sorted_idx = np.argsort(importances)[::-1][:top_n]
            else:
                print(f"⚠️ Feature importance not available for {name}. Skipping...")
                continue

            top_features = np.array(feature_names)[sorted_idx]
            top_importances = importances[sorted_idx]

            # Plot
            plt.figure(figsize=(8, 5))
            sns.barplot(x=top_importances, y=top_features)
            plt.title(f"Top {top_n} Features - {name}")
            plt.xlabel("Importance")
            plt.ylabel("Feature")
            plt.tight_layout()
            plt.show()

        except Exception as e:
            print(f"❌ Skipping {name} due to error: {e}")

# Example usage:
plot_feature_importances(trained_models, top_n=10)
# Out:
# ❌ Skipping SVR due to error: index 31 is out of bounds for axis 0 with size 1
# ⚠️ Feature importance not available for KNN. Skipping...
# ⚠️ Feature importance not available for Bagging. Skipping...
# Exception ignored in: <function ResourceTracker.__del__ at 0x105669bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x106b1dbc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/opt/anaconda3/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
# ...

# %% [markdown]
# ### RESULTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("S1_YS_Results.xlsx")

materials = df["S1 Material"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

# Bar settings
n = len(materials)
height = 0.35
offset = height + 0.05
spacing = height * 3.5 + 0.4

y = np.arange(n) * spacing

fig_height = n * spacing * 0.35 + 1
fig, ax = plt.subplots(figsize=(7, fig_height))

# Three bars per material
ax.barh(y - offset, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + offset, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("S1 Material", fontsize=12)
ax.set_xlabel("MAPE (%)", fontsize=12)
ax.set_title("Scenario S1 — Yield Strength (YS)", fontsize=13)
ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=11)
ax.invert_yaxis()
ax.legend(frameon=False, fontsize=11)

ax.grid(False)
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)
ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("S1_UTS_Results.xlsx")

materials = df["S1 Material"]

h1_values = df["H1 MAPE (UTS)"]
h1_err = df["H1 UTS errors"]

h4_values = df["H4 MAPE (UTS)"]
h4_err = df["H4 UTS errors"]

h5_values = df["H5 MAPE (UTS)"]
h5_err = df["H5 UTS errors"]

n = len(materials)
height = 0.35
offset = height + 0.05
spacing = height * 3.5 + 0.4

y = np.arange(n) * spacing

fig_height = n * spacing * 0.35 + 1
fig, ax = plt.subplots(figsize=(7, fig_height))

ax.barh(y - offset, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + offset, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("S1 Material", fontsize=12)
ax.set_xlabel("MAPE (%)", fontsize=12)
ax.set_title("Scenario S1 — Ultimate Tensile Strength (UTS)", fontsize=13)
ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=11)
ax.invert_yaxis()
ax.legend(frameon=False, fontsize=11)

ax.grid(False)
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)
ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("S2_YS_Results.xlsx")

materials = df["S2 Material"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

n = len(materials)
height = 0.35
offset = height + 0.05
spacing = height * 4 + 0.4

y = np.arange(n) * spacing

fig_height = n * spacing * 0.35 + 1
fig, ax = plt.subplots(figsize=(7, fig_height))

ax.barh(y - offset, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + offset, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("S2 Material", fontsize=12)
ax.set_xlabel("MAPE (%)", fontsize=12)
ax.set_title("Scenario S2 — Yield Strength (YS)", fontsize=13)
ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=11)
ax.invert_yaxis()
ax.legend(frameon=False, fontsize=11)

ax.grid(False)
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)
ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("S2_UTS_Results.xlsx")

materials = df["S2 Material"]

h1_values = df["H1 MAPE (UTS)"]
h1_err = df["H1 UTS errors"]

h4_values = df["H4 MAPE (UTS)"]
h4_err = df["H4 UTS errors"]

h5_values = df["H5 MAPE (UTS)"]
h5_err = df["H5 UTS errors"]

n = len(materials)
height = 0.35
offset = height + 0.05
spacing = height * 4 + 0.4

y = np.arange(n) * spacing

fig_height = n * spacing * 0.35 + 1
fig, ax = plt.subplots(figsize=(7, fig_height))

ax.barh(y - offset, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + offset, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("S2 Material", fontsize=12)
ax.set_xlabel("MAPE (%)", fontsize=12)
ax.set_title("Scenario S2 — Ultimate Tensile Strength (UTS)", fontsize=13)
ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=11)
ax.invert_yaxis()
ax.legend(frameon=False, fontsize=11)

ax.grid(False)
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)
ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load and sort
df = pd.read_excel("H5_YS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

# Bar settings
n = len(materials)
width = 0.25   # narrower because 3 bars now
spacing = 1.4

x = np.arange(n) * spacing

fig_width = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(fig_width, 6))

# Bars
ax.bar(x - width, h1_values, width,
       yerr=h1_err, capsize=3,
       color="#1f77b4", label="H1")

ax.bar(x, h4_values, width,
       yerr=h4_err, capsize=3,
       color="#ff7f0e", label="H4")

ax.bar(x + width, h5_values, width,
       yerr=h5_err, capsize=3,
       color="#2ca02c", label="H5")

# Axis labels
ax.set_xlabel("Material", fontsize=15)
ax.set_ylabel("MAPE (%)", fontsize=15)
ax.set_title("", fontsize=13)

ax.set_xticks(x)
ax.set_xticklabels(materials, rotation=45, ha="right", fontsize=13)

ax.legend(frameon=False, fontsize=15)
ax.grid(False)

# ---- Panel Style Grouping ----
unique_scenarios = scenarios.unique()
start_idx = 0

y_top = ax.get_ylim()[1]

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    # Vertical separator (except first)
    if start_idx != 0:
        ax.axvline(x=x[start_idx] - spacing/2,
                   color='black', linewidth=1)

    # Midpoint of group
    mid_point = np.mean(x[indices])

    # Scenario label at TOP
    ax.text(mid_point, y_top * 1.05,
            f"{scenario}",
            ha='center',
            va='bottom',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

# Increase top margin
plt.subplots_adjust(top=0.85)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load and sort
df = pd.read_excel("H5_UTS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]   # ← corrected column name
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (UTS)"]
h1_err = df["H1 UTS errors"]

h4_values = df["H4 MAPE (UTS)"]
h4_err = df["H4 UTS errors"]

h5_values = df["H5 MAPE (UTS)"]
h5_err = df["H5 UTS errors"]

# Bar settings
n = len(materials)
width = 0.25
spacing = 1.4

x = np.arange(n) * spacing

fig_width = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(fig_width, 6))

# Bars
ax.bar(x - width, h1_values, width,
       yerr=h1_err, capsize=3,
       color="#1f77b4", label="H1")

ax.bar(x, h4_values, width,
       yerr=h4_err, capsize=3,
       color="#ff7f0e", label="H4")

ax.bar(x + width, h5_values, width,
       yerr=h5_err, capsize=3,
       color="#2ca02c", label="H5")

# Axis labels
ax.set_xlabel("Material", fontsize=15)
ax.set_ylabel("MAPE (%)", fontsize=15)
ax.set_title("", fontsize=13)

ax.set_xticks(x)
ax.set_xticklabels(materials, rotation=45, ha="right", fontsize=13)

ax.legend(frameon=False, fontsize=15)
ax.grid(False)

# ---- Panel Style Grouping ----
unique_scenarios = scenarios.unique()
start_idx = 0

y_top = ax.get_ylim()[1]

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    if start_idx != 0:
        ax.axvline(x=x[start_idx] - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(x[indices])

    ax.text(mid_point, y_top * 1.05,
            f"{scenario}",
            ha='center',
            va='bottom',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.subplots_adjust(top=0.85)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load and sort
df = pd.read_excel("H5_YS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

# Bar settings
n = len(materials)
height = 0.25
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

# Bars (horizontal now)
ax.barh(y - height, h1_values, height,
        xerr=h1_err, capsize=3,
        color="#1f77b4", label="H1")

ax.barh(y, h4_values, height,
        xerr=h4_err, capsize=3,
        color="#ff7f0e", label="H4")

ax.barh(y + height, h5_values, height,
        xerr=h5_err, capsize=3,
        color="#2ca02c", label="H5")

# Axis labels
ax.set_ylabel("Material", fontsize=15)
ax.set_xlabel("MAPE (%)", fontsize=15)
ax.set_title("", fontsize=13)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=13)

ax.legend(frameon=False, fontsize=15)
ax.grid(False)

# ---- Panel Style Grouping ----
unique_scenarios = scenarios.unique()
start_idx = 0

x_right = ax.get_xlim()[1]

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    # Horizontal separator (except first)
    if start_idx != 0:
        ax.axhline(y=y[start_idx] - spacing/2,
                   color='black', linewidth=1)

    # Midpoint of group
    mid_point = np.mean(y[indices])

    # Scenario label on right
    ax.text(x_right * 1.02, mid_point,
            f"{scenario}",
            va='center',
            ha='left',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

# Invert so first material is at top (cleaner look)
ax.invert_yaxis()

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

# Increase right margin for scenario labels
plt.subplots_adjust(right=0.85)

plt.tight_layout()

# ===== ADD THIS LINE TO DOWNLOAD =====
plt.savefig('H5YScomparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load and sort
df = pd.read_excel("H5_UTS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (UTS)"]
h1_err = df["H1 UTS errors"]

h4_values = df["H4 MAPE (UTS)"]
h4_err = df["H4 UTS errors"]

h5_values = df["H5 MAPE (UTS)"]
h5_err = df["H5 UTS errors"]

# Bar settings
n = len(materials)
height = 0.25
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

# Horizontal bars
ax.barh(y - height, h1_values, height,
        xerr=h1_err, capsize=3,
        color="#1f77b4", label="H1")

ax.barh(y, h4_values, height,
        xerr=h4_err, capsize=3,
        color="#ff7f0e", label="H4")

ax.barh(y + height, h5_values, height,
        xerr=h5_err, capsize=3,
        color="#2ca02c", label="H5")

# Axis labels
ax.set_ylabel("Material", fontsize=15)
ax.set_xlabel("MAPE (%)", fontsize=15)
ax.set_title("", fontsize=13)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=13)

ax.legend(frameon=False, fontsize=15)
ax.grid(False)

# ---- Panel Style Grouping ----
unique_scenarios = scenarios.unique()
start_idx = 0

x_right = ax.get_xlim()[1]

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    # Horizontal separator
    if start_idx != 0:
        ax.axhline(y=y[start_idx] - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y[indices])

    # Scenario label on right
    ax.text(x_right * 1.02, mid_point,
            f"{scenario}",
            va='center',
            ha='left',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

# Invert for top-to-bottom logical order
ax.invert_yaxis()

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

# Make space on right for scenario labels
plt.subplots_adjust(right=0.85)

plt.tight_layout()
# ===== ADD THIS LINE TO DOWNLOAD =====
plt.savefig('H5YScomparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("H5_YS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

n = len(materials)
height = 0.25
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

ax.barh(y - height, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + height, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("Material", fontsize=15)
ax.set_xlabel("MAPE (%)", fontsize=15)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=13)

ax.legend(frameon=False, fontsize=15)
ax.grid(False)

# ---- Panel Grouping with Internal Labels ----
unique_scenarios = scenarios.unique()
start_idx = 0

x_inside = ax.get_xlim()[1] * 0.97  # inside right boundary

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    if start_idx != 0:
        ax.axhline(y=y[start_idx] - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y[indices])

    # Offset slightly downward so it doesn’t overlap a bar
    ax.text(x_inside, mid_point + height*1.2,
            f"{scenario}",
            va='center',
            ha='right',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

ax.invert_yaxis()

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("H5_YS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h2_values = df["H2 MAPE (YS)"]
h2_err = df["H2 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

n = len(materials)

# Slightly smaller height since now 4 bars
height = 0.18
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

# ---- 4 Model Bars ----
ax.barh(y - 1.5*height, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y - 0.5*height, h2_values, height, xerr=h2_err,
        capsize=3, color="#9467bd", label="H2")

ax.barh(y + 0.5*height, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + 1.5*height, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

# ---- Labels ----
ax.set_ylabel("Material", fontsize=15)
ax.set_xlabel("MAPE (%)", fontsize=15)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=13)

ax.legend(frameon=False, fontsize=13)
ax.grid(False)

# ---- Panel Grouping ----
unique_scenarios = scenarios.unique()
start_idx = 0

x_inside = max(
    h1_values.max(),
    h2_values.max(),
    h4_values.max(),
    h5_values.max()
) * 0.97

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    if start_idx != 0:
        ax.axhline(y=y[start_idx] - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y[indices])

    ax.text(x_inside, mid_point - height*1.5,
            f"{scenario}",
            va='center',
            ha='right',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

ax.invert_yaxis()

# ---- Publication Box ----
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[589], line 70
#      68 for scenario in unique_scenarios:
#      69     indices = np.where(scenarios == scenario)[0]
# ---> 70     end_idx = indices[-1]
#      72     if start_idx != 0:
#      73         ax.axhline(y=y[start_idx] - spacing/2,
#      74                    color='black', linewidth=1)
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("H5_YS_Results.xlsx")
df = df.sort_values("Scenario")

materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

n = len(materials)
height = 0.25
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

ax.barh(y - height, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + height, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("Material", fontsize=15)
ax.set_xlabel("MAPE (%)", fontsize=15)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=13)

ax.legend(frameon=False, fontsize=15)
ax.grid(False)

# ---- Panel Grouping with Corrected Internal Labels ----
unique_scenarios = scenarios.unique()
start_idx = 0

x_inside = ax.get_xlim()[1] * 0.97

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    if start_idx != 0:
        ax.axhline(y=y[start_idx] - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y[indices])

    # Shift upward slightly (negative direction after invert)
    ax.text(x_inside, mid_point - height*1.2,
            f"{scenario}",
            va='center',
            ha='right',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

ax.invert_yaxis()

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[588], line 58
#      56 for scenario in unique_scenarios:
#      57     indices = np.where(scenarios == scenario)[0]
# ---> 58     end_idx = indices[-1]
#      60     if start_idx != 0:
#      61         ax.axhline(y=y[start_idx] - spacing/2,
#      62                    color='black', linewidth=1)
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Load and sort
# -----------------------------
df = pd.read_excel("H5_YS_Results.xlsx")
df = df.sort_values("Scenario").reset_index(drop=True)

# -----------------------------
# Extract columns
# -----------------------------
materials = df["Material"]
scenarios = df["Scenario"]

h1_values = df["H1 MAPE (YS)"]
h1_err = df["H1 YS errors"]

h2_values = df["H2 MAPE (YS)"]
h2_err = df["H2 YS errors"]

h4_values = df["H4 MAPE (YS)"]
h4_err = df["H4 YS errors"]

h5_values = df["H5 MAPE (YS)"]
h5_err = df["H5 YS errors"]

# -----------------------------
# Layout parameters
# -----------------------------
n = len(materials)
height = 0.18
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

# -----------------------------
# Plot bars (4 models)
# -----------------------------
ax.barh(y - 1.5*height, h1_values, height,
        xerr=h1_err, capsize=3,
        color="#1f77b4", label="H1")

ax.barh(y - 0.5*height, h2_values, height,
        xerr=h2_err, capsize=3,
        color="#9467bd", label="H2")

ax.barh(y + 0.5*height, h4_values, height,
        xerr=h4_err, capsize=3,
        color="#ff7f0e", label="H4")

ax.barh(y + 1.5*height, h5_values, height,
        xerr=h5_err, capsize=3,
        color="#2ca02c", label="H5")

# -----------------------------
# Axis labels
# -----------------------------
ax.set_ylabel("Material", fontsize=15)
ax.set_xlabel("MAPE (%)", fontsize=15)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=13)

ax.legend(frameon=False, fontsize=13)
ax.grid(False)

# -----------------------------
# Scenario Grouping (Robust)
# -----------------------------
grouped = df.groupby("Scenario", sort=False)

for i, (scenario, group) in enumerate(grouped):

    indices = group.index.to_numpy()
    y_positions = y[indices]

    if i != 0:
        ax.axhline(y=y_positions.min() - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y_positions)

    ax.text(ax.get_xlim()[1] * 0.97,
            mid_point,
            f"{scenario}",
            va='center',
            ha='right',
            fontsize=16,
            fontweight='bold')

# -----------------------------
# Final formatting
# -----------------------------
ax.invert_yaxis()

# Publication-style border box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.tight_layout()

# ===== ADD THIS LINE TO DOWNLOAD =====
plt.savefig('H5YScomparison.png', dpi=300, bbox_inches='tight')

plt.show()

# -----------------------------
# Optional: Save for journal
# -----------------------------
# plt.savefig("YS_MAPE_comparison.pdf", dpi=600, bbox_inches="tight")
# plt.savefig("YS_MAPE_comparison.svg", dpi=600, bbox_inches="tight")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Load data
# -----------------------------
df = pd.read_excel("H5_UTS_Results.xlsx")
df = df.sort_values("Scenario").reset_index(drop=True)

materials = df["Material"]
scenarios = df["Scenario"]

# -----------------------------
# Extract metrics
# -----------------------------
h1_values = df["H1 MAPE (UTS)"]
h1_err = df["H1 UTS errors"]

h2_values = df["H2 MAPE (UTS)"]
h2_err = df["H2 UTS errors"]

h4_values = df["H4 MAPE (UTS)"]
h4_err = df["H4 UTS errors"]

h5_values = df["H5 MAPE (UTS)"]
h5_err = df["H5 UTS errors"]

# -----------------------------
# Layout
# -----------------------------
n = len(materials)
height = 0.18
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

# -----------------------------
# Bars (4 models)
# -----------------------------
ax.barh(y - 1.5*height, h1_values, height,
        xerr=h1_err, capsize=3,
        color="#1f77b4", label="H1")

ax.barh(y - 0.5*height, h2_values, height,
        xerr=h2_err, capsize=3,
        color="#9467bd", label="H2")

ax.barh(y + 0.5*height, h4_values, height,
        xerr=h4_err, capsize=3,
        color="#ff7f0e", label="H4")

ax.barh(y + 1.5*height, h5_values, height,
        xerr=h5_err, capsize=3,
        color="#2ca02c", label="H5")

# -----------------------------
# Labels
# -----------------------------
ax.set_ylabel("Material", fontsize=16)
ax.set_xlabel("MAPE (%)", fontsize=16)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=16)

ax.legend(frameon=False, fontsize=16)
ax.grid(False)

# -----------------------------
# Robust Scenario Grouping
# -----------------------------
grouped = df.groupby("Scenario", sort=False)

for i, (scenario, group) in enumerate(grouped):

    indices = group.index.to_numpy()
    y_positions = y[indices]

    if i != 0:
        ax.axhline(y=y_positions.min() - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y_positions)

    ax.text(ax.get_xlim()[1] * 0.97,
            mid_point,
            f"{scenario}",
            va='center',
            ha='right',
            fontsize=16,
            fontweight='bold')

# -----------------------------
# Final formatting
# -----------------------------
ax.invert_yaxis()

# Publication-style box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.tight_layout()

# ===== ADD THIS LINE TO DOWNLOAD =====
plt.savefig('H5UTScomparison.png', dpi=300, bbox_inches='tight')

plt.show()

# -----------------------------
# Optional export (journal-ready)
# -----------------------------
# plt.savefig("UTS_MAPE_comparison.pdf", dpi=600, bbox_inches="tight")
# plt.savefig("UTS_MAPE_comparison.svg", dpi=600, bbox_inches="tight")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("H5_UTS_Results.xlsx")

h1_values = df["H1 MAPE (UTS)"]
h1_err = df["H1 UTS errors"]

h2_values = df["H2 MAPE (UTS)"]
h2_err = df["H2 UTS errors"]

h4_values = df["H4 MAPE (UTS)"]
h4_err = df["H4 UTS errors"]

h5_values = df["H5 MAPE (UTS)"]
h5_err = df["H5 UTS errors"]

n = len(materials)
height = 0.25
spacing = 1.4

y = np.arange(n) * spacing

fig_height = n * 0.6 + 2
fig, ax = plt.subplots(figsize=(8, fig_height))

ax.barh(y - height, h1_values, height, xerr=h1_err,
        capsize=3, color="#1f77b4", label="H1")

ax.barh(y, h4_values, height, xerr=h4_err,
        capsize=3, color="#ff7f0e", label="H4")

ax.barh(y + height, h5_values, height, xerr=h5_err,
        capsize=3, color="#2ca02c", label="H5")

ax.set_ylabel("Material", fontsize=16)
ax.set_xlabel("MAPE (%)", fontsize=16)

ax.set_yticks(y)
ax.set_yticklabels(materials, fontsize=16)

ax.legend(frameon=False, fontsize=16)
ax.grid(False)

# ---- Panel Grouping with Internal Labels ----
unique_scenarios = scenarios.unique()
start_idx = 0

x_inside = ax.get_xlim()[1] * 0.97  # inside right boundary

for scenario in unique_scenarios:
    indices = np.where(scenarios == scenario)[0]
    end_idx = indices[-1]

    if start_idx != 0:
        ax.axhline(y=y[start_idx] - spacing/2,
                   color='black', linewidth=1)

    mid_point = np.mean(y[indices])

    # Offset slightly downward so it doesn’t overlap a bar
    ax.text(x_inside, mid_point + height*1.2,
            f"{scenario}",
            va='center',
            ha='right',
            fontsize=13,
            fontweight='bold')

    start_idx = end_idx + 1

ax.invert_yaxis()

# Black publication box
for spine in ax.spines.values():
    spine.set_color("black")
    spine.set_linewidth(1.2)

ax.tick_params(axis='both', colors='black')

plt.tight_layout()
plt.show()
