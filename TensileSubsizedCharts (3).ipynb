# %%
import pandas as pd

# Define the data
data = [
    [0, 'JPCA', 183.7000, 215.0716, -31.3716, 31.3716],
    [1, 'JPCA', 241.1700, 265.2945, -24.1245, 24.1245],
    [2, 'JPCA', 262.1600, 265.2945, -3.1345, 3.1345],
    [3, 'JPCA', 268.4800, 265.2945, 3.1855, 3.1855],
    [4, 'JPCA', 218.9100, 265.2945, -46.3845, 46.3845],
    [5, 'JPCA', 256.0900, 265.2945, -9.2045, 9.2045],
    [6, 'JPCA', 273.3500, 265.2945, 8.0555, 8.0555],
    [7, 'JPCA', 304.2700, 265.2945, 38.9755, 38.9755],
    [8, 'JPCA', 257.6400, 265.2945, -7.6545, 7.6545],
    [9, 'JPCA', 206.5000, 252.7761, -46.2761, 46.2761],
    [10, 'JPCA', 239.3000, 261.7681, -22.4681, 22.4681],
    [11, 'JPCA', 266.6900, 261.7681, 4.9219, 4.9219],
    [12, 'JPCA', 239.1700, 261.7681, -22.5981, 22.5981],
    [13, 'JPCA', 254.4900, 261.7681, -7.2781, 7.2781],
    [14, 'JPCA', 244.0700, 261.7681, -17.6981, 17.6981],
    [15, 'JPCA', 241.2400, 261.7681, -20.5281, 20.5281],
    [16, 'JPCA', 256.6600, 261.7681, -5.1081, 5.1081],
    [17, 'JPCA', 180.0900, 223.2266, -43.1366, 43.1366],
    [18, 'JPCA', 197.2400, 256.3024, -59.0624, 59.0624],
    [19, 'JPCA', 232.7700, 265.2945, -32.5245, 32.5245],
    [20, 'JPCA', 222.9700, 265.2945, -42.3245, 42.3245],
    [21, 'JPCA', 248.7000, 265.2945, -16.5945, 16.5945],
    [22, 'JPCA', 267.0800, 265.2945, 1.7855, 1.7855],
    [23, 'JPCA', 265.8500, 265.2945, 0.5555, 0.5555],
    [24, 'JPCA', 242.5700, 265.2945, -22.7245, 22.7245],
    [25, 'JPCA', 234.0000, 265.2945, -31.2945, 31.2945],
    # Add rows 26–74 similarly...
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Display the DataFrame
print(df)
# Out:
#     Index Material  Actual Yield Strength (MPa)  \
# 0       0     JPCA                       183.70
# 1       1     JPCA                       241.17
# 2       2     JPCA                       262.16
# 3       3     JPCA                       268.48
# 4       4     JPCA                       218.91
# 5       5     JPCA                       256.09
# 6       6     JPCA                       273.35
# 7       7     JPCA                       304.27
# 8       8     JPCA                       257.64
# 9       9     JPCA                       206.50
# 10     10     JPCA                       239.30
# 11     11     JPCA                       266.69
# 12     12     JPCA                       239.17
# 13     13     JPCA                       254.49
# 14     14     JPCA                       244.07
# 15     15     JPCA                       241.24
# 16     16     JPCA                       256.66
# 17     17     JPCA                       180.09
# ...

# %%
import pandas as pd

# Full dataset from indices 0–74
data = [
    [0, 'JPCA', 183.7000, 215.0716, -31.3716, 31.3716],
    [1, 'JPCA', 241.1700, 265.2945, -24.1245, 24.1245],
    [2, 'JPCA', 262.1600, 265.2945, -3.1345, 3.1345],
    [46, 'JPCA', 489.2300, 496.4371, -7.2071, 7.2071],
    [47, 'JPCA', 486.6900, 498.9399, -12.2499, 12.2499],
    [48, 'JPCA', 491.7700, 496.4371, -4.6671, 4.6671],
    [49, 'JPCA', 456.1700, 496.4371, -40.2671, 40.2671],
    [50, 'JPCA', 727.4700, 639.3681, 88.1019, 88.1019],
    [51, 'JPCA', 697.1800, 615.8444, 81.3356, 81.3356],
    [52, 'JPCA', 690.8900, 607.6478, 83.2422, 83.2422],
    [53, 'JPCA', 201.0600, 241.5979, -40.8979, 40.8979],
    [54, 'JPCA', 196.8600, 238.4316, -41.5716, 41.5716],
    [55, 'JPCA', 175.0900, 238.4316, -63.3416, 63.3416],
    [56, 'JPCA', 736.4400, 638.3444, 98.0956, 98.0956],
    [57, 'JPCA', 655.5200, 614.8207, 40.6993, 40.6993],
    [58, 'JPCA', 731.5200, 695.0758, 36.4442, 36.4442],
    [59, 'JPCA', 704.9400, 671.5521, 33.3879, 33.3879],
    [60, 'JPCA', 679.2000, 657.4234, 21.7766, 21.7766],
    [61, 'JPCA', 767.7400, 681.1287, 86.6113, 86.6113],
    [62, 'JPCA', 761.0700, 657.6050, 103.4650, 103.4650],
    [63, 'JPCA', 364.0000, 360.0871, 3.9129, 3.9129],
    [64, 'JPCA', 393.8400, 317.9444, 75.8956, 75.8956],
    [65, 'JPCA', 396.1700, 281.6225, 114.5475, 114.5475],
    [66, 'JPCA', 353.2900, 317.9008, 35.3892, 35.3892],
    [67, 'JPCA', 362.3800, 302.9613, 59.4187, 59.4187],
    [68, 'JPCA', 399.1700, 432.9457, -33.7757, 33.7757],
    [69, 'JPCA', 271.0500, 360.1821, -89.1321, 89.1321],
    [70, 'JPCA', 354.7300, 393.3009, -38.5709, 38.5709],
    [71, 'JPCA', 329.8500, 390.7594, -60.9094, 60.9094],
    [72, 'JPCA', 220.5600, 178.6900, 41.8700, 41.8700],
    [73, 'JPCA', 165.5800, 211.6849, -46.1049, 46.1049],
    [74, 'JPCA', 163.3400, 196.7455, -33.4055, 33.4055],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Display the DataFrame
print(df)
# Out:
#     Index Material  Actual Yield Strength (MPa)  \
# 0       0     JPCA                       183.70
# 1       1     JPCA                       241.17
# 2       2     JPCA                       262.16
# 3       3     JPCA                       268.48
# 4       4     JPCA                       218.91
# ..    ...      ...                          ...
# 70     70     JPCA                       354.73
# 71     71     JPCA                       329.85
# 72     72     JPCA                       220.56
# 73     73     JPCA                       165.58
# 74     74     JPCA                       163.34
#
#     Predicted Yield Strength (MPa)  Error (MPa)  Absolute Error (MPa)
# 0                         215.0716     -31.3716               31.3716
# 1                         265.2945     -24.1245               24.1245
# 2                         265.2945      -3.1345                3.1345
# 3                         265.2945       3.1855                3.1855
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
    [44, 'JPCA', 489.2300, 496.4371, -7.2071, 7.2071],
    [45, 'JPCA', 463.8000, 496.4371, -32.6371, 32.6371],
    [46, 'JPCA', 489.2300, 496.4371, -7.2071, 7.2071],
    [47, 'JPCA', 486.6900, 498.9399, -12.2499, 12.2499],
    [48, 'JPCA', 491.7700, 496.4371, -4.6671, 4.6671],
    [49, 'JPCA', 456.1700, 496.4371, -40.2671, 40.2671],
    [50, 'JPCA', 727.4700, 639.3681, 88.1019, 88.1019],
    [51, 'JPCA', 697.1800, 615.8444, 81.3356, 81.3356],
    [52, 'JPCA', 690.8900, 607.6478, 83.2422, 83.2422],
    [53, 'JPCA', 201.0600, 241.5979, -40.8979, 40.8979],
    [54, 'JPCA', 196.8600, 238.4316, -41.5716, 41.5716],
    [55, 'JPCA', 175.0900, 238.4316, -63.3416, 63.3416],
    [56, 'JPCA', 736.4400, 638.3444, 98.0956, 98.0956],
    [57, 'JPCA', 655.5200, 614.8207, 40.6993, 40.6993],
    [58, 'JPCA', 731.5200, 695.0758, 36.4442, 36.4442],
    [59, 'JPCA', 704.9400, 671.5521, 33.3879, 33.3879],
    [60, 'JPCA', 679.2000, 657.4234, 21.7766, 21.7766],
    [61, 'JPCA', 767.7400, 681.1287, 86.6113, 86.6113],
    [62, 'JPCA', 761.0700, 657.6050, 103.4650, 103.4650],
    [63, 'JPCA', 364.0000, 360.0871, 3.9129, 3.9129],
    [64, 'JPCA', 393.8400, 317.9444, 75.8956, 75.8956],
    [65, 'JPCA', 396.1700, 281.6225, 114.5475, 114.5475],
    [66, 'JPCA', 353.2900, 317.9008, 35.3892, 35.3892],
    [67, 'JPCA', 362.3800, 302.9613, 59.4187, 59.4187],
    [68, 'JPCA', 399.1700, 432.9457, -33.7757, 33.7757],
    [69, 'JPCA', 271.0500, 360.1821, -89.1321, 89.1321],
    [70, 'JPCA', 354.7300, 393.3009, -38.5709, 38.5709],
    [71, 'JPCA', 329.8500, 390.7594, -60.9094, 60.9094],
    [72, 'JPCA', 220.5600, 178.6900, 41.8700, 41.8700],
    [73, 'JPCA', 165.5800, 211.6849, -46.1049, 46.1049],
    [74, 'JPCA', 163.3400, 196.7455, -33.4055, 33.4055],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Create the scatter plot with regression line
plt.figure(figsize=(12, 10))

# Scatter plot with color based on density
scatter = plt.scatter(df['Actual Yield Strength (MPa)'], 
                     df['Predicted Yield Strength (MPa)'], 
                     c=df['Absolute Error (MPa)'], 
                     cmap='viridis', alpha=0.7, s=60, 
                     edgecolors='black', linewidth=0.5)

# Calculate regression line
X = df['Actual Yield Strength (MPa)'].values.reshape(-1, 1)
y = df['Predicted Yield Strength (MPa)'].values
reg = LinearRegression()
reg.fit(X, y)

# Predictions for regression line
x_line = np.linspace(df['Actual Yield Strength (MPa)'].min(), 
                     df['Actual Yield Strength (MPa)'].max(), 100)
y_line = reg.predict(x_line.reshape(-1, 1))

# Plot regression line
plt.plot(x_line, y_line, color='red', linewidth=3, 
         label=f'Regression line: y = {reg.coef_[0]:.3f}x + {reg.intercept_:.3f}')

# Perfect prediction line (y = x)
min_val = min(df['Actual Yield Strength (MPa)'].min(), df['Predicted Yield Strength (MPa)'].min())
max_val = max(df['Actual Yield Strength (MPa)'].max(), df['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', alpha=0.7, linewidth=2,
         label='Perfect prediction (y = x)')

# Calculate statistics
r2 = r2_score(df['Actual Yield Strength (MPa)'], df['Predicted Yield Strength (MPa)'])
rmse = np.sqrt(mean_squared_error(df['Actual Yield Strength (MPa)'], df['Predicted Yield Strength (MPa)']))
mae = df['Absolute Error (MPa)'].mean()

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=14, fontweight='bold')
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=14, fontweight='bold')
plt.title('Regression Analysis: Predicted vs Actual Yield Strength (JPCA Material)', 
          fontsize=16, fontweight='bold')

# Add colorbar for absolute error
cbar = plt.colorbar(scatter)
cbar.set_label('Absolute Error (MPa)', fontsize=12, fontweight='bold')

# Add grid
plt.grid(True, alpha=0.3)

# Add statistics text box
stats_text = f'R² = {r2:.3f}\nRMSE = {rmse:.2f} MPa\nMAE = {mae:.2f} MPa\nn = {len(df)}'
plt.annotate(stats_text, xy=(0.05, 0.75), xycoords='axes fraction', 
             bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
             fontsize=11, fontweight='bold')

plt.legend(fontsize=11, loc='lower right')
plt.tight_layout()
plt.show()

# Print detailed statistics
print("="*60)
print("REGRESSION ANALYSIS SUMMARY")
print("="*60)
print(f"Number of data points: {len(df)}")
print(f"R-squared: {r2:.4f}")
print(f"Root Mean Square Error (RMSE): {rmse:.4f} MPa")
print(f"Mean Absolute Error (MAE): {mae:.4f} MPa")
print(f"Regression Equation: y = {reg.coef_[0]:.4f}x + {reg.intercept_:.4f}")
print(f"Slope: {reg.coef_[0]:.4f}")
print(f"Intercept: {reg.intercept_:.4f} MPa")
print("="*60)

# Additional analysis: Error distribution
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(df['Error (MPa)'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
plt.xlabel('Prediction Error (MPa)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Prediction Errors', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.scatter(df['Actual Yield Strength (MPa)'], df['Error (MPa)'], alpha=0.7, color='red')
plt.axhline(y=0, color='black', linestyle='--', alpha=0.7)
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Prediction Error (MPa)', fontsize=12)
plt.title('Error vs Actual Value', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ...
# REGRESSION ANALYSIS SUMMARY
# ...
# Number of data points: 75
# R-squared: 0.9274
# Root Mean Square Error (RMSE): 44.1316 MPa
# Mean Absolute Error (MAE): 34.3369 MPa
# Regression Equation: y = 0.8250x + 64.5960
# Slope: 0.8250
# Intercept: 64.5960 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Full dataset from indices 0–74
data = [
    [0, 'JPCA', 183.7000, 215.0716, -31.3716, 31.3716],
    [1, 'JPCA', 241.1700, 265.2945, -24.1245, 24.1245],
    [2, 'JPCA', 262.1600, 265.2945, -3.1345, 3.1345],
    [3, 'JPCA', 268.4800, 265.2945, 3.1855, 3.1855],
    [4, 'JPCA', 218.9100, 265.2945, -46.3845, 46.3845],
    [48, 'JPCA', 491.7700, 496.4371, -4.6671, 4.6671],
    [49, 'JPCA', 456.1700, 496.4371, -40.2671, 40.2671],
    [50, 'JPCA', 727.4700, 639.3681, 88.1019, 88.1019],
    [51, 'JPCA', 697.1800, 615.8444, 81.3356, 81.3356],
    [52, 'JPCA', 690.8900, 607.6478, 83.2422, 83.2422],
    [53, 'JPCA', 201.0600, 241.5979, -40.8979, 40.8979],
    [54, 'JPCA', 196.8600, 238.4316, -41.5716, 41.5716],
    [55, 'JPCA', 175.0900, 238.4316, -63.3416, 63.3416],
    [56, 'JPCA', 736.4400, 638.3444, 98.0956, 98.0956],
    [57, 'JPCA', 655.5200, 614.8207, 40.6993, 40.6993],
    [58, 'JPCA', 731.5200, 695.0758, 36.4442, 36.4442],
    [59, 'JPCA', 704.9400, 671.5521, 33.3879, 33.3879],
    [60, 'JPCA', 679.2000, 657.4234, 21.7766, 21.7766],
    [61, 'JPCA', 767.7400, 681.1287, 86.6113, 86.6113],
    [62, 'JPCA', 761.0700, 657.6050, 103.4650, 103.4650],
    [63, 'JPCA', 364.0000, 360.0871, 3.9129, 3.9129],
    [64, 'JPCA', 393.8400, 317.9444, 75.8956, 75.8956],
    [65, 'JPCA', 396.1700, 281.6225, 114.5475, 114.5475],
    [66, 'JPCA', 353.2900, 317.9008, 35.3892, 35.3892],
    [67, 'JPCA', 362.3800, 302.9613, 59.4187, 59.4187],
    [68, 'JPCA', 399.1700, 432.9457, -33.7757, 33.7757],
    [69, 'JPCA', 271.0500, 360.1821, -89.1321, 89.1321],
    [70, 'JPCA', 354.7300, 393.3009, -38.5709, 38.5709],
    [71, 'JPCA', 329.8500, 390.7594, -60.9094, 60.9094],
    [72, 'JPCA', 220.5600, 178.6900, 41.8700, 41.8700],
    [73, 'JPCA', 165.5800, 211.6849, -46.1049, 46.1049],
    [74, 'JPCA', 163.3400, 196.7455, -33.4055, 33.4055],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df['Actual Yield Strength (MPa)'], 
           df['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df['Actual Yield Strength (MPa)'].min(), df['Predicted Yield Strength (MPa)'].min())
max_val = max(df['Actual Yield Strength (MPa)'].max(), df['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('JPCA: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# UTS data from both images
uts_data = [
    ['JPCA', 537.2800, 837.8275, -300.5475],
    ['JPCA', 773.7300, 828.5405, -54.8105],
    ['JPCA', 816.5100, 842.7810, -26.2710],
    ['JPCA', 858.2900, 842.7810, 15.5090],
    ['JPCA', 891.8500, 848.4032, 43.4468],
    ['JPCA', 910.7200, 834.1578, 76.5622],
    ['JPCA', 818.3300, 822.3071, -3.9771],
    ['JPCA', 527.3300, 703.7130, -176.3830],
    ['JPCA', 691.7900, 799.1683, -107.3783],
    ['JPCA', 832.6500, 831.8833, 0.7667],
    ['JPCA', 871.7900, 831.8833, 39.9067],
    ['JPCA', 928.9400, 854.9587, 73.9813],
    ['JPCA', 888.4900, 837.7851, 50.7049],
    ['JPCA', 868.8900, 854.9587, 13.9313],
    ['JPCA', 837.5400, 852.4641, -14.9241],
    ['JPCA', 841.5000, 837.7851, 3.7149],
    ['JPCA', 829.7100, 852.4641, -22.7541],
    ['JPCA', 920.5800, 863.4360, 57.1440],
    ['JPCA', 894.4700, 863.4360, 31.0340],
    ['JPCA', 893.2000, 863.4360, 29.7640],
    ['JPCA', 553.0100, 837.7851, -284.7751],
    ['JPCA', 540.8600, 667.3728, -126.5128],
    ['JPCA', 556.2900, 661.1155, -104.8255],
    ['JPCA', 902.8900, 900.9423, 1.9477],
    ['JPCA', 900.6100, 902.1888, -1.5788],
    ['JPCA', 927.9600, 903.6877, 24.2723],
    ['JPCA', 884.3400, 892.2885, -7.9485],
    ['JPCA', 909.3200, 904.4390, 4.8810],
    ['JPCA', 930.7300, 927.0947, 3.6353],
    ['JPCA', 934.1800, 928.7272, 5.4528],
    ['JPCA', 937.7700, 921.0858, 16.6842],
    ['JPCA', 915.3100, 920.6588, -5.3488],
    ['JPCA', 965.0700, 945.3820, 19.6880],
    ['JPCA', 726.2600, 715.1973, 11.0627],
    ['JPCA', 720.4100, 745.1686, -24.7586],
    ['JPCA', 705.5300, 752.6537, -47.1237],
    ['JPCA', 710.8900, 745.6697, -34.7797],
    ['JPCA', 754.4800, 752.3344, 2.1456],
    ['JPCA', 738.7000, 749.2192, -10.5192],
    ['JPCA', 757.6100, 758.2943, -0.6843],
    ['JPCA', 742.7000, 763.0038, -20.3038],
    ['JPCA', 748.0500, 756.0198, -7.9698],
    ['JPCA', 769.9800, 762.6845, 7.2955],
]

# Create DataFrame
df_uts = pd.DataFrame(uts_data, columns=[
    'Material', 'Ultimate Tensile Strength (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Display the DataFrame
print(df_uts)
# Out:
#    Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  Error (MPa)
# 0      JPCA                           537.28             837.8275    -300.5475
# 1      JPCA                           773.73             828.5405     -54.8105
# 2      JPCA                           816.51             842.7810     -26.2710
# 3      JPCA                           858.29             842.7810      15.5090
# 4      JPCA                           891.85             848.4032      43.4468
# 5      JPCA                           910.72             834.1578      76.5622
# 6      JPCA                           818.33             822.3071      -3.9771
# 7      JPCA                           527.33             703.7130    -176.3830
# 8      JPCA                           691.79             799.1683    -107.3783
# 9      JPCA                           832.65             831.8833       0.7667
# 10     JPCA                           871.79             831.8833      39.9067
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# UTS data from both images
uts_data = [
    ['JPCA', 537.2800, 837.8275, -300.5475],
    ['JPCA', 773.7300, 828.5405, -54.8105],
    ['JPCA', 816.5100, 842.7810, -26.2710],
    ['JPCA', 858.2900, 842.7810, 15.5090],
    ['JPCA', 891.8500, 848.4032, 43.4468],
    ['JPCA', 910.7200, 834.1578, 76.5622],
    ['JPCA', 818.3300, 822.3071, -3.9771],
    ['JPCA', 527.3300, 703.7130, -176.3830],
    ['JPCA', 691.7900, 799.1683, -107.3783],
    ['JPCA', 832.6500, 831.8833, 0.7667],
    ['JPCA', 871.7900, 831.8833, 39.9067],
    ['JPCA', 928.9400, 854.9587, 73.9813],
    ['JPCA', 888.4900, 837.7851, 50.7049],
    ['JPCA', 868.8900, 854.9587, 13.9313],
    ['JPCA', 837.5400, 852.4641, -14.9241],
    ['JPCA', 841.5000, 837.7851, 3.7149],
    ['JPCA', 829.7100, 852.4641, -22.7541],
    ['JPCA', 920.5800, 863.4360, 57.1440],
    ['JPCA', 894.4700, 863.4360, 31.0340],
    ['JPCA', 893.2000, 863.4360, 29.7640],
    ['JPCA', 553.0100, 837.7851, -284.7751],
    ['JPCA', 540.8600, 667.3728, -126.5128],
    ['JPCA', 556.2900, 661.1155, -104.8255],
    ['JPCA', 902.8900, 900.9423, 1.9477],
    ['JPCA', 900.6100, 902.1888, -1.5788],
    ['JPCA', 927.9600, 903.6877, 24.2723],
    ['JPCA', 884.3400, 892.2885, -7.9485],
    ['JPCA', 909.3200, 904.4390, 4.8810],
    ['JPCA', 930.7300, 927.0947, 3.6353],
    ['JPCA', 934.1800, 928.7272, 5.4528],
    ['JPCA', 937.7700, 921.0858, 16.6842],
    ['JPCA', 915.3100, 920.6588, -5.3488],
    ['JPCA', 965.0700, 945.3820, 19.6880],
    ['JPCA', 726.2600, 715.1973, 11.0627],
    ['JPCA', 720.4100, 745.1686, -24.7586],
    ['JPCA', 705.5300, 752.6537, -47.1237],
    ['JPCA', 710.8900, 745.6697, -34.7797],
    ['JPCA', 754.4800, 752.3344, 2.1456],
    ['JPCA', 738.7000, 749.2192, -10.5192],
    ['JPCA', 757.6100, 758.2943, -0.6843],
    ['JPCA', 742.7000, 763.0038, -20.3038],
    ['JPCA', 748.0500, 756.0198, -7.9698],
    ['JPCA', 769.9800, 762.6845, 7.2955],
]

# Create DataFrame
df_uts = pd.DataFrame(uts_data, columns=[
    'Material', 'Ultimate Tensile Strength (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_uts['Ultimate Tensile Strength (MPa)'], 
           df_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_uts['Ultimate Tensile Strength (MPa)'].min(), df_uts['Predicted UTS (MPa)'].min())
max_val = max(df_uts['Ultimate Tensile Strength (MPa)'].max(), df_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('JPCA: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

#
    [87, 'JFMS', 753.7700, 691.0042, 62.7658, 62.7658],
    [88, 'JFMS', 827.0800, 723.4168, 103.6631, 103.6631],
    [89, 'JFMS', 813.6900, 723.4168, 90.2732, 90.2732],
    [90, 'JFMS', 307.0100, 417.4043, -110.3943, 110.3943],
    [91, 'JFMS', 300.3300, 368.5779, -68.2479, 68.2479],
    [92, 'JFMS', 306.1400, 368.5779, -62.4379, 62.4379],
    [93, 'JFMS', 292.8200, 390.1597, -97.3397, 97.3397],
    [94, 'JFMS', 357.2200, 409.8627, -52.6427, 52.6427],
    [95, 'JFMS', 379.5500, 429.8059, -50.2559, 50.2559],
    [96, 'JFMS', 399.1400, 424.8022, -25.6622, 25.6622],
    [97, 'JFMS', 374.1800, 429.8059, -55.6259, 55.6259],
    [98, 'JFMS', 504.7900, 467.2860, 37.5040, 37.5040],
    [99, 'JFMS', 406.7400, 429.0659, -22.3259, 22.3259],
    [100, 'JFMS', 387.2000, 422.3043, -35.1043, 35.1043],
    [101, 'JFMS', 395.0400, 413.0659, -18.0259, 18.0259],
    [102, 'JFMS', 395.0400, 413.0659, -18.0259, 18.0259],
]

# Create DataFrame
df_jfms = pd.DataFrame(jfms_data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Display the DataFrame
print(df_jfms)
# Out:
#      Index Material  Actual Yield Strength (MPa)  \
# 0        0     JFMS                       298.09
# 1        1     JFMS                       322.78
# 2        2     JFMS                       383.15
# 3        3     JFMS                       348.29
# 4        4     JFMS                       404.18
# ..     ...      ...                          ...
# 98      98     JFMS                       504.79
# 99      99     JFMS                       406.74
# 100    100     JFMS                       387.20
# 101    101     JFMS                       395.04
# 102    102     JFMS                       395.04
#
#      Predicted Yield Strength (MPa)  Error (MPa)  Absolute Error (MPa)
# 0                          411.7889    -113.6989              113.6989
# 1                          411.7889     -89.0089               89.0089
# 2                          411.7889     -28.6389               28.6389
# 3                          413.0201     -64.7301               64.7301
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from all 4 images (indices 0–102)
jfms_data = [
    [0, 'JFMS', 298.0900, 411.7889, -113.6989, 113.6989],
    [1, 'JFMS', 322.7800, 411.7889, -89.0089, 89.0089],
    [2, 'JFMS', 383.1500, 411.7889, -28.6389, 28.6389],
    [3, 'JFMS', 348.2900, 413.0201, -64.7301, 64.7301],
    [4, 'JFMS', 404.1800, 411.7889, -7.6089, 7.6089],
    [5, 'JFMS', 431.5000, 477.4324, -45.9324, 45.9324],
    [6, 'JFMS', 446.1600, 413.0201, 33.1399, 33.1399],
    [7, 'JFMS', 477.2200, 486.4245, -9.2045, 9.2045],
    [8, 'JFMS', 497.3400, 486.4245, 10.9155, 10.9155],
    [9, 'JFMS', 483.4500, 486.4245, -2.9745, 2.9745],
    [10, 'JFMS', 525.3400, 486.4245, 38.9155, 38.9155],
    [11, 'JFMS', 497.7900, 486.4245, 11.3655, 11.3655],
    [12, 'JFMS', 501.1700, 486.4245, 14.7455, 14.7455],
    [13, 'JFMS', 506.5300, 486.4245, 20.1055, 20.1055],
    [100, 'JFMS', 387.2000, 422.3043, -35.1043, 35.1043],
    [101, 'JFMS', 395.0400, 413.0659, -18.0259, 18.0259],
    [102, 'JFMS', 395.0400, 413.0659, -18.0259, 18.0259],
]

# Create DataFrame
df_jfms = pd.DataFrame(jfms_data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_jfms['Actual Yield Strength (MPa)'], 
           df_jfms['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_jfms['Actual Yield Strength (MPa)'].min(), df_jfms['Predicted Yield Strength (MPa)'].min())
max_val = max(df_jfms['Actual Yield Strength (MPa)'].max(), df_jfms['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('JFMS: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# JFMS UTS prediction data (indices 0–60)
jfms_uts_data = [
    [0, 'JFMS', 528.6800, 532.3609, -3.6809],
    [1, 'JFMS', 556.0900, 532.3609, 23.7291],
    [2, 'JFMS', 558.6600, 586.5475, -27.8875],
    [3, 'JFMS', 661.8400, 532.3609, 129.4791],
    [4, 'JFMS', 657.8000, 586.5475, 71.3325],
    [5, 'JFMS', 653.9400, 676.8734, -22.9334],
    [6, 'JFMS', 591.3100, 590.6962, 0.6138],
    [7, 'JFMS', 730.9900, 590.6962, 140.2938],
    [8, 'JFMS', 683.9700, 709.2780, -25.3080],
    [9, 'JFMS', 725.6900, 740.4367, -14.7467],
    [10, 'JFMS', 822.3300, 775.0243, 47.3057],
    [11, 'JFMS', 759.6300, 740.4367, 19.1933],
    [12, 'JFMS', 764.8300, 756.6899, 8.1401],
    [13, 'JFMS', 792.2100, 756.6899, 35.5201],
    [14, 'JFMS', 762.1600, 748.5627, 13.5973],
    [15, 'JFMS', 775.1700, 758.7995, 16.3705],
    [16, 'JFMS', 732.2700, 709.2780, 22.9920],
    [17, 'JFMS', 799.7500, 767.9711, 31.7789],
    [18, 'JFMS', 776.2300, 767.9711, 8.2589],
    [19, 'JFMS', 737.0700, 767.9711, -30.9011],
    [20, 'JFMS', 679.6500, 767.9711, -88.3211],
    [21, 'JFMS', 689.0200, 758.7995, -69.7795],
    [22, 'JFMS', 774.7000, 775.9420, -1.2420],
    [23, 'JFMS', 761.6200, 775.9420, -14.3220],
    [24, 'JFMS', 787.4300, 780.3232, 7.1068],
    [25, 'JFMS', 535.1600, 586.5475, -51.3875],
    [26, 'JFMS', 603.0600, 642.1983, -39.1383],
    [27, 'JFMS', 588.6900, 642.1983, -53.5083],
    [28, 'JFMS', 706.1800, 707.7544, -1.5744],
    [29, 'JFMS', 704.8500, 719.4852, -14.6352],
    [30, 'JFMS', 763.6100, 719.4852, 44.1248],
    [31, 'JFMS', 678.5500, 767.8563, -89.3063],
    [32, 'JFMS', 687.4300, 766.6255, -79.1955],
    [33, 'JFMS', 789.2500, 777.9801, 11.2699],
    [34, 'JFMS', 800.9800, 777.9801, 22.9999],
    [35, 'JFMS', 806.2300, 766.6255, 39.6045],
    [36, 'JFMS', 782.2200, 778.6115, 3.6085],
    [37, 'JFMS', 787.4000, 778.6115, 8.7885],
    [38, 'JFMS', 687.6700, 688.3409, -0.6709],
    [39, 'JFMS', 678.4100, 697.5126, -19.1026],
    [40, 'JFMS', 675.3300, 697.3978, -22.0678],
    [41, 'JFMS', 687.6700, 696.1670, -8.4970],
    [42, 'JFMS', 1110.1300, 1088.2887, 21.8413],
    [43, 'JFMS', 1036.1800, 1033.7600, 2.4393],
    [44, 'JFMS', 1026.8700, 1023.3975, 3.4725],
    [45, 'JFMS', 1094.7100, 1094.5489, 0.1611],
    [46, 'JFMS', 1094.7100, 1022.0050, 72.7050],
    [47, 'JFMS', 1048.4600, 1077.7280, -29.2685],
    [48, 'JFMS', 992.9500, 998.2377, -5.2877],
    [49, 'JFMS', 1036.1200, 1011.9325, 24.1875],
    [50, 'JFMS', 1113.2200, 1093.1227, 20.0973],
    [51, 'JFMS', 817.1800, 830.1743, -12.9943],
    [52, 'JFMS', 894.2700, 848.2559, 46.0141],
    [53, 'JFMS', 891.1900, 860.6081, 30.5819],
    [54, 'JFMS', 872.6900, 848.1411, 24.5489],
    [55, 'JFMS', 881.9400, 854.1622, 27.7778],
    [56, 'JFMS', 860.3500, 899.4407, -39.0907],
    [57, 'JFMS', 946.7000, 928.0300, 18.6700],
    [58, 'JFMS', 931.2800, 936.7112, -5.4312],
    [59, 'JFMS', 922.0300, 919.4951, 2.5349],
    [60, 'JFMS', 934.3600, 930.2554, 4.1046],
]

# Create DataFrame
df_jfms_uts = pd.DataFrame(jfms_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Display the DataFrame
print(df_jfms_uts)
# Out:
#     Index Material  Actual UTS (MPa)  Predicted UTS (MPa)  Error (MPa)
# 0       0     JFMS            528.68             532.3609      -3.6809
# 1       1     JFMS            556.09             532.3609      23.7291
# 2       2     JFMS            558.66             586.5475     -27.8875
# 3       3     JFMS            661.84             532.3609     129.4791
# 4       4     JFMS            657.80             586.5475      71.3325
# ..    ...      ...               ...                  ...          ...
# 56     56     JFMS            860.35             899.4407     -39.0907
# 57     57     JFMS            946.70             928.0300      18.6700
# 58     58     JFMS            931.28             936.7112      -5.4312
# 59     59     JFMS            922.03             919.4951       2.5349
# 60     60     JFMS            934.36             930.2554       4.1046
#
# [61 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# JFMS UTS prediction data (indices 0–60)
jfms_uts_data = [
    [0, 'JFMS', 528.6800, 532.3609, -3.6809],
    [1, 'JFMS', 556.0900, 532.3609, 23.7291],
    [2, 'JFMS', 558.6600, 586.5475, -27.8875],
    [3, 'JFMS', 661.8400, 532.3609, 129.4791],
    [4, 'JFMS', 657.8000, 586.5475, 71.3325],
    [5, 'JFMS', 653.9400, 676.8734, -22.9334],
    [6, 'JFMS', 591.3100, 590.6962, 0.6138],
    [58, 'JFMS', 931.2800, 936.7112, -5.4312],
    [59, 'JFMS', 922.0300, 919.4951, 2.5349],
    [60, 'JFMS', 934.3600, 930.2554, 4.1046],
]

# Create DataFrame
df_jfms_uts = pd.DataFrame(jfms_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_jfms_uts['Actual UTS (MPa)'], 
           df_jfms_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_jfms_uts['Actual UTS (MPa)'].min(), df_jfms_uts['Predicted UTS (MPa)'].min())
max_val = max(df_jfms_uts['Actual UTS (MPa)'].max(), df_jfms_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('JFMS: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# SS316 prediction data (rows 0–106)
ss316_data = [
    # Rows 0–33
    [0, 'SS316', 230.0000, 497.8941, -267.8941, 267.8941],
    [1, 'SS316', 264.0000, 497.8941, -233.8941, 233.8941],
    [2, 'SS316', 215.0000, 497.8941, -282.8941, 282.8941],
    [3, 'SS316', 134.0000, 407.2930, -273.2930, 273.2930],
    [4, 'SS316', 146.0000, 407.2930, -261.2930, 261.2930],
    [5, 'SS316', 88.0000, 395.5393, -307.5393, 307.5393],
    [6, 'SS316', 96.0000, 395.5393, -299.5393, 299.5393],
    [7, 'SS316', 735.0000, 497.1059, -237.1059, 237.1059],
    [8, 'SS316', 748.0000, 497.8941, -250.1059, 250.1059],
    [9, 'SS316', 733.0000, 497.8941, -235.1059, 235.1059],
    [10, 'SS316', 646.0000, 407.2930, -238.7070, 238.7070],
    [11, 'SS316', 627.0000, 407.2930, -219.7070, 219.7070],
    [12, 'SS316', 536.0000, 395.5393, -140.4607, 140.4607],
    [13, 'SS316', 539.0000, 395.5393, -143.4607, 143.4607],
    [14, 'SS316', 551.0000, 395.5393, -155.4607, 155.4607],
    [15, 'SS316', 207.0000, 482.5926, -275.5926, 275.5926],
    [16, 'SS316', 198.0000, 482.5926, -284.5926, 284.5926],
    [17, 'SS316', 224.0000, 482.5926, -258.5926, 258.5926],
    [18, 'SS316', 138.0000, 402.8005, -264.8005, 264.8005],
    [19, 'SS316', 141.0000, 402.8005, -261.8005, 261.8005],
    [20, 'SS316', 152.0000, 402.8005, -250.8005, 250.8005],
    [21, 'SS316', 95.0000, 388.0083, -293.0083, 293.0083],
    [22, 'SS316', 103.0000, 388.0083, -285.0083, 285.0083],
    [23, 'SS316', 86.0000, 388.0083, -302.0083, 302.0083],
    [24, 'SS316', 733.0000, 482.5926, -250.4074, 250.4074],
    [25, 'SS316', 741.0000, 482.5926, -258.4074, 258.4074],
    [26, 'SS316', 724.0000, 482.5926, -241.4074, 241.4074],
    [27, 'SS316', 655.0000, 402.8005, -252.1995, 252.1995],
    [72, 'SS316', 206.0000, 230.9830, -24.9830, 24.9830],
    [73, 'SS316', 208.0000, 230.9830, -22.9830, 22.9830],
    [74, 'SS316', 210.0000, 230.9830, -20.9830, 20.9830],
    [75, 'SS316', 212.0000, 230.9830, -18.9830, 18.9830],
    [76, 'SS316', 214.0000, 230.9830, -16.9830, 16.9830],
    [77, 'SS316', 216.0000, 230.9830, -14.9830, 14.9830],
    [78, 'SS316', 218.0000, 230.9830, -12.9830, 12.9830],
    [79, 'SS316', 220.0000, 230.9830, -10.9830, 10.9830],
    [80, 'SS316', 222.0000, 230.9830, -8.9830, 8.9830],
    [81, 'SS316', 224.0000, 230.9830, -6.9830, 6.9830],
    [82, 'SS316', 226.0000, 230.9830, -4.9830, 4.9830],
    [83, 'SS316', 228.0000, 230.9830, -2.9830, 2.9830],
    [84, 'SS316', 230.0000, 230.9830, -0.9830, 0.9830],
    [85, 'SS316', 232.0000, 230.9830, 1.0170, 1.0170],
    [86, 'SS316', 234.0000, 230.9830, 3.0170, 3.0170],
    [87, 'SS316', 236.0000, 230.9830, 5.0170, 5.0170],
    [88, 'SS316', 238.0000, 230.9830, 7.0170, 7.0170],
    [89, 'SS316', 240.0000, 230.9830, 9.0170, 9.0170],
    [90, 'SS316', 242.0000, 230.9830, 11.0170, 11.0170],
    [91, 'SS316', 244.0000, 230.9830, 13.0170, 13.0170],
    [92, 'SS316', 246.0000, 230.9830, 15.0170, 15.0170],
    [93, 'SS316', 248.0000, 230.9830, 17.0170, 17.0170],
    [94, 'SS316', 250.0000, 230.9830, 19.0170, 19.0170],
    [95, 'SS316', 252.0000, 230.9830, 21.0170, 21.0170],
    [96, 'SS316', 254.0000, 230.9830, 23.0170, 23.0170],
    [97, 'SS316', 256.0000, 230.9830, 25.0170, 25.0170],
    [98, 'SS316', 258.0000, 230.9830, 27.0170, 27.0170],
    [99, 'SS316', 260.0000, 230.9830, 29.0170, 29.0170],
    [100, 'SS316', 262.0000, 230.9830, 31.0170, 31.0170],
    [101, 'SS316', 264.0000, 230.9830, 33.0170, 33.0170],
    [102, 'SS316', 266.0000, 230.9830, 35.0170, 35.0170],
    [103, 'SS316', 268.0000, 230.9830, 37.0170, 37.0170],
    [104, 'SS316', 270.0000, 230.9830, 39.0170, 39.0170],
    [105, 'SS316', 272.0000, 230.9830, 41.0170, 41.0170],
    [106, 'SS316', 183.0000, 242.8610, -59.8610, 59.8610],
]

# Create DataFrame
df_ss316 = pd.DataFrame(ss316_data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Display the DataFrame
print(df_ss316)
# Out:
#      Index Material  Actual Yield Strength (MPa)  \
# 0        0    SS316                        230.0
# 1        1    SS316                        264.0
# 2        2    SS316                        215.0
# 3        3    SS316                        134.0
# 4        4    SS316                        146.0
# ..     ...      ...                          ...
# 102    102    SS316                        266.0
# 103    103    SS316                        268.0
# 104    104    SS316                        270.0
# 105    105    SS316                        272.0
# 106    106    SS316                        183.0
#
#      Predicted Yield Strength (MPa)  Error (MPa)  Absolute Error (MPa)
# 0                          497.8941    -267.8941              267.8941
# 1                          497.8941    -233.8941              233.8941
# 2                          497.8941    -282.8941              282.8941
# 3                          407.2930    -273.2930              273.2930
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

    [84, 'SS316', 230.0000, 230.9830, -0.9830, 0.9830],
    [85, 'SS316', 232.0000, 230.9830, 1.0170, 1.0170],
    [86, 'SS316', 234.0000, 230.9830, 3.0170, 3.0170],
    [87, 'SS316', 236.0000, 230.9830, 5.0170, 5.0170],
    [88, 'SS316', 238.0000, 230.9830, 7.0170, 7.0170],
    [89, 'SS316', 240.0000, 230.9830, 9.0170, 9.0170],
    [90, 'SS316', 242.0000, 230.9830, 11.0170, 11.0170],
    [91, 'SS316', 244.0000, 230.9830, 13.0170, 13.0170],
    [92, 'SS316', 246.0000, 230.9830, 15.0170, 15.0170],
    [93, 'SS316', 248.0000, 230.9830, 17.0170, 17.0170],
    [94, 'SS316', 250.0000, 230.9830, 19.0170, 19.0170],
    [95, 'SS316', 252.0000, 230.9830, 21.0170, 21.0170],
    [96, 'SS316', 254.0000, 230.9830, 23.0170, 23.0170],
    [97, 'SS316', 256.0000, 230.9830, 25.0170, 25.0170],
    [98, 'SS316', 258.0000, 230.9830, 27.0170, 27.0170],
    [99, 'SS316', 260.0000, 230.9830, 29.0170, 29.0170],
    [100, 'SS316', 262.0000, 230.9830, 31.0170, 31.0170],
    [101, 'SS316', 264.0000, 230.9830, 33.0170, 33.0170],
    [102, 'SS316', 266.0000, 230.9830, 35.0170, 35.0170],
    [103, 'SS316', 268.0000, 230.9830, 37.0170, 37.0170],
    [104, 'SS316', 270.0000, 230.9830, 39.0170, 39.0170],
    [105, 'SS316', 272.0000, 230.9830, 41.0170, 41.0170],
    [106, 'SS316', 183.0000, 242.8610, -59.8610, 59.8610],
]

# Create DataFrame
df_ss316 = pd.DataFrame(ss316_data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_ss316['Actual Yield Strength (MPa)'], 
           df_ss316['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_ss316['Actual Yield Strength (MPa)'].min(), df_ss316['Predicted Yield Strength (MPa)'].min())
max_val = max(df_ss316['Actual Yield Strength (MPa)'].max(), df_ss316['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS316: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# SS316 UTS prediction data (rows 0–66)
ss316_uts_data = [
    [0, 'SS316', 590.0000, 688.6551, -98.6551],
    [1, 'SS316', 578.0000, 688.6551, -110.6551],
    [2, 'SS316', 479.0000, 584.2474, -105.2474],
    [3, 'SS316', 467.0000, 584.2474, -117.2474],
    [4, 'SS316', 441.0000, 529.3115, -88.3115],
    [5, 'SS316', 448.0000, 529.3115, -81.3115],
    [6, 'SS316', 460.0000, 529.3115, -69.3115],
    [7, 'SS316', 803.0000, 688.6551, 114.3449],
    [8, 'SS316', 817.0000, 688.6551, 128.3449],
    [9, 'SS316', 802.0000, 688.6551, 113.3449],
    [64, 'SS316', 429.4000, 458.9915, -29.5915],
    [65, 'SS316', 637.0000, 646.6099, -9.6099],
    [66, 'SS316', 448.6000, 469.4351, -20.8351],
]

# Create DataFrame
df_ss316_uts = pd.DataFrame(ss316_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Display the DataFrame
print(df_ss316_uts)
# Out:
#     Index Material  Actual UTS (MPa)  Predicted UTS (MPa)  Error (MPa)
# 0       0    SS316             590.0             688.6551     -98.6551
# 1       1    SS316             578.0             688.6551    -110.6551
# 2       2    SS316             479.0             584.2474    -105.2474
# 3       3    SS316             467.0             584.2474    -117.2474
# 4       4    SS316             441.0             529.3115     -88.3115
# ..    ...      ...               ...                  ...          ...
# 62     62    SS316             695.0             645.8196      49.1804
# 63     63    SS316             590.4             611.5418     -21.1418
# 64     64    SS316             429.4             458.9915     -29.5915
# 65     65    SS316             637.0             646.6099      -9.6099
# 66     66    SS316             448.6             469.4351     -20.8351
#
# [67 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# SS316 UTS prediction data (rows 0–66)
ss316_uts_data = [
    [0, 'SS316', 590.0000, 688.6551, -98.6551],
    [1, 'SS316', 578.0000, 688.6551, -110.6551],
    [2, 'SS316', 479.0000, 584.2474, -105.2474],
    [3, 'SS316', 467.0000, 584.2474, -117.2474],
    [4, 'SS316', 441.0000, 529.3115, -88.3115],
    [5, 'SS316', 448.0000, 529.3115, -81.3115],
    [6, 'SS316', 460.0000, 529.3115, -69.3115],
    [7, 'SS316', 803.0000, 688.6551, 114.3449],
    [8, 'SS316', 817.0000, 688.6551, 128.3449],
    [9, 'SS316', 802.0000, 688.6551, 113.3449],
    [10, 'SS316', 684.0000, 584.2474, 99.7526],
    [11, 'SS316', 619.0000, 529.3115, 89.6885],
    [12, 'SS316', 627.0000, 529.3115, 97.6885],
    [13, 'SS316', 634.0000, 529.3115, 104.6885],
    [14, 'SS316', 577.0000, 682.4752, -105.4752],
    [15, 'SS316', 569.0000, 682.4752, -113.4752],
    [16, 'SS316', 465.0000, 602.1672, -137.1672],
    [17, 'SS316', 477.0000, 602.1672, -125.1672],
    [18, 'SS316', 481.0000, 602.1672, -121.1672],
    [19, 'SS316', 440.0000, 523.7969, -83.7969],
    [20, 'SS316', 431.0000, 523.7969, -92.7969],
    [21, 'SS316', 388.0000, 523.7969, -135.7969],
    [22, 'SS316', 819.0000, 682.4752, 136.5248],
    [23, 'SS316', 827.0000, 682.4752, 144.5248],
    [24, 'SS316', 707.0000, 602.1672, 104.8328],
    [25, 'SS316', 681.0000, 602.1672, 78.8328],
    [26, 'SS316', 638.0000, 602.1672, 35.8328],
    [27, 'SS316', 595.0000, 523.7969, 71.2031],
    [28, 'SS316', 638.0000, 523.7969, 114.2031],
    [29, 'SS316', 603.0000, 523.7969, 79.2031],
    [30, 'SS316', 605.0000, 669.0895, -64.0895],
    [31, 'SS316', 613.0000, 669.0895, -56.0895],
    [32, 'SS316', 602.0000, 669.0895, -67.0895],
    [33, 'SS316', 505.0000, 625.6962, -120.6962],
    [34, 'SS316', 498.0000, 625.6962, -127.6962],
    [35, 'SS316', 495.0000, 625.6962, -130.6962],
    [36, 'SS316', 464.0000, 552.9032, -88.9032],
    [37, 'SS316', 476.0000, 552.9032, -76.9032],
    [38, 'SS316', 816.0000, 669.0895, 146.9105],
    [39, 'SS316', 818.0000, 669.0895, 148.9105],
    [40, 'SS316', 712.0000, 625.6962, 86.3038],
    [41, 'SS316', 706.0000, 625.6962, 80.3038],
    [42, 'SS316', 696.0000, 625.6962, 70.3038],
    [43, 'SS316', 639.0000, 552.9032, 86.0968],
    [44, 'SS316', 640.0000, 552.9032, 87.0968],
    [45, 'SS316', 650.0000, 552.9032, 97.0968],
    [46, 'SS316', 632.0000, 711.7423, -79.7423],
    [47, 'SS316', 621.0000, 711.7423, -90.7423],
    [48, 'SS316', 623.0000, 711.7423, -88.7423],
    [49, 'SS316', 509.0000, 631.4342, -122.4342],
    [50, 'SS316', 512.0000, 631.4342, -119.4342],
    [51, 'SS316', 501.0000, 631.4342, -130.4342],
    [52, 'SS316', 504.0000, 536.0399, -32.0399],
    [53, 'SS316', 506.0000, 536.0399, -30.0399],
    [54, 'SS316', 464.0000, 536.0399, -72.0399],
    [55, 'SS316', 882.0000, 711.7423, 170.2577],
    [56, 'SS316', 873.0000, 711.7423, 161.2577],
    [57, 'SS316', 774.0000, 631.4342, 142.5658],
    [58, 'SS316', 766.0000, 631.4342, 134.5658],
    [59, 'SS316', 771.0000, 631.4342, 139.5658],
    [60, 'SS316', 712.0000, 536.0399, 175.9601],
    [61, 'SS316', 701.0000, 536.0399, 164.9601],
    [62, 'SS316', 695.0000, 645.8196, 49.1804],
    [63, 'SS316', 590.4000, 611.5418, -21.1418],
    [64, 'SS316', 429.4000, 458.9915, -29.5915],
    [65, 'SS316', 637.0000, 646.6099, -9.6099],
    [66, 'SS316', 448.6000, 469.4351, -20.8351],
]

# Create DataFrame
df_ss316_uts = pd.DataFrame(ss316_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_ss316_uts['Actual UTS (MPa)'], 
           df_ss316_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=50, color='BLUE')

# Perfect prediction line (y = x)
min_val = min(df_ss316_uts['Actual UTS (MPa)'].min(), df_ss316_uts['Predicted UTS (MPa)'].min())
max_val = max(df_ss316_uts['Actual UTS (MPa)'].max(), df_ss316_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('SS316: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# SS304 prediction data
ss304_data = [
    ['SS304', 296.0000, 360.2918, -64.2918, 64.2918],
    ['SS304', 350.0000, 360.2918, -10.2918, 10.2918],
    ['SS304', 362.0000, 369.6404, -7.6404, 7.6404],
    ['SS304', 421.0000, 381.4427, 39.5573, 39.5573],
    ['SS304', 319.0000, 360.2918, -41.2918, 41.2918],
    ['SS304', 356.0000, 360.2918, -4.2918, 4.2918],
    ['SS304', 379.0000, 369.6404, 9.3596, 9.3596],
    ['SS304', 445.0000, 381.4427, 63.5573, 63.5573],
    ['SS304', 274.3600, 267.9904, 6.3696, 6.3696],
    ['SS304', 233.8500, 220.9564, 12.8936, 12.8936],
    ['SS304', 234.8700, 220.9564, 13.9136, 13.9136],
    ['SS304', 289.2300, 225.6011, 63.6289, 63.6289],
    ['SS304', 248.0000, 307.2353, -59.2353, 59.2353],
    ['SS304', 264.0000, 307.2353, -43.2353, 43.2353],
    ['SS304', 285.0000, 307.2353, -22.2353, 22.2353],
    ['SS304', 343.0000, 307.2353, 35.7647, 35.7647],
    ['SS304', 344.0000, 319.0377, 24.9623, 24.9623],
    ['SS304', 371.0000, 319.0377, 51.9623, 51.9623],
    ['SS304', 484.0000, 344.2529, 139.7471, 139.7471],
]

# Create DataFrame
df_ss304 = pd.DataFrame(ss304_data, columns=[
    'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Display the DataFrame
print(df_ss304)
# Out:
#    Material  Actual Yield Strength (MPa)  Predicted Yield Strength (MPa)  \
# 0     SS304                       296.00                        360.2918
# 1     SS304                       350.00                        360.2918
# 2     SS304                       362.00                        369.6404
# 3     SS304                       421.00                        381.4427
# 4     SS304                       319.00                        360.2918
# 5     SS304                       356.00                        360.2918
# 6     SS304                       379.00                        369.6404
# 7     SS304                       445.00                        381.4427
# 8     SS304                       274.36                        267.9904
# 9     SS304                       233.85                        220.9564
# 10    SS304                       234.87                        220.9564
# 11    SS304                       289.23                        225.6011
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# SS304 prediction data
ss304_data = [
    ['SS304', 296.0000, 360.2918, -64.2918, 64.2918],
    ['SS304', 350.0000, 360.2918, -10.2918, 10.2918],
    ['SS304', 362.0000, 369.6404, -7.6404, 7.6404],
    ['SS304', 421.0000, 381.4427, 39.5573, 39.5573],
    ['SS304', 319.0000, 360.2918, -41.2918, 41.2918],
    ['SS304', 356.0000, 360.2918, -4.2918, 4.2918],
    ['SS304', 379.0000, 369.6404, 9.3596, 9.3596],
    ['SS304', 445.0000, 381.4427, 63.5573, 63.5573],
    ['SS304', 274.3600, 267.9904, 6.3696, 6.3696],
    ['SS304', 233.8500, 220.9564, 12.8936, 12.8936],
    ['SS304', 234.8700, 220.9564, 13.9136, 13.9136],
    ['SS304', 289.2300, 225.6011, 63.6289, 63.6289],
    ['SS304', 248.0000, 307.2353, -59.2353, 59.2353],
    ['SS304', 264.0000, 307.2353, -43.2353, 43.2353],
    ['SS304', 285.0000, 307.2353, -22.2353, 22.2353],
    ['SS304', 343.0000, 307.2353, 35.7647, 35.7647],
    ['SS304', 344.0000, 319.0377, 24.9623, 24.9623],
    ['SS304', 371.0000, 319.0377, 51.9623, 51.9623],
    ['SS304', 484.0000, 344.2529, 139.7471, 139.7471],
]

# Create DataFrame
df_ss304 = pd.DataFrame(ss304_data, columns=[
    'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_ss304['Actual Yield Strength (MPa)'], 
           df_ss304['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_ss304['Actual Yield Strength (MPa)'].min(), df_ss304['Predicted Yield Strength (MPa)'].min())
max_val = max(df_ss304['Actual Yield Strength (MPa)'].max(), df_ss304['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS304: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# SS304 UTS prediction data
ss304_uts_data = [
    [0, 'SS304', 729.0000, 696.2306, 32.7694],
    [1, 'SS304', 672.0000, 695.6162, -23.6162],
    [2, 'SS304', 685.0000, 686.7376, -1.7376],
    [3, 'SS304', 715.0000, 696.0449, 18.9551],
    [4, 'SS304', 734.0000, 696.2306, 37.7694],
    [5, 'SS304', 710.0000, 695.6162, 14.3838],
    [6, 'SS304', 712.0000, 691.7710, 20.2290],
    [7, 'SS304', 741.0000, 714.2759, 26.7241],
    [8, 'SS304', 699.0000, 652.6629, 46.3371],
    [9, 'SS304', 689.0000, 634.2480, 54.7520],
    [10, 'SS304', 639.0000, 634.2480, 4.7520],
    [11, 'SS304', 643.0000, 652.6629, -9.6629],
    [12, 'SS304', 651.0000, 651.8441, -0.8441],
    [13, 'SS304', 682.0000, 676.0602, 5.9398],
    [14, 'SS304', 706.0000, 688.0114, 17.9886],
    [15, 'SS304', 827.0000, 682.4752, 144.5248],
    [16, 'SS304', 707.0000, 602.1672, 104.8328],
    [17, 'SS304', 681.0000, 602.1672, 78.8328],
    [18, 'SS304', 638.0000, 602.1672, 35.8328],
    [19, 'SS304', 595.0000, 523.7969, 71.2031],
    [20, 'SS304', 638.0000, 523.7969, 114.2031],
    [21, 'SS304', 603.0000, 523.7969, 79.2031],
    [22, 'SS304', 605.0000, 669.0895, -64.0895],
    [23, 'SS304', 613.0000, 669.0895, -56.0895],
    [24, 'SS304', 602.0000, 669.0895, -67.0895],
    [25, 'SS304', 505.0000, 625.6962, -120.6962],
    [26, 'SS304', 498.0000, 625.6962, -127.6962],
    [27, 'SS304', 495.0000, 625.6962, -130.6962],
    [28, 'SS304', 464.0000, 552.9032, -88.9032],
    [29, 'SS304', 476.0000, 552.9032, -76.9032],
    [30, 'SS304', 816.0000, 669.0895, 146.9105],
    [31, 'SS304', 818.0000, 669.0895, 148.9105],
    [32, 'SS304', 712.0000, 625.6962, 86.3038],
    [33, 'SS304', 706.0000, 625.6962, 80.3038],
    [34, 'SS304', 696.0000, 625.6962, 70.3038],
    [35, 'SS304', 639.0000, 552.9032, 86.0968],
    [36, 'SS304', 640.0000, 552.9032, 87.0968],
    [37, 'SS304', 650.0000, 552.9032, 97.0968],
    [38, 'SS304', 632.0000, 711.7423, -79.7423],
    [39, 'SS304', 621.0000, 711.7423, -90.7423],
    [40, 'SS304', 623.0000, 711.7423, -88.7423],
    [41, 'SS304', 509.0000, 631.4342, -122.4342],
    [42, 'SS304', 512.0000, 631.4342, -119.4342],
    [43, 'SS304', 501.0000, 631.4342, -130.4342],
    [44, 'SS304', 504.0000, 536.0399, -32.0399],
    [45, 'SS304', 506.0000, 536.0399, -30.0399],
    [46, 'SS304', 464.0000, 536.0399, -72.0399],
    [47, 'SS304', 882.0000, 711.7423, 170.2577],
    [48, 'SS304', 873.0000, 711.7423, 161.2577],
    [49, 'SS304', 774.0000, 631.4342, 142.5658],
    [50, 'SS304', 766.0000, 631.4342, 134.5658],
    [51, 'SS304', 771.0000, 631.4342, 139.5658],
    [52, 'SS304', 712.0000, 536.0399, 175.9601],
    [53, 'SS304', 701.0000, 536.0399, 164.9601],
    [54, 'SS304', 695.0000, 645.8196, 49.1804],
    [55, 'SS304', 590.4000, 611.5418, -21.1418],
    [56, 'SS304', 429.4000, 458.9915, -29.5915],
    [57, 'SS304', 637.0000, 646.6099, -9.6099],
    [58, 'SS304', 448.6000, 469.4351, -20.8351],
]

# Create DataFrame
df_ss304_uts = pd.DataFrame(ss304_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Display the DataFrame
print(df_ss304_uts)
# Out:
#     Index Material  Actual UTS (MPa)  Predicted UTS (MPa)  Error (MPa)
# 0       0    SS304             729.0             696.2306      32.7694
# 1       1    SS304             672.0             695.6162     -23.6162
# 2       2    SS304             685.0             686.7376      -1.7376
# 3       3    SS304             715.0             696.0449      18.9551
# 4       4    SS304             734.0             696.2306      37.7694
# 5       5    SS304             710.0             695.6162      14.3838
# 6       6    SS304             712.0             691.7710      20.2290
# 7       7    SS304             741.0             714.2759      26.7241
# 8       8    SS304             699.0             652.6629      46.3371
# 9       9    SS304             689.0             634.2480      54.7520
# 10     10    SS304             639.0             634.2480       4.7520
# 11     11    SS304             643.0             652.6629      -9.6629
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# SS304 UTS prediction data
ss304_uts_data = [
    [0, 'SS304', 729.0000, 696.2306, 32.7694],
    [1, 'SS304', 672.0000, 695.6162, -23.6162],
    [2, 'SS304', 685.0000, 686.7376, -1.7376],
    [3, 'SS304', 715.0000, 696.0449, 18.9551],
    [4, 'SS304', 734.0000, 696.2306, 37.7694],
    [5, 'SS304', 710.0000, 695.6162, 14.3838],
    [6, 'SS304', 712.0000, 691.7710, 20.2290],
    [7, 'SS304', 741.0000, 714.2759, 26.7241],
    [8, 'SS304', 699.0000, 652.6629, 46.3371],
    [9, 'SS304', 689.0000, 634.2480, 54.7520],
    [10, 'SS304', 639.0000, 634.2480, 4.7520],
    [11, 'SS304', 643.0000, 652.6629, -9.6629],
    [12, 'SS304', 651.0000, 651.8441, -0.8441],
    [13, 'SS304', 682.0000, 676.0602, 5.9398],
    [14, 'SS304', 706.0000, 688.0114, 17.9886],
    [15, 'SS304', 827.0000, 682.4752, 144.5248],
    [16, 'SS304', 707.0000, 602.1672, 104.8328],
    [17, 'SS304', 681.0000, 602.1672, 78.8328],
    [18, 'SS304', 638.0000, 602.1672, 35.8328],
    [19, 'SS304', 595.0000, 523.7969, 71.2031],
    [20, 'SS304', 638.0000, 523.7969, 114.2031],
    [21, 'SS304', 603.0000, 523.7969, 79.2031],
    [22, 'SS304', 605.0000, 669.0895, -64.0895],
    [23, 'SS304', 613.0000, 669.0895, -56.0895],
    [24, 'SS304', 602.0000, 669.0895, -67.0895],
    [25, 'SS304', 505.0000, 625.6962, -120.6962],
    [26, 'SS304', 498.0000, 625.6962, -127.6962],
    [27, 'SS304', 495.0000, 625.6962, -130.6962],
    [28, 'SS304', 464.0000, 552.9032, -88.9032],
    [29, 'SS304', 476.0000, 552.9032, -76.9032],
    [30, 'SS304', 816.0000, 669.0895, 146.9105],
    [31, 'SS304', 818.0000, 669.0895, 148.9105],
    [32, 'SS304', 712.0000, 625.6962, 86.3038],
    [33, 'SS304', 706.0000, 625.6962, 80.3038],
    [34, 'SS304', 696.0000, 625.6962, 70.3038],
    [35, 'SS304', 639.0000, 552.9032, 86.0968],
    [36, 'SS304', 640.0000, 552.9032, 87.0968],
    [37, 'SS304', 650.0000, 552.9032, 97.0968],
    [38, 'SS304', 632.0000, 711.7423, -79.7423],
    [39, 'SS304', 621.0000, 711.7423, -90.7423],
    [40, 'SS304', 623.0000, 711.7423, -88.7423],
    [41, 'SS304', 509.0000, 631.4342, -122.4342],
    [42, 'SS304', 512.0000, 631.4342, -119.4342],
    [43, 'SS304', 501.0000, 631.4342, -130.4342],
    [44, 'SS304', 504.0000, 536.0399, -32.0399],
    [45, 'SS304', 506.0000, 536.0399, -30.0399],
    [46, 'SS304', 464.0000, 536.0399, -72.0399],
    [47, 'SS304', 882.0000, 711.7423, 170.2577],
    [48, 'SS304', 873.0000, 711.7423, 161.2577],
    [49, 'SS304', 774.0000, 631.4342, 142.5658],
    [50, 'SS304', 766.0000, 631.4342, 134.5658],
    [51, 'SS304', 771.0000, 631.4342, 139.5658],
    [52, 'SS304', 712.0000, 536.0399, 175.9601],
    [53, 'SS304', 701.0000, 536.0399, 164.9601],
    [54, 'SS304', 695.0000, 645.8196, 49.1804],
    [55, 'SS304', 590.4000, 611.5418, -21.1418],
    [56, 'SS304', 429.4000, 458.9915, -29.5915],
    [57, 'SS304', 637.0000, 646.6099, -9.6099],
    [58, 'SS304', 448.6000, 469.4351, -20.8351],
]

# Create DataFrame
df_ss304_uts = pd.DataFrame(ss304_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_ss304_uts['Actual UTS (MPa)'], 
           df_ss304_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_ss304_uts['Actual UTS (MPa)'].min(), df_ss304_uts['Predicted UTS (MPa)'].min())
max_val = max(df_ss304_uts['Actual UTS (MPa)'].max(), df_ss304_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('SS304: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# SS316-A prediction data (rows 0–33)
ss316a_data = [
    [0, 'SS316-A', 205.7100, 229.1597, -23.4497, 23.4497],
    [1, 'SS316-A', 210.6100, 229.1597, -18.5497, 18.5497],
    [2, 'SS316-A', 189.8200, 229.1597, -39.3397, 39.3397],
    [3, 'SS316-A', 212.0800, 229.1597, -17.0797, 17.0797],
    [4, 'SS316-A', 225.2700, 229.1597, -3.8897, 3.8897],
    [5, 'SS316-A', 208.7400, 229.1597, -20.4197, 20.4197],
    [6, 'SS316-A', 242.8900, 229.1597, 13.7303, 13.7303],
    [7, 'SS316-A', 242.2900, 229.1597, 13.1303, 13.1303],
    [8, 'SS316-A', 244.4600, 229.1597, 15.3003, 15.3003],
    [9, 'SS316-A', 227.6900, 229.1597, -1.4697, 1.4697],
    [10, 'SS316-A', 210.3300, 229.1597, -18.8297, 18.8297],
    [11, 'SS316-A', 188.5600, 229.1597, -40.5997, 40.5997],
    [12, 'SS316-A', 179.5800, 229.1597, -49.5797, 49.5797],
    [13, 'SS316-A', 213.9500, 229.1597, -15.2097, 15.2097],
    [14, 'SS316-A', 208.8300, 229.1597, -20.3297, 20.3297],
    [15, 'SS316-A', 199.9400, 229.1597, -29.2197, 29.2197],
    [16, 'SS316-A', 238.1600, 229.1597, 9.0003, 9.0003],
    [17, 'SS316-A', 275.8500, 229.1597, 46.6903, 46.6903],
    [18, 'SS316-A', 290.5200, 234.3584, 56.1616, 56.1616],
    [19, 'SS316-A', 297.5500, 234.3584, 63.1916, 63.1916],
    [20, 'SS316-A', 308.1200, 243.9263, 64.1937, 64.1937],
    [21, 'SS316-A', 276.1200, 238.5171, 37.6029, 37.6029],
    [22, 'SS316-A', 229.5600, 234.3584, -4.7984, 4.7984],
    [23, 'SS316-A', 262.0100, 234.3584, 27.6516, 27.6516],
    [24, 'SS316-A', 241.0600, 229.1597, 11.9003, 11.9003],
    [25, 'SS316-A', 206.3800, 229.1597, -22.7797, 22.7797],
    [26, 'SS316-A', 239.1200, 234.3584, 4.7616, 4.7616],
    [27, 'SS316-A', 259.9700, 234.3584, 25.6116, 25.6116],
    [28, 'SS316-A', 249.5200, 234.3584, 15.1616, 15.1616],
    [29, 'SS316-A', 269.6300, 234.3584, 35.2716, 35.2716],
    [30, 'SS316-A', 213.7400, 229.1597, -15.4197, 15.4197],
    [31, 'SS316-A', 201.1100, 229.1597, -28.0497, 28.0497],
    [32, 'SS316-A', 197.9500, 198.9934, -1.0434, 1.0434],
    [33, 'SS316-A', 232.7900, 198.9934, 33.7966, 33.7966],
]

# Create DataFrame
df_ss316a = pd.DataFrame(ss316a_data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Display the DataFrame
print(df_ss316a)
# Out:
#     Index Material  Actual Yield Strength (MPa)  \
# 0       0  SS316-A                       205.71
# 1       1  SS316-A                       210.61
# 2       2  SS316-A                       189.82
# 3       3  SS316-A                       212.08
# 4       4  SS316-A                       225.27
# 5       5  SS316-A                       208.74
# 6       6  SS316-A                       242.89
# 7       7  SS316-A                       242.29
# 8       8  SS316-A                       244.46
# 9       9  SS316-A                       227.69
# 10     10  SS316-A                       210.33
# 11     11  SS316-A                       188.56
# 12     12  SS316-A                       179.58
# 13     13  SS316-A                       213.95
# 14     14  SS316-A                       208.83
# 15     15  SS316-A                       199.94
# 16     16  SS316-A                       238.16
# 17     17  SS316-A                       275.85
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# SS316-A prediction data (rows 0–33)
ss316a_data = [
    [0, 'SS316-A', 205.7100, 229.1597, -23.4497, 23.4497],
    [1, 'SS316-A', 210.6100, 229.1597, -18.5497, 18.5497],
    [2, 'SS316-A', 189.8200, 229.1597, -39.3397, 39.3397],
    [3, 'SS316-A', 212.0800, 229.1597, -17.0797, 17.0797],
    [4, 'SS316-A', 225.2700, 229.1597, -3.8897, 3.8897],
    [5, 'SS316-A', 208.7400, 229.1597, -20.4197, 20.4197],
    [6, 'SS316-A', 242.8900, 229.1597, 13.7303, 13.7303],
    [7, 'SS316-A', 242.2900, 229.1597, 13.1303, 13.1303],
    [8, 'SS316-A', 244.4600, 229.1597, 15.3003, 15.3003],
    [9, 'SS316-A', 227.6900, 229.1597, -1.4697, 1.4697],
    [10, 'SS316-A', 210.3300, 229.1597, -18.8297, 18.8297],
    [11, 'SS316-A', 188.5600, 229.1597, -40.5997, 40.5997],
    [12, 'SS316-A', 179.5800, 229.1597, -49.5797, 49.5797],
    [13, 'SS316-A', 213.9500, 229.1597, -15.2097, 15.2097],
    [14, 'SS316-A', 208.8300, 229.1597, -20.3297, 20.3297],
    [15, 'SS316-A', 199.9400, 229.1597, -29.2197, 29.2197],
    [16, 'SS316-A', 238.1600, 229.1597, 9.0003, 9.0003],
    [17, 'SS316-A', 275.8500, 229.1597, 46.6903, 46.6903],
    [18, 'SS316-A', 290.5200, 234.3584, 56.1616, 56.1616],
    [19, 'SS316-A', 297.5500, 234.3584, 63.1916, 63.1916],
    [20, 'SS316-A', 308.1200, 243.9263, 64.1937, 64.1937],
    [21, 'SS316-A', 276.1200, 238.5171, 37.6029, 37.6029],
    [22, 'SS316-A', 229.5600, 234.3584, -4.7984, 4.7984],
    [23, 'SS316-A', 262.0100, 234.3584, 27.6516, 27.6516],
    [24, 'SS316-A', 241.0600, 229.1597, 11.9003, 11.9003],
    [25, 'SS316-A', 206.3800, 229.1597, -22.7797, 22.7797],
    [26, 'SS316-A', 239.1200, 234.3584, 4.7616, 4.7616],
    [27, 'SS316-A', 259.9700, 234.3584, 25.6116, 25.6116],
    [28, 'SS316-A', 249.5200, 234.3584, 15.1616, 15.1616],
    [29, 'SS316-A', 269.6300, 234.3584, 35.2716, 35.2716],
    [30, 'SS316-A', 213.7400, 229.1597, -15.4197, 15.4197],
    [31, 'SS316-A', 201.1100, 229.1597, -28.0497, 28.0497],
    [32, 'SS316-A', 197.9500, 198.9934, -1.0434, 1.0434],
    [33, 'SS316-A', 232.7900, 198.9934, 33.7966, 33.7966],
]

# Create DataFrame
df_ss316a = pd.DataFrame(ss316a_data, columns=[
    'Index', 'Material', 'Actual Yield Strength (MPa)',
    'Predicted Yield Strength (MPa)', 'Error (MPa)', 'Absolute Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_ss316a['Actual Yield Strength (MPa)'], 
           df_ss316a['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_ss316a['Actual Yield Strength (MPa)'].min(), df_ss316a['Predicted Yield Strength (MPa)'].min())
max_val = max(df_ss316a['Actual Yield Strength (MPa)'].max(), df_ss316a['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS316-A: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# SS316-A UTS prediction data
ss316a_uts_data = [
    [0, 'SS316-A', 564.3800, 576.3810, -12.0010],
    [1, 'SS316-A', 557.9900, 577.1086, -19.1186],
    [2, 'SS316-A', 529.3100, 576.3810, -47.0710],
    [3, 'SS316-A', 633.4600, 587.5118, 45.9482],
    [4, 'SS316-A', 579.9300, 587.5118, -7.5818],
    [5, 'SS316-A', 616.9000, 587.5118, 29.3882],
    [6, 'SS316-A', 610.6900, 587.5118, 23.1782],
    [7, 'SS316-A', 629.0100, 588.3661, 40.6439],
    [8, 'SS316-A', 520.8200, 551.5778, -30.7578],
    [9, 'SS316-A', 586.4000, 561.4626, 24.9374],
    [10, 'SS316-A', 477.6300, 538.8050, -61.1750],
    [11, 'SS316-A', 547.0000, 561.9810, -14.9810],
    [12, 'SS316-A', 620.8500, 561.9810, 58.8690],
    [13, 'SS316-A', 612.3000, 583.6263, 28.6737],
    [14, 'SS316-A', 620.4300, 609.8319, 10.5981],
    [15, 'SS316-A', 669.6200, 609.8319, 59.7881],
    [16, 'SS316-A', 683.8200, 643.6998, 40.1202],
    [17, 'SS316-A', 632.3000, 631.4069, 0.8931],
    [18, 'SS316-A', 687.6300, 665.9923, 21.6377],
    [19, 'SS316-A', 587.1800, 619.0604, -31.8804],
    [20, 'SS316-A', 512.5200, 511.3486, 1.1714],
    [21, 'SS316-A', 520.5100, 537.2186, -16.7086],
    [22, 'SS316-A', 552.8900, 558.8639, -5.9739],
    [23, 'SS316-A', 643.0400, 558.4507, 84.5893],
    [24, 'SS316-A', 608.0500, 585.4334, 22.6166],
    [25, 'SS316-A', 552.5800, 585.4334, -32.8534],
    [26, 'SS316-A', 552.5500, 573.6461, -21.0961],
    [27, 'SS316-A', 417.4700, 436.0235, -18.5535],
    [28, 'SS316-A', 482.9200, 490.2763, -7.3563],
]

# Create DataFrame
df_ss316a_uts = pd.DataFrame(ss316a_uts_data, columns=[
    'Index', 'Material', 'Actual UTS (MPa)',
    'Predicted UTS (MPa)', 'Error (MPa)'
])

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot
plt.scatter(df_ss316a_uts['Actual UTS (MPa)'], 
           df_ss316a_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=50, color='blue')

# Perfect prediction line (y = x)
min_val = min(df_ss316a_uts['Actual UTS (MPa)'].min(), df_ss316a_uts['Predicted UTS (MPa)'].min())
max_val = max(df_ss316a_uts['Actual UTS (MPa)'].max(), df_ss316a_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('SS316-A: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Equal aspect ratio
plt.axis('equal')

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Performance summary data
data = [
    ["JFMS", 235, 103, 8.40, 3.40, 16.31, 10.66],
    ["JPCA", 186, 75, 10.71, 3.10, 31.07, 19.03],
    ["SS316", 111, 107, 86.02, 27.76, 52.44, 48.60],
    ["SS316-A", 95, 34, 11.48, 4.19, 18.16, 10.79],
    ["SS316-B", 72, 21, 12.10, 7.04, 13.16, 4.03],
    ["SS316-C", 71, 21, 7.33, 4.29, 10.51, 7.06],
    ["SS316L", 57, 53, 26.11, 10.23, 34.94, 20.19],
    ["SS304", 19, 19, 12.76, 5.97, 13.91, 11.16],
    ["Zr-2.5 Nb", 15, 14, 8.18, 3.93, 8.81, 3.66],
    ["CrMoV", 11, 11, 1.91, 0.71, 1.89, 1.60],
    ["DP600", 10, 10, 13.57, 2.64, 12.54, 6.21],
    ["DP800", 10, 10, 6.43, 2.29, 7.89, 5.20],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    "Material", "Total in dataset", "Hold-out number (after preprocessing)",
    "MAPE (CV)", "+/- (CV)", "MAPE (Holdout)", "+/- (Holdout)"
])

# Display DataFrame
print(df)

# Create simple MAPE comparison plot with error bars
plt.figure(figsize=(12, 6))

# Set up positions for bars
x_pos = np.arange(len(df))
bar_width = 0.35

# Create bars with error bars
plt.bar(x_pos - bar_width/2, df['MAPE (CV)'], bar_width, 
        yerr=df['+/- (CV)'], capsize=4, label='Training MAPE (CV)', 
        color='blue', alpha=0.7)

plt.bar(x_pos + bar_width/2, df['MAPE (Holdout)'], bar_width, 
        yerr=df['+/- (Holdout)'], capsize=4, label='Hold-out MAPE', 
        color='red', alpha=0.7)

# Customize the plot
plt.xlabel('Materials')
plt.ylabel('MAPE (%)')
plt.title('Yield Strength Model Performance: Training Data vs Hold-out Data MAPE')
plt.xticks(x_pos, df['Material'], rotation=45)
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Create separate charts for better readability
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Chart 1: Cross-Validation MAPE
ax1.bar(x_pos, df['MAPE (CV)'], yerr=df['+/- (CV)'], capsize=5, 
        color='blue', alpha=0.7)
ax1.set_xlabel('Materials')
ax1.set_ylabel('MAPE (%)')
ax1.set_title('Cross-Validation MAPE with Error Bars')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(df['Material'], rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels for CV
for i, v in enumerate(df['MAPE (CV)']):
    ax1.text(i, v + df['+/- (CV)'].iloc[i] + 2, f'{v:.1f}%', 
             ha='center', va='bottom', fontsize=9)

# Chart 2: Hold-out MAPE
ax2.bar(x_pos, df['MAPE (Holdout)'], yerr=df['+/- (Holdout)'], capsize=5, 
        color='red', alpha=0.7)
ax2.set_xlabel('Materials')
ax2.set_ylabel('MAPE (%)')
ax2.set_title('Hold-out MAPE with Error Bars')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(df['Material'], rotation=45)
ax2.grid(True, alpha=0.3)

# Add value labels for Holdout
for i, v in enumerate(df['MAPE (Holdout)']):
    ax2.text(i, v + df['+/- (Holdout)'].iloc[i] + 2, f'{v:.1f}%', 
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
#      Material  Total in dataset  Hold-out number (after preprocessing)  \
# 0        JFMS               235                                    103
# 1        JPCA               186                                     75
# 2       SS316               111                                    107
# 3     SS316-A                95                                     34
# 4     SS316-B                72                                     21
# 5     SS316-C                71                                     21
# 6      SS316L                57                                     53
# 7       SS304                19                                     19
# 8   Zr-2.5 Nb                15                                     14
# 9       CrMoV                11                                     11
# 10      DP600                10                                     10
# 11      DP800                10                                     10
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Performance summary data
data = [
    ["JFMS", 235, 61, 6.02, 1.83, 3.95, 4.32],
    ["JPCA", 186, 43, 9.99, 4.02, 6.96, 12.75],
    ["SS316", 111, 67, 19.22, 2.24, 16.08, 7.21],
    ["SS316-A", 95, 29, 6.98, 3.27, 4.94, 3.61],
    ["SS316-B", 72, 26, 4.98, 3.11, 4.16, 4.25],
    ["SS316-C", 71, 25, 3.94, 0.20, 3.42, 3.58],
    ["SS316L", 57, 52, 9.68, 3.83, 6.71, 6.28],
    ["SS304", 19, 15, 4.49, 2.38, 3.00, 2.33],
    ["Zr-2.5 Nb", 15, 15, 4.45, 2.74, 4.50, 2.36],
    ["CrMoV", 11, 11, 2.94, 2.62, 1.92, 1.62],
    ["DP600", 10, 10, 3.39, 1.20, 2.25, 1.91],
    ["DP800", 10, 10, 3.27, 1.92, 2.22, 2.07],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    "Material", "Total in dataset", "Hold-out number (after preprocessing)",
    "MAPE (without hold-out)", "+/- (without holdout)", "MAPE (with holdout)", "+/- (with holdout)"
])

# Display DataFrame
print(df)

# Create simple MAPE comparison plot with error bars
plt.figure(figsize=(12, 6))

# Set up positions for bars
x_pos = np.arange(len(df))
bar_width = 0.35

# Create bars with error bars
plt.bar(x_pos - bar_width/2, df['MAPE (without hold-out)'], bar_width, 
        yerr=df['+/- (without holdout)'], capsize=4, label='Training MAPE (CV)', 
        color='blue', alpha=0.7)

plt.bar(x_pos + bar_width/2, df['MAPE (with holdout)'], bar_width, 
        yerr=df['+/- (with holdout)'], capsize=4, label='Hold-out MAPE', 
        color='red', alpha=0.7)

# Customize the plot
plt.xlabel('Materials')
plt.ylabel('MAPE (%)')
plt.title('Ultimate Tensile Strength Model Performance: Training Data vs Hold-out Data MAPE')
plt.xticks(x_pos, df['Material'], rotation=45)
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Create separate charts for better readability
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Chart 1: Without Hold-out MAPE
ax1.bar(x_pos, df['MAPE (without hold-out)'], yerr=df['+/- (without holdout)'], capsize=5, 
        color='blue', alpha=0.7)
ax1.set_xlabel('Materials')
ax1.set_ylabel('MAPE (%)')
ax1.set_title('MAPE Without Hold-out (CV) with Error Bars')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(df['Material'], rotation=45)
ax1.grid(True, alpha=0.3)

# Add value labels for Without Hold-out
for i, v in enumerate(df['MAPE (without hold-out)']):
    ax1.text(i, v + df['+/- (without holdout)'].iloc[i] + 0.5, f'{v:.1f}%', 
             ha='center', va='bottom', fontsize=9)

# Chart 2: With Hold-out MAPE
ax2.bar(x_pos, df['MAPE (with holdout)'], yerr=df['+/- (with holdout)'], capsize=5, 
        color='red', alpha=0.7)
ax2.set_xlabel('Materials')
ax2.set_ylabel('MAPE (%)')
ax2.set_title('MAPE With Hold-out with Error Bars')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(df['Material'], rotation=45)
ax2.grid(True, alpha=0.3)

# Add value labels for With Hold-out
for i, v in enumerate(df['MAPE (with holdout)']):
    ax2.text(i, v + df['+/- (with holdout)'].iloc[i] + 0.5, f'{v:.1f}%', 
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
#      Material  Total in dataset  Hold-out number (after preprocessing)  \
# 0        JFMS               235                                     61
# 1        JPCA               186                                     43
# 2       SS316               111                                     67
# 3     SS316-A                95                                     29
# 4     SS316-B                72                                     26
# 5     SS316-C                71                                     25
# 6      SS316L                57                                     52
# 7       SS304                19                                     15
# 8   Zr-2.5 Nb                15                                     15
# 9       CrMoV                11                                     11
# 10      DP600                10                                     10
# 11      DP800                10                                     10
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Performance summary data
data = [
    ["Aluminum Alloys", 9, 9, 17.72, 3.46, 622.2966, 565.8968],
    ["Ferritic-Martensitic Steels", 272, 139, 7.65, 2.48, 49.7463, 36.3814],
    ["Low-Alloy Structural Steels", 70, 30, 8.74, 7.51, 54.4968, 21.9778],
    ["Nickel & Superalloys", 2, 2, 6.10, 6.97, 71.1940, 1.6915],
    ["Other materials", 22, 22, 9.64, 3.66, 33.2682, 42.0786],
    ["Stainless Steels", 636, 353, 33.56, 7.09, 151.8109, 121.4288],
    ["Titanium Alloys", 13, 5, 8.12, 7.41, 45.5125, 4.3608],
    ["Zirconium Alloys", 26, 25, 7.83, 1.79, 56.1018, 10.8841],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    "Chemistry & Alloy Family", "Total rows in dataset", "Holdout after data cleaning",
    "YS MAPE without holdout", "STD without holdout", "YS MAPE on holdout", "STD on holdout"
])

# Display DataFrame
print(df)

# Create simple MAPE comparison plot with error bars
plt.figure(figsize=(12, 6))

# Set up positions for bars
x_pos = np.arange(len(df))
bar_width = 0.35

# Create bars with error bars
bars1 = plt.bar(x_pos - bar_width/2, df['YS MAPE without holdout'], bar_width, 
        yerr=df['STD without holdout'], capsize=4, label='Training MAPE (CV)', 
        color='blue', alpha=0.7)

bars2 = plt.bar(x_pos + bar_width/2, df['YS MAPE on holdout'], bar_width, 
        yerr=df['STD on holdout'], capsize=4, label='Hold-out MAPE', 
        color='red', alpha=0.7)

# Add percentage numbers at the top of each bar
for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    height1 = bar1.get_height()
    height2 = bar2.get_height()
    plt.text(bar1.get_x() + bar1.get_width()/2., height1 + df['STD without holdout'].iloc[i] + 5, 
             f'{height1:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')
    plt.text(bar2.get_x() + bar2.get_width()/2., height2 + df['STD on holdout'].iloc[i] + 20, 
             f'{height2:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

# Customize the plot
plt.xlabel('Alloy Families')
plt.ylabel('Yield Strength MAPE (%)')
plt.title('Yield Strength Model Performance: Without Hold-out vs On Hold-out MAPE')
plt.xticks(x_pos, df['Chemistry & Alloy Family'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Create separate charts for better readability
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Chart 1: Without Hold-out MAPE
bars1 = ax1.bar(x_pos, df['YS MAPE without holdout'], yerr=df['STD without holdout'], capsize=5, 
        color='blue', alpha=0.7)
ax1.set_xlabel('Alloy Families')
ax1.set_ylabel('Yield Strength MAPE (%)')
ax1.set_title('YS MAPE Without Hold-out with Error Bars')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(df['Chemistry & Alloy Family'], rotation=45, ha='right')
ax1.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars1):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + df['STD without holdout'].iloc[i] + 5, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

# Chart 2: On Hold-out MAPE
bars2 = ax2.bar(x_pos, df['YS MAPE on holdout'], yerr=df['STD on holdout'], capsize=5, 
        color='red', alpha=0.7)
ax2.set_xlabel('Alloy Families')
ax2.set_ylabel('Yield Strength MAPE (%)')
ax2.set_title('YS MAPE On Hold-out with Error Bars')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(df['Chemistry & Alloy Family'], rotation=45, ha='right')
ax2.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars2):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + df['STD on holdout'].iloc[i] + 20, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
#       Chemistry & Alloy Family  Total rows in dataset  \
# 0              Aluminum Alloys                      9
# 1  Ferritic-Martensitic Steels                    272
# 2  Low-Alloy Structural Steels                     70
# 3         Nickel & Superalloys                      2
# 4              Other materials                     22
# 5             Stainless Steels                    636
# 6              Titanium Alloys                     13
# 7             Zirconium Alloys                     26
#
#    Holdout after data cleaning  YS MAPE without holdout  STD without holdout  \
# 0                            9                    17.72                 3.46
# 1                          139                     7.65                 2.48
# 2                           30                     8.74                 7.51
# 3                            2                     6.10                 6.97
# 4                           22                     9.64                 3.66
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Performance summary data
data = [
    ["Aluminum Alloys", 9, 9, 11.91, 11.53, 6.8558, 10.4300],
    ["Ferritic-Martensitic Steels", 272, 97, 5.14, 2.12, 3.5802, 3.9286],
    ["Low-Alloy Structural Steels", 70, 30, 6.07, 3.57, 3.0141, 3.4190],
    ["Nickel & Superalloys", 2, 2, 4.49, 3.98, 52.4145, 1.3783],
    ["Other materials", 22, 22, 3.42, 1.17, 2.1263, 1.8788],
    ["Stainless Steels", 636, 280, 10.09, 1.66, 7.8311, 8.5439],
    ["Titanium Alloys", 13, 13, 9.61, 6.71, 7.3449, 8.1582],
    ["Zirconium Alloys", 26, 26, 3.63, 2.48, 3.2274, 2.6401],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    "Chemistry & Alloy Family", "Total rows in dataset", "Hold-out after data cleaning",
    "UTS MAPE without holdout", "STD without holdout", "UTS MAPE on holdout", "STD on holdout"
])

# Display DataFrame
print(df)

# Create simple MAPE comparison plot with error bars
plt.figure(figsize=(12, 6))

# Set up positions for bars
x_pos = np.arange(len(df))
bar_width = 0.35

# Create bars with error bars
bars1 = plt.bar(x_pos - bar_width/2, df['UTS MAPE without holdout'], bar_width, 
        yerr=df['STD without holdout'], capsize=4, label='Training MAPE', 
        color='blue', alpha=0.7)

bars2 = plt.bar(x_pos + bar_width/2, df['UTS MAPE on holdout'], bar_width, 
        yerr=df['STD on holdout'], capsize=4, label='Hold-out MAPE', 
        color='red', alpha=0.7)

# Add percentage numbers at the top of each bar
for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    height1 = bar1.get_height()
    height2 = bar2.get_height()
    plt.text(bar1.get_x() + bar1.get_width()/2., height1 + df['STD without holdout'].iloc[i] + 1, 
             f'{height1:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')
    plt.text(bar2.get_x() + bar2.get_width()/2., height2 + df['STD on holdout'].iloc[i] + 1, 
             f'{height2:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

# Customize the plot
plt.xlabel('Alloy Families')
plt.ylabel('Ultimate Tensile Strength MAPE (%)')
plt.title('Ultimate Tensile Strength Model Performance: Without Hold-out vs On Hold-out UTS MAPE')
plt.xticks(x_pos, df['Chemistry & Alloy Family'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Create separate charts for better readability
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Chart 1: Without Hold-out UTS MAPE
bars1 = ax1.bar(x_pos, df['UTS MAPE without holdout'], yerr=df['STD without holdout'], capsize=5, 
        color='blue', alpha=0.7)
ax1.set_xlabel('Alloy Families')
ax1.set_ylabel('Ultimate Tensile Strength MAPE (%)')
ax1.set_title('UTS MAPE Without Hold-out with Error Bars')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(df['Chemistry & Alloy Family'], rotation=45, ha='right')
ax1.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars1):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + df['STD without holdout'].iloc[i] + 1, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

# Chart 2: On Hold-out UTS MAPE
bars2 = ax2.bar(x_pos, df['UTS MAPE on holdout'], yerr=df['STD on holdout'], capsize=5, 
        color='red', alpha=0.7)
ax2.set_xlabel('Alloy Families')
ax2.set_ylabel('Ultimate Tensile Strength MAPE (%)')
ax2.set_title('UTS MAPE On Hold-out with Error Bars')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(df['Chemistry & Alloy Family'], rotation=45, ha='right')
ax2.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars2):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + df['STD on holdout'].iloc[i] + 1, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
#       Chemistry & Alloy Family  Total rows in dataset  \
# 0              Aluminum Alloys                      9
# 1  Ferritic-Martensitic Steels                    272
# 2  Low-Alloy Structural Steels                     70
# 3         Nickel & Superalloys                      2
# 4              Other materials                     22
# 5             Stainless Steels                    636
# 6              Titanium Alloys                     13
# 7             Zirconium Alloys                     26
#
#    Hold-out after data cleaning  UTS MAPE without holdout  \
# 0                             9                     11.91
# 1                            97                      5.14
# 2                            30                      6.07
# 3                             2                      4.49
# 4                            22                      3.42
# 5                           280                     10.09
# 6                            13                      9.61
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Performance summary data
data = [
    ["Austenitic", 636, 353, 33.56, 7.09, 151.8109, 121.4288],
    ["FCC solid solution", 5, 5, 25.87, 15.97, 473.1161, 361.1255],
    ["Ferrite + Pearlite", 20, 4, 10.07, 7.72, 48.7591, 4.5326],
    ["Ferritic", 18, 18, 12.35, 10.05, 119.0103, 87.1838],
    ["Ferritic-Martensitic", 248, 115, 8.10, 2.88, 23.6186, 20.1306],
    ["Ferritic-Martensitic (dual phase)", 20, 20, 9.73, 4.06, 9.2799, 8.0597],
    ["Martensitic tempered", 4, 4, 11.63, 8.52, 17.4657, 11.4420],
    ["Precipitation-hardened", 6, 6, 11.90, 13.94, 77.8038, 51.4689],
    ["Precipitation-hardened Y'/Y''", 2, 2, 6.10, 6.97, 71.1940, 1.6915],
    ["Refined Ferrite", 2, 2, 8.75, 7.72, 10.5261, 5.2491],
    ["Tempered Bainitic", 39, 15, 3.60, 3.58, 16.1430, 4.0328],
    ["Tempered Martensitic", 11, 11, 1.63, 1.22, 1.8854, 1.6005],
    ["α+β Zr phases", 15, 14, 9.16, 2.42, 8.8126, 3.6555],
    ["α+β titanium", 13, 5, 8.12, 7.41, 45.5125, 4.3608],
    ["α-Zr solid solution", 11, 11, 6.08, 2.15, 31.8902, 8.2507],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    "Material Group", "Total rows in dataset", "Holdout after data cleaning",
    "YS MAPE without holdout", "STD without holdout", "YS MAPE on holdout", "STD on holdout"
])

# Display DataFrame
print(df)

# Create simple MAPE comparison plot with error bars
plt.figure(figsize=(14, 7))

# Set up positions for bars
x_pos = np.arange(len(df))
bar_width = 0.35

# Create bars with error bars
bars1 = plt.bar(x_pos - bar_width/2, df['YS MAPE without holdout'], bar_width, 
        yerr=df['STD without holdout'], capsize=4, label='Without Hold-out', 
        color='blue', alpha=0.7)

bars2 = plt.bar(x_pos + bar_width/2, df['YS MAPE on holdout'], bar_width, 
        yerr=df['STD on holdout'], capsize=4, label='On Hold-out', 
        color='red', alpha=0.7)

# Add percentage numbers at the top of each bar
for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    height1 = bar1.get_height()
    height2 = bar2.get_height()
    plt.text(bar1.get_x() + bar1.get_width()/2., height1 + df['STD without holdout'].iloc[i] + 5, 
             f'{height1:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')
    plt.text(bar2.get_x() + bar2.get_width()/2., height2 + df['STD on holdout'].iloc[i] + 10, 
             f'{height2:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Customize the plot
plt.xlabel('Material Groups')
plt.ylabel('Yield Strength MAPE (%)')
plt.title('YS Model Performance: Without Hold-out vs On Hold-out Yield Strength MAPE')
plt.xticks(x_pos, df['Material Group'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Create separate charts for better readability
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Chart 1: Without Hold-out YS MAPE
bars1 = ax1.bar(x_pos, df['YS MAPE without holdout'], yerr=df['STD without holdout'], capsize=5, 
        color='blue', alpha=0.7)
ax1.set_xlabel('Material Groups')
ax1.set_ylabel('Yield Strength MAPE (%)')
ax1.set_title('YS MAPE Without Hold-out with Error Bars')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(df['Material Group'], rotation=45, ha='right')
ax1.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars1):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + df['STD without holdout'].iloc[i] + 5, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Chart 2: On Hold-out YS MAPE
bars2 = ax2.bar(x_pos, df['YS MAPE on holdout'], yerr=df['STD on holdout'], capsize=5, 
        color='red', alpha=0.7)
ax2.set_xlabel('Material Groups')
ax2.set_ylabel('Yield Strength MAPE (%)')
ax2.set_title('YS MAPE On Hold-out with Error Bars')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(df['Material Group'], rotation=45, ha='right')
ax2.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars2):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + df['STD on holdout'].iloc[i] + 10, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
#                        Material Group  Total rows in dataset  \
# 0                          Austenitic                    636
# 1                  FCC solid solution                      5
# 2                  Ferrite + Pearlite                     20
# 3                            Ferritic                     18
# 4                Ferritic-Martensitic                    248
# 5   Ferritic-Martensitic (dual phase)                     20
# 6                Martensitic tempered                      4
# 7              Precipitation-hardened                      6
# 8       Precipitation-hardened Y'/Y''                      2
# 9                     Refined Ferrite                      2
# 10                  Tempered Bainitic                     39
# 11               Tempered Martensitic                     11
# 12                      α+β Zr phases                     15
# 13                       α+β titanium                     13
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Performance summary data
data = [
    ["Austenitic", 636, 280, 10.09, 1.66, 7.8311, 8.5439],
    ["FCC solid solution", 5, 5, 7.00, 5.05, 2.2292, 1.9773],
    ["Ferrite + Pearlite", 20, 4, 9.90, 6.08, 6.3094, 5.4102],
    ["Ferritic", 18, 18, 5.64, 3.57, 3.3509, 2.9097],
    ["Ferritic-Martensitic", 248, 73, 5.50, 2.14, 3.8527, 4.2234],
    ["Ferritic-Martensitic (dual phase)", 20, 20, 3.04, 1.25, 2.2319, 1.9417],
    ["Martensitic tempered", 4, 4, 10.94, 8.53, 5.5193, 5.5176],
    ["Precipitation-hardened", 6, 6, 15.03, 14.01, 8.7828, 12.5882],
    ["Precipitation-hardened Y'/Y''", 2, 2, 4.49, 3.98, 52.4145, 1.3783],
    ["Refined Ferrite", 2, 2, 6.74, 0.84, 0.6900, 0.2133],
    ["Tempered Bainitic", 39, 15, 2.33, 2.62, 1.7533, 1.8587],
    ["Tempered Martensitic", 11, 11, 2.29, 0.85, 1.4837, 1.1944],
    ["α+β Zr phases", 15, 15, 4.47, 2.57, 4.5004, 2.3640],
    ["α+β titanium", 13, 13, 9.61, 6.71, 7.3449, 8.1582],
    ["α-Zr solid solution", 11, 11, 1.69, 1.00, 1.4916, 1.9636],
]

# Create DataFrame
df = pd.DataFrame(data, columns=[
    "Material Group", "Total rows in dataset", "Hold-out after data cleaning",
    "UTS MAPE without holdout", "STD without holdout", "UTS MAPE on holdout", "STD on holdout"
])

# Display DataFrame
print(df)

# Create simple MAPE comparison plot with error bars
plt.figure(figsize=(14, 7))

# Set up positions for bars
x_pos = np.arange(len(df))
bar_width = 0.35

# Create bars with error bars
bars1 = plt.bar(x_pos - bar_width/2, df['UTS MAPE without holdout'], bar_width, 
        yerr=df['STD without holdout'], capsize=4, label='Without Hold-out', 
        color='blue', alpha=0.7)

bars2 = plt.bar(x_pos + bar_width/2, df['UTS MAPE on holdout'], bar_width, 
        yerr=df['STD on holdout'], capsize=4, label='On Hold-out', 
        color='red', alpha=0.7)

# Add percentage numbers at the top of each bar
for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    height1 = bar1.get_height()
    height2 = bar2.get_height()
    plt.text(bar1.get_x() + bar1.get_width()/2., height1 + df['STD without holdout'].iloc[i] + 1, 
             f'{height1:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')
    plt.text(bar2.get_x() + bar2.get_width()/2., height2 + df['STD on holdout'].iloc[i] + 1, 
             f'{height2:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Customize the plot
plt.xlabel('Material Groups')
plt.ylabel('Ultimate Tensile Strength MAPE (%)')
plt.title('UTS Model Performance: Without Hold-out vs On Hold-out UTS MAPE')
plt.xticks(x_pos, df['Material Group'], rotation=45, ha='right')
plt.legend()
plt.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()

# Create separate charts for better readability
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# Chart 1: Without Hold-out UTS MAPE
bars1 = ax1.bar(x_pos, df['UTS MAPE without holdout'], yerr=df['STD without holdout'], capsize=5, 
        color='blue', alpha=0.7)
ax1.set_xlabel('Material Groups')
ax1.set_ylabel('Ultimate Tensile Strength MAPE (%)')
ax1.set_title('UTS MAPE Without Hold-out with Error Bars')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(df['Material Group'], rotation=45, ha='right')
ax1.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars1):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + df['STD without holdout'].iloc[i] + 1, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

# Chart 2: On Hold-out UTS MAPE
bars2 = ax2.bar(x_pos, df['UTS MAPE on holdout'], yerr=df['STD on holdout'], capsize=5, 
        color='red', alpha=0.7)
ax2.set_xlabel('Material Groups')
ax2.set_ylabel('Ultimate Tensile Strength MAPE (%)')
ax2.set_title('UTS MAPE On Hold-out with Error Bars')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(df['Material Group'], rotation=45, ha='right')
ax2.grid(True, alpha=0.3)

# Add percentage numbers at the top of each bar
for i, bar in enumerate(bars2):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + df['STD on holdout'].iloc[i] + 1, 
             f'{height:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
#                        Material Group  Total rows in dataset  \
# 0                          Austenitic                    636
# 1                  FCC solid solution                      5
# 2                  Ferrite + Pearlite                     20
# 3                            Ferritic                     18
# 4                Ferritic-Martensitic                    248
# 5   Ferritic-Martensitic (dual phase)                     20
# 6                Martensitic tempered                      4
# 7              Precipitation-hardened                      6
# 8       Precipitation-hardened Y'/Y''                      2
# 9                     Refined Ferrite                      2
# 10                  Tempered Bainitic                     39
# 11               Tempered Martensitic                     11
# 12                      α+β Zr phases                     15
# 13                       α+β titanium                     13
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Aluminum yield strength prediction data
aluminum_data = [
    ["Aluminum 6061", 72.0000, 684.4739, -612.4739, 612.4739],
    ["Aluminum 6061", 73.0000, 688.5900, -615.5900, 615.5900],
    ["Aluminum 6061-T6", 294.0000, 687.1890, -393.1890, 393.1890],
    ["Aluminum 6061-T6", 279.0000, 690.6883, -411.6883, 411.6883],
    ["Aluminum alloy EN AW 6006 T6", 264.4000, 692.4316, -428.0316, 428.0316],
    ["Aluminum alloy EN AW 6006 T6", 264.1000, 692.4316, -428.3316, 428.3316],
    ["CP Al (Al – 99.6 wt.%)", 48.4700, 748.6998, -700.2298, 700.2298],
    ["CP Al (Al – 99.6 wt.%)", 51.3500, 748.6998, -697.3498, 697.3498],
    ["CP Al (Al – 99.6 wt.%)", 55.2500, 748.6998, -693.4498, 693.4498],
]

# Create DataFrame
df_aluminum = pd.DataFrame(aluminum_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_aluminum)

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot with different colors for each material type
materials = df_aluminum['Material'].unique()
colors = ['red', 'blue', 'green', 'orange']

for i, material in enumerate(materials):
    material_data = df_aluminum[df_aluminum['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = min(df_aluminum['Yield Strength (MPa)'].min(), df_aluminum['Predicted Yield Strength (MPa)'].min())
max_val = max(df_aluminum['Yield Strength (MPa)'].max(), df_aluminum['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('Aluminum Alloys: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_aluminum)}")
print(f"Average Absolute Error: {df_aluminum['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_aluminum['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_aluminum['Absolute Error (MPa)'].min():.2f} MPa")
# Out:
#                        Material  Yield Strength (MPa)  \
# 0                 Aluminum 6061                 72.00
# 1                 Aluminum 6061                 73.00
# 2              Aluminum 6061-T6                294.00
# 3              Aluminum 6061-T6                279.00
# 4  Aluminum alloy EN AW 6006 T6                264.40
# 5  Aluminum alloy EN AW 6006 T6                264.10
# 6        CP Al (Al – 99.6 wt.%)                 48.47
# 7        CP Al (Al – 99.6 wt.%)                 51.35
# 8        CP Al (Al – 99.6 wt.%)                 55.25
#
#    Predicted Yield Strength (MPa)  Error (MPa)  Absolute Error (MPa)
# 0                        684.4739    -612.4739              612.4739
# 1                        688.5900    -615.5900              615.5900
# 2                        687.1890    -393.1890              393.1890
# 3                        690.6883    -411.6883              411.6883
# 4                        692.4316    -428.0316              428.0316
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Aluminum UTS prediction data
aluminum_uts_data = [
    ["Aluminum 6061", 122.0000, 146.4673, -24.4673, 24.4673],
    ["Aluminum 6061", 119.0000, 142.7561, -23.7561, 23.7561],
    ["Aluminum 6061-T6", 315.0000, 302.1413, 12.8587, 12.8587],
    ["Aluminum 6061-T6", 301.0000, 298.4301, 2.5699, 2.5699],
    ["Aluminum alloy EN AW 6006 T6", 309.3000, 301.2018, 8.0982, 8.0982],
    ["Aluminum alloy EN AW 6006 T6", 311.0000, 301.2018, 9.7982, 9.7982],
    ["CP Al (Al – 99.6 wt.%)", 66.0200, 72.7887, -6.7687, 6.7687],
    ["CP Al (Al – 99.6 wt.%)", 68.3900, 72.7887, -4.3987, 4.3987],
    ["CP Al (Al – 99.6 wt.%)", 73.6400, 72.7887, 0.8513, 0.8513],
]

# Create DataFrame
df_aluminum_uts = pd.DataFrame(aluminum_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_aluminum_uts)

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot with different colors for each material type
materials = df_aluminum_uts['Material'].unique()
colors = ['red', 'blue', 'green', 'orange']

for i, material in enumerate(materials):
    material_data = df_aluminum_uts[df_aluminum_uts['Material'] == material]
    plt.scatter(material_data['Ultimate Tensile Strength (MPa)'], 
               material_data['Predicted UTS (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = min(df_aluminum_uts['Ultimate Tensile Strength (MPa)'].min(), df_aluminum_uts['Predicted UTS (MPa)'].min())
max_val = max(df_aluminum_uts['Ultimate Tensile Strength (MPa)'].max(), df_aluminum_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('Aluminum Alloys: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_aluminum_uts)}")
print(f"Average Absolute Error: {df_aluminum_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_aluminum_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_aluminum_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_aluminum_uts['Absolute Error (MPa)'].mean() / df_aluminum_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#                        Material  Ultimate Tensile Strength (MPa)  \
# 0                 Aluminum 6061                           122.00
# 1                 Aluminum 6061                           119.00
# 2              Aluminum 6061-T6                           315.00
# 3              Aluminum 6061-T6                           301.00
# 4  Aluminum alloy EN AW 6006 T6                           309.30
# 5  Aluminum alloy EN AW 6006 T6                           311.00
# 6        CP Al (Al – 99.6 wt.%)                            66.02
# 7        CP Al (Al – 99.6 wt.%)                            68.39
# 8        CP Al (Al – 99.6 wt.%)                            73.64
#
#    Predicted UTS (MPa)  Error (MPa)  Absolute Error (MPa)
# 0             146.4673     -24.4673               24.4673
# 1             142.7561     -23.7561               23.7561
# 2             302.1413      12.8587               12.8587
# 3             298.4301       2.5699                2.5699
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Titanium yield strength prediction data
titanium_data = [
    ["Titanium Gr.5 (Ti6Al4V)", 913.5000, 451.8811, 461.6189, 461.6189],
    ["Titanium Gr.5 (Ti6Al4V)", 892.3000, 451.8811, 440.4189, 440.4189],
    ["Ti-6Al-4V", 1009.0000, 460.4402, 548.5598, 548.5598],
    ["Ti-6Al-4V", 832.0000, 460.4402, 371.5598, 371.5598],
    ["Ti-6Al-4V", 825.0000, 460.4402, 364.5598, 364.5598],
]

# Create DataFrame
df_titanium = pd.DataFrame(titanium_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_titanium)

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot with different colors for each material type
materials = df_titanium['Material'].unique()
colors = ['red', 'blue']

for i, material in enumerate(materials):
    material_data = df_titanium[df_titanium['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=80, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = min(df_titanium['Yield Strength (MPa)'].min(), df_titanium['Predicted Yield Strength (MPa)'].min())
max_val = max(df_titanium['Yield Strength (MPa)'].max(), df_titanium['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('Titanium Alloys: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_titanium)}")
print(f"Average Actual Yield Strength: {df_titanium['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_titanium['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_titanium['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_titanium['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_titanium['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_titanium['Absolute Error (MPa)'].mean() / df_titanium['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#                   Material  Yield Strength (MPa)  \
# 0  Titanium Gr.5 (Ti6Al4V)                 913.5
# 1  Titanium Gr.5 (Ti6Al4V)                 892.3
# 2                Ti-6Al-4V                1009.0
# 3                Ti-6Al-4V                 832.0
# 4                Ti-6Al-4V                 825.0
#
#    Predicted Yield Strength (MPa)  Error (MPa)  Absolute Error (MPa)
# 0                        451.8811     461.6189              461.6189
# 1                        451.8811     440.4189              440.4189
# 2                        460.4402     548.5598              548.5598
# 3                        460.4402     371.5598              371.5598
# 4                        460.4402     364.5598              364.5598
# Statistics:
# Number of samples: 5
# Average Actual Yield Strength: 894.36 MPa
# Average Predicted Yield Strength: 457.02 MPa
# Average Absolute Error: 437.34 MPa
# Maximum Absolute Error: 548.56 MPa
# Minimum Absolute Error: 364.56 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Titanium UTS prediction data
titanium_uts_data = [
    ["Titanium Gr.5 (Ti6Al4V)", 965.1000, 965.0903, 0.0097, 0.0097],
    ["Titanium Gr.5 (Ti6Al4V)", 981.2000, 965.0903, 16.1097, 16.1097],
    ["Ti6Al4V", 823.0000, 1082.2429, -259.2429, 259.2429],
    ["Ti6Al4V", 1243.0000, 1238.4217, 4.5783, 4.5783],
    ["Ti6Al4V", 811.0000, 848.6091, -37.6091, 37.6091],
    ["Ti6Al4V", 1167.0000, 1082.2429, 84.7571, 84.7571],
    ["Ti6Al4V", 1172.0000, 1082.2429, 89.7571, 89.7571],
    ["Ti6Al4V", 1270.0000, 1238.4217, 31.5783, 31.5783],
    ["Ti6Al4V", 1143.0000, 1081.7224, 61.2776, 61.2776],
    ["Ti6Al4V", 1230.0000, 1082.2429, 147.7571, 147.7571],
    ["Ti-6Al-4V", 1062.0000, 764.3927, 297.6073, 297.6073],
    ["Ti-6Al-4V", 907.0000, 930.3142, -23.3142, 23.3142],
    ["Ti-6Al-4V", 880.0000, 930.3142, -50.3142, 50.3142],
]

# Create DataFrame
df_titanium_uts = pd.DataFrame(titanium_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_titanium_uts)

# Create simple scatter plot
plt.figure(figsize=(8, 8))

# Scatter plot with different colors for each material type
materials = df_titanium_uts['Material'].unique()
colors = ['red', 'blue', 'green']

for i, material in enumerate(materials):
    material_data = df_titanium_uts[df_titanium_uts['Material'] == material]
    plt.scatter(material_data['Ultimate Tensile Strength (MPa)'], 
               material_data['Predicted UTS (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = min(df_titanium_uts['Ultimate Tensile Strength (MPa)'].min(), df_titanium_uts['Predicted UTS (MPa)'].min())
max_val = max(df_titanium_uts['Ultimate Tensile Strength (MPa)'].max(), df_titanium_uts['Predicted UTS (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('Titanium Alloys: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_titanium_uts)}")
print(f"Average Actual UTS: {df_titanium_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_titanium_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_titanium_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_titanium_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_titanium_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_titanium_uts['Absolute Error (MPa)'].mean() / df_titanium_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#                    Material  Ultimate Tensile Strength (MPa)  \
# 0   Titanium Gr.5 (Ti6Al4V)                            965.1
# 1   Titanium Gr.5 (Ti6Al4V)                            981.2
# 2                   Ti6Al4V                            823.0
# 3                   Ti6Al4V                           1243.0
# 4                   Ti6Al4V                            811.0
# 5                   Ti6Al4V                           1167.0
# 6                   Ti6Al4V                           1172.0
# 7                   Ti6Al4V                           1270.0
# 8                   Ti6Al4V                           1143.0
# 9                   Ti6Al4V                           1230.0
# 10                Ti-6Al-4V                           1062.0
# 11                Ti-6Al-4V                            907.0
# 12                Ti-6Al-4V                            880.0
#
#     Predicted UTS (MPa)  Error (MPa)  Absolute Error (MPa)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Yield strength prediction data
yield_strength_data = [
    ["A-533B", 472.7000, 539.3485, -66.6485, 66.6485],
    ["A-533B", 434.8200, 253.4719, 181.3481, 181.3481],
    ["A-533B", 486.0500, 512.3720, -26.3220, 26.3220],
    ["A-533B", 508.0213, 431.0368, 76.9845, 76.9845],
    ["SA508 Cl.3", 434.1400, 233.0832, 201.1018, 201.1018],
    ["SA508 Cl.3", 436.2400, 233.0518, 203.1882, 203.1882],
    ["SA508 Cl.3", 442.6400, 233.0373, 209.6087, 209.6087],
    ["SA508 Cl.3", 442.6100, 233.0294, 209.5806, 209.5806],
    ["SA508 Cl.3", 445.7800, 233.0136, 212.7664, 212.7664],
    ["SA508 Cl.3", 447.0400, 233.0063, 214.0337, 214.0337],
    ["SA508 Cl.3", 446.3900, 232.9949, 213.3951, 213.3951],
    ["SA508 Cl.3", 451.4300, 232.9812, 218.4488, 218.4488],
    ["SA508 Cl.3", 453.6500, 232.9578, 220.6922, 220.6922],
    ["SA508 Cl.3", 446.2700, 232.9936, 213.2764, 213.2764],
    ["Ultra-fine grain (UFG), low carbon steel", 839.8000, 427.8536, 412.4414, 412.4414],
    ["Ultra-fine grain (UFG), low carbon steel", 772.8000, 345.4325, 427.3675, 427.3675],
    ["Experimental low-carbon steel", 1143.4000, 434.3911, 709.0089, 709.0089],
    ["Experimental low-carbon steel", 1133.0000, 434.3903, 698.6097, 698.6097],
    ["Experimental low-carbon steel", 964.1000, 434.3902, 529.7098, 529.7098],
    ["Experimental low-carbon steel", 990.1000, 434.3996, 555.7004, 555.7004],
    ["DC01", 185.0000, 344.2160, -159.2160, 159.2160],
    ["DC01", 185.0000, 344.1940, -159.1940, 159.1940],
    ["DC01", 176.0000, 340.2030, -164.2030, 164.2030],
    ["DC01", 184.0000, 344.1977, -160.1977, 160.1977],
    ["DC01", 184.0000, 344.1861, -160.1861, 160.1861],
    ["DC01", 150.0000, 344.2248, -194.2248, 194.2248],
    ["DC01", 170.0000, 344.1764, -174.1764, 174.1764],
    ["DC01", 176.0000, 344.1864, -168.1864, 168.1864],
    ["DC01", 170.0000, 344.1763, -174.1763, 174.1763],
]

# Create DataFrame
df_yield_strength = pd.DataFrame(yield_strength_data, columns=[
    "Material", "Yield Strength (MPa)", "Predicted Yield Strength (MPa)",
    "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_yield_strength)

# Create simple scatter plot
plt.figure(figsize=(10, 8))

# Scatter plot with different colors for each material type
materials = df_yield_strength['Material'].unique()
colors = ['red', 'blue', 'green', 'orange', 'purple']

for i, material in enumerate(materials):
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = min(df_yield_strength['Yield Strength (MPa)'].min(), df_yield_strength['Predicted Yield Strength (MPa)'].min())
max_val = max(df_yield_strength['Yield Strength (MPa)'].max(), df_yield_strength['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('Steel Alloys: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_yield_strength)}")
print(f"Average Actual Yield Strength: {df_yield_strength['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_yield_strength['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_yield_strength['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_yield_strength['Absolute Error (MPa)'].mean() / df_yield_strength['Yield Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Yield Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
#                                     Material  Yield Strength (MPa)  \
# 0                                     A-533B              472.7000
# 1                                     A-533B              434.8200
# 2                                     A-533B              486.0500
# 3                                     A-533B              508.0213
# 4                                 SA508 Cl.3              434.1400
# 5                                 SA508 Cl.3              436.2400
# 6                                 SA508 Cl.3              442.6400
# 7                                 SA508 Cl.3              442.6100
# 8                                 SA508 Cl.3              445.7800
# 9                                 SA508 Cl.3              447.0400
# 10                                SA508 Cl.3              446.3900
# 11                                SA508 Cl.3              451.4300
# 12                                SA508 Cl.3              453.6500
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Yield strength prediction data
yield_strength_data = [
    ["A-533B", 472.7000, 539.3485, -66.6485, 66.6485],
    ["A-533B", 434.8200, 253.4719, 181.3481, 181.3481],
    ["A-533B", 486.0500, 512.3720, -26.3220, 26.3220],
    ["A-533B", 508.0213, 431.0368, 76.9845, 76.9845],
    ["SA508 Cl.3", 434.1400, 233.0832, 201.1018, 201.1018],
    ["SA508 Cl.3", 436.2400, 233.0518, 203.1882, 203.1882],
    ["SA508 Cl.3", 442.6400, 233.0373, 209.6087, 209.6087],
    ["SA508 Cl.3", 442.6100, 233.0294, 209.5806, 209.5806],
    ["SA508 Cl.3", 445.7800, 233.0136, 212.7664, 212.7664],
    ["SA508 Cl.3", 447.0400, 233.0063, 214.0337, 214.0337],
    ["SA508 Cl.3", 446.3900, 232.9949, 213.3951, 213.3951],
    ["SA508 Cl.3", 451.4300, 232.9812, 218.4488, 218.4488],
    ["SA508 Cl.3", 453.6500, 232.9578, 220.6922, 220.6922],
    ["SA508 Cl.3", 446.2700, 232.9936, 213.2764, 213.2764],
    ["Ultra-fine grain (UFG), low carbon steel", 839.8000, 427.8536, 412.4414, 412.4414],
    ["Ultra-fine grain (UFG), low carbon steel", 772.8000, 345.4325, 427.3675, 427.3675],
    ["Experimental low-carbon steel", 1143.4000, 434.3911, 709.0089, 709.0089],
    ["Experimental low-carbon steel", 1133.0000, 434.3903, 698.6097, 698.6097],
    ["Experimental low-carbon steel", 964.1000, 434.3902, 529.7098, 529.7098],
    ["Experimental low-carbon steel", 990.1000, 434.3996, 555.7004, 555.7004],
    ["DC01", 185.0000, 344.2160, -159.2160, 159.2160],
    ["DC01", 185.0000, 344.1940, -159.1940, 159.1940],
    ["DC01", 176.0000, 340.2030, -164.2030, 164.2030],
    ["DC01", 184.0000, 344.1977, -160.1977, 160.1977],
    ["DC01", 184.0000, 344.1861, -160.1861, 160.1861],
    ["DC01", 150.0000, 344.2248, -194.2248, 194.2248],
    ["DC01", 170.0000, 344.1764, -174.1764, 174.1764],
    ["DC01", 176.0000, 344.1864, -168.1864, 168.1864],
    ["DC01", 170.0000, 344.1763, -174.1763, 174.1763],
]

# Create DataFrame
df_yield_strength = pd.DataFrame(yield_strength_data, columns=[
    "Material", "Yield Strength (MPa)", "Predicted Yield Strength (MPa)",
    "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_yield_strength)

# Create square-shaped scatter plot
plt.figure(figsize=(8, 8))  # Square aspect ratio

# Scatter plot with different colors for each material type
materials = df_yield_strength['Material'].unique()
colors = ['red', 'blue', 'green', 'orange', 'purple']

for i, material in enumerate(materials):
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = min(df_yield_strength['Yield Strength (MPa)'].min(), df_yield_strength['Predicted Yield Strength (MPa)'].min())
max_val = max(df_yield_strength['Yield Strength (MPa)'].max(), df_yield_strength['Predicted Yield Strength (MPa)'].max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('Steel Alloys: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Set equal aspect ratio to make it truly square
plt.axis('equal')

# Set the same limits for x and y axes
axis_limit = max(max_val, 1200)  # Use 1200 as upper limit to accommodate all points
plt.xlim(0, axis_limit)
plt.ylim(0, axis_limit)

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_yield_strength)}")
print(f"Average Actual Yield Strength: {df_yield_strength['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_yield_strength['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_yield_strength['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_yield_strength['Absolute Error (MPa)'].mean() / df_yield_strength['Yield Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Yield Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
#                                     Material  Yield Strength (MPa)  \
# 0                                     A-533B              472.7000
# 1                                     A-533B              434.8200
# 2                                     A-533B              486.0500
# 3                                     A-533B              508.0213
# 4                                 SA508 Cl.3              434.1400
# 5                                 SA508 Cl.3              436.2400
# 6                                 SA508 Cl.3              442.6400
# 7                                 SA508 Cl.3              442.6100
# 8                                 SA508 Cl.3              445.7800
# 9                                 SA508 Cl.3              447.0400
# 10                                SA508 Cl.3              446.3900
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Yield strength prediction data
yield_strength_data = [
    ["A-533B", 472.7000, 539.3485, -66.6485, 66.6485],
    ["A-533B", 434.8200, 253.4719, 181.3481, 181.3481],
    ["A-533B", 486.0500, 512.3720, -26.3220, 26.3220],
    ["A-533B", 508.0213, 431.0368, 76.9845, 76.9845],
    ["SA508 Cl.3", 434.1400, 233.0832, 201.1018, 201.1018],
    ["SA508 Cl.3", 436.2400, 233.0518, 203.1882, 203.1882],
    ["SA508 Cl.3", 442.6400, 233.0373, 209.6087, 209.6087],
    ["SA508 Cl.3", 442.6100, 233.0294, 209.5806, 209.5806],
    ["SA508 Cl.3", 445.7800, 233.0136, 212.7664, 212.7664],
    ["SA508 Cl.3", 447.0400, 233.0063, 214.0337, 214.0337],
    ["SA508 Cl.3", 446.3900, 232.9949, 213.3951, 213.3951],
    ["SA508 Cl.3", 451.4300, 232.9812, 218.4488, 218.4488],
    ["SA508 Cl.3", 453.6500, 232.9578, 220.6922, 220.6922],
    ["SA508 Cl.3", 446.2700, 232.9936, 213.2764, 213.2764],
    ["Ultra-fine grain (UFG), low carbon steel", 839.8000, 427.8536, 412.4414, 412.4414],
    ["Ultra-fine grain (UFG), low carbon steel", 772.8000, 345.4325, 427.3675, 427.3675],
    ["Experimental low-carbon steel", 1143.4000, 434.3911, 709.0089, 709.0089],
    ["Experimental low-carbon steel", 1133.0000, 434.3903, 698.6097, 698.6097],
    ["Experimental low-carbon steel", 964.1000, 434.3902, 529.7098, 529.7098],
    ["Experimental low-carbon steel", 990.1000, 434.3996, 555.7004, 555.7004],
    ["DC01", 185.0000, 344.2160, -159.2160, 159.2160],
    ["DC01", 185.0000, 344.1940, -159.1940, 159.1940],
    ["DC01", 176.0000, 340.2030, -164.2030, 164.2030],
    ["DC01", 184.0000, 344.1977, -160.1977, 160.1977],
    ["DC01", 184.0000, 344.1861, -160.1861, 160.1861],
    ["DC01", 150.0000, 344.2248, -194.2248, 194.2248],
    ["DC01", 170.0000, 344.1764, -174.1764, 174.1764],
    ["DC01", 176.0000, 344.1864, -168.1864, 168.1864],
    ["DC01", 170.0000, 344.1763, -174.1763, 174.1763],
]

# Create DataFrame
df_yield_strength = pd.DataFrame(yield_strength_data, columns=[
    "Material", "Yield Strength (MPa)", "Predicted Yield Strength (MPa)",
    "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_yield_strength)

# Create square-shaped scatter plot
plt.figure(figsize=(12, 12))  # Square figure

# Scatter plot with different colors for each material type
materials = df_yield_strength['Material'].unique()
colors = ['red', 'blue', 'green', 'orange', 'purple']

for i, material in enumerate(materials):
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = 0
max_val = 1200  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('Steel Alloys: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_yield_strength)}")
print(f"Average Actual Yield Strength: {df_yield_strength['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_yield_strength['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_yield_strength['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_yield_strength['Absolute Error (MPa)'].mean() / df_yield_strength['Yield Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Yield Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
#                                     Material  Yield Strength (MPa)  \
# 0                                     A-533B              472.7000
# 1                                     A-533B              434.8200
# 2                                     A-533B              486.0500
# 3                                     A-533B              508.0213
# 4                                 SA508 Cl.3              434.1400
# 5                                 SA508 Cl.3              436.2400
# 6                                 SA508 Cl.3              442.6400
# 7                                 SA508 Cl.3              442.6100
# 8                                 SA508 Cl.3              445.7800
# 9                                 SA508 Cl.3              447.0400
# 10                                SA508 Cl.3              446.3900
# 11                                SA508 Cl.3              451.4300
# 12                                SA508 Cl.3              453.6500
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Yield strength prediction data
yield_strength_data = [
    ["A-533B", 472.7000, 539.3485, -66.6485, 66.6485],
    ["A-533B", 434.8200, 253.4719, 181.3481, 181.3481],
    ["A-533B", 486.0500, 512.3720, -26.3220, 26.3220],
    ["A-533B", 508.0213, 431.0368, 76.9845, 76.9845],
    ["SA508 Cl.3", 434.1400, 233.0832, 201.1018, 201.1018],
    ["SA508 Cl.3", 436.2400, 233.0518, 203.1882, 203.1882],
    ["SA508 Cl.3", 442.6400, 233.0373, 209.6087, 209.6087],
    ["SA508 Cl.3", 442.6100, 233.0294, 209.5806, 209.5806],
    ["SA508 Cl.3", 445.7800, 233.0136, 212.7664, 212.7664],
    ["SA508 Cl.3", 447.0400, 233.0063, 214.0337, 214.0337],
    ["SA508 Cl.3", 446.3900, 232.9949, 213.3951, 213.3951],
    ["SA508 Cl.3", 451.4300, 232.9812, 218.4488, 218.4488],
    ["SA508 Cl.3", 453.6500, 232.9578, 220.6922, 220.6922],
    ["SA508 Cl.3", 446.2700, 232.9936, 213.2764, 213.2764],
    ["Ultra-fine grain (UFG), low carbon steel", 839.8000, 427.8536, 412.4414, 412.4414],
    ["Ultra-fine grain (UFG), low carbon steel", 772.8000, 345.4325, 427.3675, 427.3675],
    ["Experimental low-carbon steel", 1143.4000, 434.3911, 709.0089, 709.0089],
    ["Experimental low-carbon steel", 1133.0000, 434.3903, 698.6097, 698.6097],
    ["Experimental low-carbon steel", 964.1000, 434.3902, 529.7098, 529.7098],
    ["Experimental low-carbon steel", 990.1000, 434.3996, 555.7004, 555.7004],
    ["DC01", 185.0000, 344.2160, -159.2160, 159.2160],
    ["DC01", 185.0000, 344.1940, -159.1940, 159.1940],
    ["DC01", 176.0000, 340.2030, -164.2030, 164.2030],
    ["DC01", 184.0000, 344.1977, -160.1977, 160.1977],
    ["DC01", 184.0000, 344.1861, -160.1861, 160.1861],
    ["DC01", 150.0000, 344.2248, -194.2248, 194.2248],
    ["DC01", 170.0000, 344.1764, -174.1764, 174.1764],
    ["DC01", 176.0000, 344.1864, -168.1864, 168.1864],
    ["DC01", 170.0000, 344.1763, -174.1763, 174.1763],
]

# Create DataFrame
df_yield_strength = pd.DataFrame(yield_strength_data, columns=[
    "Material", "Yield Strength (MPa)", "Predicted Yield Strength (MPa)",
    "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_yield_strength)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot with different colors for each material type
materials = df_yield_strength['Material'].unique()
colors = ['red', 'blue', 'green', 'orange', 'purple']

for i, material in enumerate(materials):
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = 0
max_val = 1200  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('Steel Alloys: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_yield_strength)}")
print(f"Average Actual Yield Strength: {df_yield_strength['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_yield_strength['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_yield_strength['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_yield_strength['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_yield_strength['Absolute Error (MPa)'].mean() / df_yield_strength['Yield Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_yield_strength[df_yield_strength['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Yield Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
#                                     Material  Yield Strength (MPa)  \
# 0                                     A-533B              472.7000
# 1                                     A-533B              434.8200
# 2                                     A-533B              486.0500
# 3                                     A-533B              508.0213
# 4                                 SA508 Cl.3              434.1400
# 5                                 SA508 Cl.3              436.2400
# 6                                 SA508 Cl.3              442.6400
# 7                                 SA508 Cl.3              442.6100
# 8                                 SA508 Cl.3              445.7800
# 9                                 SA508 Cl.3              447.0400
# 10                                SA508 Cl.3              446.3900
# 11                                SA508 Cl.3              451.4300
# 12                                SA508 Cl.3              453.6500
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# UTS prediction data
uts_data = [
    ["A-533B", 676.9800, 853.1131, -176.1331, 176.1331],
    ["A-533B", 638.1300, 853.1131, -214.9831, 214.9831],
    ["A-533B", 692.0000, 853.1131, -161.1131, 161.1131],
    ["A-533B", 721.6000, 853.1131, -131.5131, 131.5131],
    ["SA508 Cl.3", 638.0000, 529.6600, 108.3400, 108.3400],
    ["SA508 Cl.3", 639.0000, 529.6600, 109.3400, 109.3400],
    ["SA508 Cl.3", 645.0000, 529.6600, 115.3400, 115.3400],
    ["SA508 Cl.3", 645.0000, 529.6600, 115.3400, 115.3400],
    ["SA508 Cl.3", 648.0000, 529.6600, 118.3400, 118.3400],
    ["SA508 Cl.3", 649.0000, 529.6600, 119.3400, 119.3400],
    ["SA508 Cl.3", 648.0000, 529.6600, 118.3400, 118.3400],
    ["SA508 Cl.3", 653.0000, 529.6600, 123.3400, 123.3400],
    ["SA508 Cl.3", 655.0000, 529.6600, 125.3400, 125.3400],
    ["SA508 Cl.3", 648.0000, 529.6600, 118.3400, 118.3400],
    ["Ultra-fine grain (UFG), low carbon steel", 1012.0000, 529.6600, 482.3400, 482.3400],
    ["Ultra-fine grain (UFG), low carbon steel", 930.0000, 529.6600, 400.3400, 400.3400],
    ["Experimental low-carbon steel", 1245.0000, 529.6600, 715.3400, 715.3400],
    ["Experimental low-carbon steel", 1232.0000, 529.6600, 702.3400, 702.3400],
    ["Experimental low-carbon steel", 1049.0000, 529.6600, 519.3400, 519.3400],
    ["Experimental low-carbon steel", 1075.0000, 529.6600, 545.3400, 545.3400],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
    ["DC01", 287.0000, 291.8849, -4.8849, 4.8849],
]

# Create DataFrame
df_uts = pd.DataFrame(uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot with different colors for each material type
materials = df_uts['Material'].unique()
colors = ['red', 'blue', 'green', 'orange']

for i, material in enumerate(materials):
    material_data = df_uts[df_uts['Material'] == material]
    plt.scatter(material_data['Ultimate Tensile Strength (MPa)'], 
               material_data['Predicted UTS (MPa)'], 
               alpha=0.7, s=60, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = 0
max_val = 1400  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('Steel Alloys: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_uts)}")
print(f"Average Actual UTS: {df_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_uts['Absolute Error (MPa)'].mean() / df_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_uts[df_uts['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Ultimate Tensile Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
#                                     Material  Ultimate Tensile Strength (MPa)  \
# 0                                     A-533B                           676.98
# 1                                     A-533B                           638.13
# 2                                     A-533B                           692.00
# 3                                     A-533B                           721.60
# 4                                 SA508 Cl.3                           638.00
# 5                                 SA508 Cl.3                           639.00
# 6                                 SA508 Cl.3                           645.00
# 7                                 SA508 Cl.3                           645.00
# 8                                 SA508 Cl.3                           648.00
# 9                                 SA508 Cl.3                           649.00
# 10                                SA508 Cl.3                           648.00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Yield strength prediction data for A-533B and SA508 C1.3
data = [
    ["A-533B", 472.7000, 519.1918, -46.4918, 46.4918],
    ["A-533B", 434.8200, 503.0107, -68.1907, 68.1907],
    ["A-533B", 486.0500, 524.9339, -38.8839, 38.8839],
    ["A-533B", 483.3800, 519.8846, -36.5046, 36.5046],
    ["SA508 C1.3", 434.1400, 459.6546, -25.5146, 25.5146],
    ["SA508 C1.3", 436.7400, 458.1735, -21.4335, 21.4335],
    ["SA508 C1.3", 442.6400, 458.1735, -15.5335, 15.5335],
    ["SA508 C1.3", 442.6100, 458.1735, -15.5635, 15.5635],
    ["SA508 C1.3", 442.5700, 459.8581, -17.2881, 17.2881],
    ["SA508 C1.3", 445.7800, 459.8581, -14.0781, 14.0781],
    ["SA508 C1.3", 447.0400, 459.3164, -12.2764, 12.2764],
    ["SA508 C1.3", 446.9300, 459.3164, -12.3864, 12.3864],
    ["SA508 C1.3", 451.4300, 459.3164, -7.8864, 7.8864],
    ["SA508 C1.3", 446.5500, 457.9191, -11.3691, 11.3691],
    ["SA508 C1.3", 446.2700, 455.4946, -9.2246, 9.2246],
]

# Create DataFrame
df_yield = pd.DataFrame(data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot with different colors for each material type
materials = df_yield['Material'].unique()
colors = ['red', 'blue']

for i, material in enumerate(materials):
    material_data = df_yield[df_yield['Material'] == material]
    plt.scatter(material_data['Yield Strength (MPa)'], 
               material_data['Predicted Yield Strength (MPa)'], 
               alpha=0.7, s=80, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = 400
max_val = 550  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('A-533B and SA508 C1.3: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_yield)}")
print(f"Average Actual Yield Strength: {df_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_yield['Absolute Error (MPa)'].mean() / df_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_yield[df_yield['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Yield Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
#       Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  \
# 0       A-533B                472.70                        519.1918
# 1       A-533B                434.82                        503.0107
# 2       A-533B                486.05                        524.9339
# 3       A-533B                483.38                        519.8846
# 4   SA508 C1.3                434.14                        459.6546
# 5   SA508 C1.3                436.74                        458.1735
# 6   SA508 C1.3                442.64                        458.1735
# 7   SA508 C1.3                442.61                        458.1735
# 8   SA508 C1.3                442.57                        459.8581
# 9   SA508 C1.3                445.78                        459.8581
# 10  SA508 C1.3                447.04                        459.3164
# 11  SA508 C1.3                446.93                        459.3164
# 12  SA508 C1.3                451.43                        459.3164
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# UTS prediction data for A-533B and SA508 C1.3
uts_data = [
    ["A-533B", 619.3600, 635.1331, -15.7731, 15.7731],
    ["A-533B", 579.8700, 646.2137, -66.3437, 66.3437],
    ["A-533B", 641.5700, 637.2007, 4.3693, 4.3693],
    ["A-533B", 641.5600, 635.9757, 5.5843, 5.5843],
    ["SA508 C1.3", 583.4900, 587.7799, -4.2899, 4.2899],
    ["SA508 C1.3", 592.6600, 592.2079, 0.4521, 0.4521],
    ["SA508 C1.3", 598.5700, 578.8363, 19.7337, 19.7337],
    ["SA508 C1.3", 599.8500, 596.4840, 3.3660, 3.3660],
    ["SA508 C1.3", 599.8000, 597.7179, 2.0821, 2.0821],
    ["SA508 C1.3", 595.7800, 597.7179, -1.9379, 1.9379],
    ["SA508 C1.3", 599.0100, 597.7179, 1.2921, 1.2921],
    ["SA508 C1.3", 594.3000, 602.1241, -7.8241, 7.8241],
    ["SA508 C1.3", 606.0300, 602.1241, 3.9059, 3.9059],
    ["SA508 C1.3", 597.8600, 608.5275, -10.6675, 10.6675],
    ["SA508 C1.3", 597.5900, 608.7939, -11.2039, 11.2039],
]

# Create DataFrame
df_uts = pd.DataFrame(uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot with different colors for each material type
materials = df_uts['Material'].unique()
colors = ['red', 'blue']

for i, material in enumerate(materials):
    material_data = df_uts[df_uts['Material'] == material]
    plt.scatter(material_data['Ultimate Tensile Strength (MPa)'], 
               material_data['Predicted UTS (MPa)'], 
               alpha=0.7, s=80, color=colors[i % len(colors)], label=material)

# Perfect prediction line (y = x)
min_val = 550
max_val = 660  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('A-533B and SA508 C1.3: Predicted vs Actual UTS', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_uts)}")
print(f"Average Actual UTS: {df_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_uts['Absolute Error (MPa)'].mean() / df_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")

# Print statistics by material
print(f"\nStatistics by Material:")
for material in materials:
    material_data = df_uts[df_uts['Material'] == material]
    avg_error = material_data['Absolute Error (MPa)'].mean()
    avg_actual = material_data['Ultimate Tensile Strength (MPa)'].mean()
    percentage_error = (avg_error / avg_actual) * 100
    print(f"{material}: {len(material_data)} samples, Avg Error: {avg_error:.1f} MPa ({percentage_error:.1f}%)")
# Out:
#       Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  \
# 0       A-533B                           619.36             635.1331
# 1       A-533B                           579.87             646.2137
# 2       A-533B                           641.57             637.2007
# 3       A-533B                           641.56             635.9757
# 4   SA508 C1.3                           583.49             587.7799
# 5   SA508 C1.3                           592.66             592.2079
# 6   SA508 C1.3                           598.57             578.8363
# 7   SA508 C1.3                           599.85             596.4840
# 8   SA508 C1.3                           599.80             597.7179
# 9   SA508 C1.3                           595.78             597.7179
# 10  SA508 C1.3                           599.01             597.7179
# 11  SA508 C1.3                           594.30             602.1241
# 12  SA508 C1.3                           606.03             602.1241
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# SS304L yield strength prediction data
ss304l_data = [
    ["SS304L", 274.0000, 266.4292, 7.5708, 7.5708],
    ["SS304L", 272.0000, 280.5549, -8.5549, -8.5549],
    ["SS304L", 278.0000, 255.4919, 22.5081, 22.5081],
    ["SS304L", 325.0000, 255.4919, 69.5081, 69.5081],
    ["SS304L", 360.0000, 256.9560, 103.0440, 103.0440],
    ["SS304L", 368.0000, 257.5376, 110.4624, 110.4624],
    ["SS304L", 426.0000, 257.5376, 168.4624, 168.4624],
]

# Create DataFrame
df_ss304l = pd.DataFrame(ss304l_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss304l)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot - all points are the same
plt.scatter(df_ss304l['Yield Strength (MPa)'], 
           df_ss304l['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=80, color='blue', label='SS304L')

# Perfect prediction line (y = x)
min_val = 150
max_val = 350  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS304L: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss304l)}")
print(f"Actual Yield Strength: {df_ss304l['Yield Strength (MPa)'].iloc[0]} MPa")
print(f"Predicted Yield Strength: {df_ss304l['Predicted Yield Strength (MPa)'].iloc[0]} MPa")
print(f"Average Absolute Error: {df_ss304l['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Percentage Error: {(df_ss304l['Absolute Error (MPa)'].mean() / df_ss304l['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  Error (MPa)  \
# 0   SS304L                 274.0                        266.4292       7.5708
# 1   SS304L                 272.0                        280.5549      -8.5549
# 2   SS304L                 278.0                        255.4919      22.5081
# 3   SS304L                 325.0                        255.4919      69.5081
# 4   SS304L                 360.0                        256.9560     103.0440
# 5   SS304L                 368.0                        257.5376     110.4624
# 6   SS304L                 426.0                        257.5376     168.4624
#
#    Absolute Error (MPa)
# 0                7.5708
# 1               -8.5549
# 2               22.5081
# 3               69.5081
# 4              103.0440
# 5              110.4624
# 6              168.4624
# Statistics:
# Number of samples: 7
# Actual Yield Strength: 274.0 MPa
# Predicted Yield Strength: 266.4292 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# SS304L UTS prediction data
ss304l_uts_data = [
    ["SS304L", 789.0000, 773.8620, 15.1380, 15.1380],
    ["SS304L", 781.0000, 751.8060, 29.1940, 29.1940],
    ["SS304L", 669.0000, 671.3596, -2.3596, 2.3596],
    ["SS304L", 645.0000, 650.8989, -5.8989, 5.8989],
    ["SS304L", 660.0000, 659.2403, 0.7597, 0.7597],
    ["SS304L", 680.0000, 686.8544, -6.8544, 6.8544],
    ["SS304L", 698.0000, 692.0394, 5.9606, 5.9606],
]

# Create DataFrame
df_ss304l_uts = pd.DataFrame(ss304l_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss304l_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss304l_uts['Ultimate Tensile Strength (MPa)'], 
           df_ss304l_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=80, color='blue', label='SS304L')

# Perfect prediction line (y = x)
min_val = 600
max_val = 850  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('SS304L: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss304l_uts)}")
print(f"Average Actual UTS: {df_ss304l_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_ss304l_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss304l_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss304l_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss304l_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss304l_uts['Absolute Error (MPa)'].mean() / df_ss304l_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  Error (MPa)  \
# 0   SS304L                            789.0             773.8620      15.1380
# 1   SS304L                            781.0             751.8060      29.1940
# 2   SS304L                            669.0             671.3596      -2.3596
# 3   SS304L                            645.0             650.8989      -5.8989
# 4   SS304L                            660.0             659.2403       0.7597
# 5   SS304L                            680.0             686.8544      -6.8544
# 6   SS304L                            698.0             692.0394       5.9606
#
#    Absolute Error (MPa)
# 0               15.1380
# 1               29.1940
# 2                2.3596
# 3                5.8989
# 4                0.7597
# 5                6.8544
# 6                5.9606
# Statistics:
# Number of samples: 7
# Average Actual UTS: 703.14 MPa
# Average Predicted UTS: 698.01 MPa
# Average Absolute Error: 9.45 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 20MnNiMo55 yield strength prediction data
data_20MnNiMo55 = [
    ["20MnNiMo55", 496.3700, 501.0241, -4.6541, 4.6541],
    ["20MnNiMo55", 485.1500, 505.8140, -20.6640, 20.6640],
    ["20MnNiMo55", 473.0200, 487.1098, -14.0898, 14.0898],
    ["20MnNiMo55", 499.8900, 487.1098, 12.7802, 12.7802],
    ["20MnNiMo55", 473.2400, 492.6239, -19.3839, 19.3839],
    ["20MnNiMo55", 456.5800, 492.6239, -36.0439, 36.0439],
    ["20MnNiMo55", 484.8100, 492.6239, -7.8139, 7.8139],
]

# Create DataFrame
df_20MnNiMo55 = pd.DataFrame(data_20MnNiMo55, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_20MnNiMo55)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_20MnNiMo55['Yield Strength (MPa)'], 
           df_20MnNiMo55['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=80, color='blue', label='20MnNiMo55')

# Perfect prediction line (y = x)
min_val = 440
max_val = 520  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('20MnNiMo55: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_20MnNiMo55)}")
print(f"Average Actual Yield Strength: {df_20MnNiMo55['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_20MnNiMo55['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_20MnNiMo55['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_20MnNiMo55['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_20MnNiMo55['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_20MnNiMo55['Absolute Error (MPa)'].mean() / df_20MnNiMo55['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  \
# 0  20MnNiMo55                496.37                        501.0241
# 1  20MnNiMo55                485.15                        505.8140
# 2  20MnNiMo55                473.02                        487.1098
# 3  20MnNiMo55                499.89                        487.1098
# 4  20MnNiMo55                473.24                        492.6239
# 5  20MnNiMo55                456.58                        492.6239
# 6  20MnNiMo55                484.81                        492.6239
#
#    Error (MPa)  Absolute Error (MPa)
# 0      -4.6541                4.6541
# 1     -20.6640               20.6640
# 2     -14.0898               14.0898
# 3      12.7802               12.7802
# 4     -19.3839               19.3839
# 5     -36.0439               36.0439
# 6      -7.8139                7.8139
# Statistics:
# Number of samples: 7
# Average Actual Yield Strength: 481.29 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 20MnNiMo55 UTS prediction data
data_20MnNiMo55_uts = [
    ["20MnNiMo55", 625.1700, 621.5408, 3.6292, 3.6292],
    ["20MnNiMo55", 621.6500, 618.4181, 3.2319, 3.2319],
    ["20MnNiMo55", 620.4100, 631.2753, -10.8653, 10.8653],
    ["20MnNiMo55", 641.8400, 631.2753, 10.5647, 10.5647],
    ["20MnNiMo55", 604.3100, 602.2624, 2.0476, 2.0476],
    ["20MnNiMo55", 595.3500, 602.2624, -6.9124, 6.9124],
    ["20MnNiMo55", 610.4300, 602.2624, 8.1676, 8.1676],
]

# Create DataFrame
df_20MnNiMo55_uts = pd.DataFrame(data_20MnNiMo55_uts, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_20MnNiMo55_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_20MnNiMo55_uts['Ultimate Tensile Strength (MPa)'], 
           df_20MnNiMo55_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=80, color='blue', label='20MnNiMo55')

# Perfect prediction line (y = x)
min_val = 580
max_val = 660  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('20MnNiMo55: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_20MnNiMo55_uts)}")
print(f"Average Actual UTS: {df_20MnNiMo55_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_20MnNiMo55_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_20MnNiMo55_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_20MnNiMo55_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_20MnNiMo55_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_20MnNiMo55_uts['Absolute Error (MPa)'].mean() / df_20MnNiMo55_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#      Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  \
# 0  20MnNiMo55                           625.17             621.5408
# 1  20MnNiMo55                           621.65             618.4181
# 2  20MnNiMo55                           620.41             631.2753
# 3  20MnNiMo55                           641.84             631.2753
# 4  20MnNiMo55                           604.31             602.2624
# 5  20MnNiMo55                           595.35             602.2624
# 6  20MnNiMo55                           610.43             602.2624
#
#    Error (MPa)  Absolute Error (MPa)
# 0       3.6292                3.6292
# 1       3.2319                3.2319
# 2     -10.8653               10.8653
# 3      10.5647               10.5647
# 4       2.0476                2.0476
# 5      -6.9124                6.9124
# 6       8.1676                8.1676
# Statistics:
# Number of samples: 7
# Average Actual UTS: 617.02 MPa
# Average Predicted UTS: 615.61 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# SS304L yield strength prediction data
ss304l_yield_data = [
    ["SS304L", 274.0000, 435.1082, -161.1082, 161.1082],
    ["SS304L", 272.0000, 445.8512, -173.8512, 173.8512],
    ["SS304L", 278.0000, 331.0033, -53.0033, 53.0033],
    ["SS304L", 325.0000, 331.0033, -6.0033, 6.0033],
    ["SS304L", 360.0000, 331.0033, 28.9967, 28.9967],
    ["SS304L", 368.0000, 350.1994, 17.8006, 17.8006],
    ["SS304L", 426.0000, 350.1994, 75.8006, 75.8006],
]

# Create DataFrame
df_ss304l_yield = pd.DataFrame(ss304l_yield_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss304l_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot - plot all data points
plt.scatter(df_ss304l_yield['Yield Strength (MPa)'], 
           df_ss304l_yield['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=80, color='blue', label='SS304L')

# Perfect prediction line (y = x)
min_val = 250
max_val = 500  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS304L: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss304l_yield)}")
print(f"Average Actual Yield Strength: {df_ss304l_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_ss304l_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss304l_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss304l_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss304l_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss304l_yield['Absolute Error (MPa)'].mean() / df_ss304l_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  Error (MPa)  \
# 0   SS304L                 274.0                        435.1082    -161.1082
# 1   SS304L                 272.0                        445.8512    -173.8512
# 2   SS304L                 278.0                        331.0033     -53.0033
# 3   SS304L                 325.0                        331.0033      -6.0033
# 4   SS304L                 360.0                        331.0033      28.9967
# 5   SS304L                 368.0                        350.1994      17.8006
# 6   SS304L                 426.0                        350.1994      75.8006
#
#    Absolute Error (MPa)
# 0              161.1082
# 1              173.8512
# 2               53.0033
# 3                6.0033
# 4               28.9967
# 5               17.8006
# 6               75.8006
# Statistics:
# Number of samples: 7
# Average Actual Yield Strength: 329.00 MPa
# Average Predicted Yield Strength: 367.77 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# SS304L UTS prediction data
ss304l_uts_data = [
    ["SS304L", 789.0000, 773.8620, 15.1380, 15.1380],
    ["SS304L", 781.0000, 751.8060, 29.1940, 29.1940],
    ["SS304L", 669.0000, 671.3596, -2.3596, 2.3596],
    ["SS304L", 645.0000, 650.8989, -5.8989, 5.8989],
    ["SS304L", 660.0000, 659.2403, 0.7597, 0.7597],
    ["SS304L", 680.0000, 686.8544, -6.8544, 6.8544],
    ["SS304L", 698.0000, 692.0394, 5.9606, 5.9606],
]

# Create DataFrame
df_ss304l_uts = pd.DataFrame(ss304l_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss304l_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss304l_uts['Ultimate Tensile Strength (MPa)'], 
           df_ss304l_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=80, color='blue', label='SS304L')

# Perfect prediction line (y = x)
min_val = 600
max_val = 850  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Ultimate Tensile Strength (MPa)', fontsize=12)
plt.title('SS304L: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss304l_uts)}")
print(f"Average Actual UTS: {df_ss304l_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_ss304l_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss304l_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss304l_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss304l_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss304l_uts['Absolute Error (MPa)'].mean() / df_ss304l_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  Error (MPa)  \
# 0   SS304L                            789.0             773.8620      15.1380
# 1   SS304L                            781.0             751.8060      29.1940
# 2   SS304L                            669.0             671.3596      -2.3596
# 3   SS304L                            645.0             650.8989      -5.8989
# 4   SS304L                            660.0             659.2403       0.7597
# 5   SS304L                            680.0             686.8544      -6.8544
# 6   SS304L                            698.0             692.0394       5.9606
#
#    Absolute Error (MPa)
# 0               15.1380
# 1               29.1940
# 2                2.3596
# 3                5.8989
# 4                0.7597
# 5                6.8544
# 6                5.9606
# Statistics:
# Number of samples: 7
# Average Actual UTS: 703.14 MPa
# Average Predicted UTS: 698.01 MPa
# Average Absolute Error: 9.45 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# SS316L yield strength prediction data (rows 0–52)
ss316l_yield_data = [
    ["SS316L", 721.0700, 309.4656, 411.6044, 411.6044],
    ["SS316L", 544.8100, 309.4656, 235.3444, 235.3444],
    ["SS316L", 264.3900, 265.0818, -0.6918, 0.6918],
    ["SS316L", 691.8500, 250.0156, 441.8344, 441.8344],
    ["SS316L", 522.0200, 261.0282, 260.9918, 260.9918],
    ["SS316L", 249.2100, 305.4120, -56.2020, 56.2020],
    ["SS316L", 763.8000, 254.0692, 509.7308, 509.7308],
    ["SS316L", 554.1500, 265.0818, 289.0682, 289.0682],
MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss316l_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss316l_yield['Yield Strength (MPa)'], 
           df_ss316l_yield['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=60, color='blue', label='SS316L')

# Perfect prediction line (y = x)
min_val = 150
max_val = 800  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS316L: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss316l_yield)}")
print(f"Average Actual Yield Strength: {df_ss316l_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_ss316l_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss316l_yield['Absolute Error (MPa)'].mean() / df_ss316l_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#    Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  \
# 0    SS316L                721.07                        309.4656
# 1    SS316L                544.81                        309.4656
# 2    SS316L                264.39                        265.0818
# 3    SS316L                691.85                        250.0156
# 4    SS316L                522.02                        261.0282
# 5    SS316L                249.21                        305.4120
# 6    SS316L                763.80                        254.0692
# 7    SS316L                554.15                        265.0818
# 8    SS316L                260.39                        265.0818
# 9    SS316L                734.42                        254.0692
# 10   SS316L                519.44                        329.3098
# 11   SS316L                245.70                        329.3098
# 12   SS316L                643.62                        309.4656
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# SS316L UTS prediction data
ss316l_uts_data = [
    ["SS316L", 822.8700, 775.9487, 46.9213, 46.9213],
    ["SS316L", 738.8900, 717.6843, 21.2057, 21.2057],
    ["SS316L", 624.0600, 631.9865, -7.9265, 7.9265],
    ["SS316L", 808.0700, 735.1737, 72.8963, 72.8963],
    ["SS316L", 732.7300, 715.2095, 17.5205, 17.5205],
    ["SS316L", 593.2100, 613.6555, -20.4455, 20.4455],
    ["SS316L", 830.2700, 771.3049, 58.9651, 58.9651],
    ["SS316L", 732.7200, 714.4568, 18.2632, 18.2632],
    ["SS316L", 616.6500, 626.9779, -10.3279, 10.3279],
    ["SS316L", 805.5800, 771.3049, 34.2751, 34.2751],
    ["SS316L", 715.4300, 709.2510, 6.1790, 6.1790],
    ["SS316L", 606.7700, 631.2109, -24.4409, 24.4409],
    ["SS316L", 743.8600, 738.9583, 4.9017, 4.9017],
    ["SS316L", 561.0900, 621.7691, -60.6791, 60.6791],
    ["SS316L", 580.1100, 572.8364, 7.2736, 7.2736],
    ["SS316L", 565.9100, 572.8364, -6.9264, 6.9264],
    ["SS316L", 564.6900, 577.5597, -12.8697, 12.8697],
    ["SS316L", 526.1400, 552.9397, -26.7997, 26.7997],
    ["SS316L", 520.4500, 565.5930, -45.1430, 45.1430],
    ["SS316L", 339.7800, 367.8192, -28.0392, 28.0392],
    ["SS316L", 397.8500, 388.6236, 9.2264, 9.2264],
    ["SS316L", 462.3700, 470.0036, -7.6336, 7.6336],
    ["SS316L", 546.2400, 546.1192, 0.1208, 0.1208],
    ["SS316L", 556.9900, 557.5275, -0.5375, 0.5375],
    ["SS316L", 660.0000, 664.6853, -4.6853, 4.6853],
    ["SS316L", 689.0000, 664.6853, 24.3147, 24.3147],
    ["SS316L", 1403.0000, 1120.0519, 282.9481, 282.9481],
    ["SS316L", 1113.0000, 1120.0519, -7.0519, 7.0519],
    ["SS316L", 685.0000, 664.6853, 20.3147, 20.3147],
    ["SS316L", 700.0000, 664.6853, 35.3147, 35.3147],
    ["SS316L", 640.0000, 664.6853, -24.6853, 24.6853],
    ["SS316L", 564.0000, 664.6853, -100.6853, 100.6853],
    ["SS316L", 1083.0000, 1120.0519, -37.0519, 37.0519],
    ["SS316L", 1235.0000, 1120.0519, 114.9481, 114.9481],
    ["SS316L", 529.0000, 600.2198, -71.2198, 71.2198],
    ["SS316L", 520.0000, 600.2198, -80.2198, 80.2198],
    ["SS316L", 680.0000, 600.2198, 79.7802, 79.7802],
    ["SS316L", 664.0000, 664.6853, -0.6853, 0.6853],
    ["SS316L", 591.0000, 664.6853, -73.6853, 73.6853],
    ["SS316L", 684.0000, 664.6853, 19.3147, 19.3147],
    ["SS316L", 688.0000, 664.6853, 23.3147, 23.3147],
    ["SS316L", 594.0000, 664.6853, -70.6853, 70.6853],
    ["SS316L", 703.0000, 664.6853, 38.3147, 38.3147],
    ["SS316L", 717.0000, 664.6853, 52.3147, 52.3147],
    ["SS316L", 563.0000, 600.2198, -37.2198, 37.2198],
    ["SS316L", 620.0000, 600.2198, 19.7802, 19.7802],
    ["SS316L", 600.0000, 600.2198, -0.2198, 0.2198],
    ["SS316L", 573.0000, 590.8784, -17.8784, 17.8784],
    ["SS316L", 565.0000, 584.9954, -19.9954, 19.9954],
    ["SS316L", 566.0000, 584.9954, -18.9954, 18.9954],
    ["SS316L", 590.0000, 588.1833, 1.8167, 1.8167],
    ["SS316L", 619.0000, 623.3241, -4.3241, 4.3241],
]

# Create DataFrame
df_ss316l_uts = pd.DataFrame(ss316l_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss316l_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss316l_uts['Ultimate Tensile Strength (MPa)'], 
           df_ss316l_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=60, color='blue', label='SS316L')

# Perfect prediction line (y = x)
min_val = 300
max_val = 1450  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted UTS (MPa)', fontsize=12)
plt.title('SS316L: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss316l_uts)}")
print(f"Average Actual UTS: {df_ss316l_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_ss316l_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss316l_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df
    ["SS316L", 216.0000, 323.0929, -107.0929, 107.0929],
    ["SS316L", 220.0000, 323.0929, -103.0929, 103.0929],
    ["SS316L", 270.0000, 323.0929, -53.0929, 53.0929],
    ["SS316L", 663.0000, 302.3516, 360.6484, 360.6484],
    ["SS316L", 602.0000, 302.3516, 299.6484, 299.6484],
    ["SS316L", 557.0000, 302.3516, 254.6484, 254.6484],
    ["SS316L", 555.0000, 302.3516, 252.6484, 252.6484],
    ["SS316L", 561.0000, 302.3516, 258.6484, 258.6484],
    ["SS316L", 487.0000, 302.3516, 184.6484, 184.6484],
    ["SS316L", 456.0000, 302.3516, 153.6484, 153.6484],
    ["SS316L", 496.0000, 302.3516, 193.6484, 193.6484],
    ["SS316L", 345.0000, 323.0929, 21.9071, 21.9071],
    ["SS316L", 310.0000, 323.0929, -13.0929, 13.0929],
    ["SS316L", 468.0000, 323.0929, 144.9071, 144.9071],
    ["SS316L", 255.0000, 299.7696, -44.7696, 44.7696],
    ["SS316L", 272.0000, 262.8832, 9.1168, 9.1168],
    ["SS316L", 283.0000, 262.8832, 20.1168, 20.1168],
    ["SS316L", 326.0000, 306.1144, 19.8856, 19.8856],
    ["SS316L", 348.0000, 313.0122, 34.9878, 34.9878],
]

# Create DataFrame
df_ss316l_yield = pd.DataFrame(ss316l_yield_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss316l_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss316l_yield['Yield Strength (MPa)'], 
           df_ss316l_yield['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=60, color='blue', label='SS316L')

# Perfect prediction line (y = x)
min_val = 150
max_val = 800  # Set consistent max value for both axes
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS316L: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss316l_yield)}")
print(f"Average Actual Yield Strength: {df_ss316l_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_ss316l_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss316l_yield['Absolute Error (MPa)'].mean() / df_ss316l_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#    Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  \
# 0    SS316L                721.07                        309.4656
# 1    SS316L                544.81                        309.4656
# 2    SS316L                264.39                        265.0818
# 3    SS316L                691.85                        250.0156
# 4    SS316L                522.02                        261.0282
# 5    SS316L                249.21                        305.4120
# 6    SS316L                763.80                        254.0692
# 7    SS316L                554.15                        265.0818
# 8    SS316L                260.39                        265.0818
# 9    SS316L                734.42                        254.0692
# 10   SS316L                519.44                        329.3098
# 11   SS316L                245.70                        329.3098
# 12   SS316L                643.62                        309.4656
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

    ["SS316L", 565.0000, 575.9501, -10.9501, 10.9501],
    ["SS316L", 566.0000, 576.5201, -10.5201, 10.5201],
    ["SS316L", 590.0000, 586.6016, 3.3984, 3.3984],
    ["SS316L", 619.0000, 609.2771, 9.7229, 9.7229],
]

# Create DataFrame
df_ss316l_uts = pd.DataFrame(ss316l_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss316l_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss316l_uts['Ultimate Tensile Strength (MPa)'], 
           df_ss316l_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=60, color='blue', label='SS316L')

# Perfect prediction line (y = x)
min_val = 300
max_val = 1450  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted UTS (MPa)', fontsize=12)
plt.title('SS316L: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss316l_uts)}")
print(f"Average Actual UTS: {df_ss316l_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_ss316l_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss316l_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss316l_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss316l_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss316l_uts['Absolute Error (MPa)'].mean() / df_ss316l_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#    Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  \
# 0    SS316L                           822.87             786.9266
# 1    SS316L                           738.89             732.8781
# 2    SS316L                           624.06             667.0721
# 3    SS316L                           808.07             771.9500
# 4    SS316L                           732.73             703.7388
# 5    SS316L                           593.21             623.4134
# 6    SS316L                           830.27             758.1607
# 7    SS316L                           732.72             720.6911
# 8    SS316L                           616.65             672.7113
# 9    SS316L                           805.58             752.2481
# 10   SS316L                           715.43             703.1097
# 11   SS316L                           606.77             635.0779
# 12   SS316L                           743.86             700.7482
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# SS304L yield strength prediction data
ss304l_yield_data = [
    ["SS304L", 274.0000, 435.1082, -161.1082, 161.1082],
    ["SS304L", 272.0000, 445.8512, -173.8512, 173.8512],
    ["SS304L", 278.0000, 331.0033, -53.0033, 53.0033],
    ["SS304L", 325.0000, 331.0033, -6.0033, 6.0033],
    ["SS304L", 360.0000, 331.0033, 28.9967, 28.9967],
    ["SS304L", 368.0000, 350.1994, 17.8006, 17.8006],
    ["SS304L", 426.0000, 350.1994, 75.8006, 75.8006],
]

# Create DataFrame
df_ss304l_yield = pd.DataFrame(ss304l_yield_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_ss304l_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_ss304l_yield['Yield Strength (MPa)'], 
           df_ss304l_yield['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=60, color='blue', label='SS304L')

# Perfect prediction line (y = x)
min_val = 250
max_val = 500  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('SS304L: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_ss304l_yield)}")
print(f"Average Actual Yield Strength: {df_ss304l_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_ss304l_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_ss304l_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_ss316l_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_ss304l_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_ss304l_yield['Absolute Error (MPa)'].mean() / df_ss304l_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  Error (MPa)  \
# 0   SS304L                 274.0                        435.1082    -161.1082
# 1   SS304L                 272.0                        445.8512    -173.8512
# 2   SS304L                 278.0                        331.0033     -53.0033
# 3   SS304L                 325.0                        331.0033      -6.0033
# 4   SS304L                 360.0                        331.0033      28.9967
# 5   SS304L                 368.0                        350.1994      17.8006
# 6   SS304L                 426.0                        350.1994      75.8006
#
#    Absolute Error (MPa)
# 0              161.1082
# 1              173.8512
# 2               53.0033
# 3                6.0033
# 4               28.9967
# 5               17.8006
# 6               75.8006
# Statistics:
# Number of samples: 7
# Average Actual Yield Strength: 329.00 MPa
# Average Predicted Yield Strength: 367.77 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 20MnNiMo55 yield strength prediction data
mnni_data = [
    ["20MnNiMo55", 496.3700, 583.7580, -87.3880, 87.3880],
    ["20MnNiMo55", 485.1500, 584.5501, -99.4001, 99.4001],
    ["20MnNiMo55", 473.0200, 349.6076, 123.4124, 123.4124],
    ["20MnNiMo55", 499.8900, 349.6076, 150.2824, 150.2824],
    ["20MnNiMo55", 473.2400, 336.3667, 136.8733, 136.8733],
    ["20MnNiMo55", 456.5800, 336.3667, 120.2133, 120.2133],
    ["20MnNiMo55", 484.8100, 336.3667, 148.4433, 148.4433],
]

# Create DataFrame
df_mnni_yield = pd.DataFrame(mnni_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_mnni_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_mnni_yield['Yield Strength (MPa)'], 
           df_mnni_yield['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=60, color='BLUE', label='20MnNiMo55')

# Perfect prediction line (y = x)
min_val = 300
max_val = 650  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('20MnNiMo55: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_mnni_yield)}")
print(f"Average Actual Yield Strength: {df_mnni_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_mnni_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_mnni_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_mnni_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_mnni_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_mnni_yield['Absolute Error (MPa)'].mean() / df_mnni_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#      Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  \
# 0  20MnNiMo55                496.37                        583.7580
# 1  20MnNiMo55                485.15                        584.5501
# 2  20MnNiMo55                473.02                        349.6076
# 3  20MnNiMo55                499.89                        349.6076
# 4  20MnNiMo55                473.24                        336.3667
# 5  20MnNiMo55                456.58                        336.3667
# 6  20MnNiMo55                484.81                        336.3667
#
#    Error (MPa)  Absolute Error (MPa)
# 0     -87.3880               87.3880
# 1     -99.4001               99.4001
# 2     123.4124              123.4124
# 3     150.2824              150.2824
# 4     136.8733              136.8733
# 5     120.2133              120.2133
# 6     148.4433              148.4433
# Statistics:
# Number of samples: 7
# Average Actual Yield Strength: 481.29 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 20MnNiMo55 UTS prediction data
mnni_uts_data = [
    ["20MnNiMo55", 625.1700, 626.9381, -1.7681, 1.7681],
    ["20MnNiMo55", 621.6500, 626.9381, -5.2881, 5.2881],
    ["20MnNiMo55", 620.4100, 632.8252, -12.4152, 12.4152],
    ["20MnNiMo55", 641.8400, 632.8252, 9.0148, 9.0148],
    ["20MnNiMo55", 604.3100, 602.9630, 1.3470, 1.3470],
    ["20MnNiMo55", 595.3500, 602.9630, -7.6130, 7.6130],
    ["20MnNiMo55", 610.4300, 602.9630, 7.4670, 7.4670],
]

# Create DataFrame
df_mnni_uts = pd.DataFrame(mnni_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_mnni_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_mnni_uts['Ultimate Tensile Strength (MPa)'], 
           df_mnni_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=60, color='blue', label='20MnNiMo55')

# Perfect prediction line (y = x)
min_val = 590
max_val = 650  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted UTS (MPa)', fontsize=12)
plt.title('20MnNiMo55: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_mnni_uts)}")
print(f"Average Actual UTS: {df_mnni_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_mnni_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_mnni_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_mnni_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_mnni_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_mnni_uts['Absolute Error (MPa)'].mean() / df_mnni_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#      Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  \
# 0  20MnNiMo55                           625.17             626.9381
# 1  20MnNiMo55                           621.65             626.9381
# 2  20MnNiMo55                           620.41             632.8252
# 3  20MnNiMo55                           641.84             632.8252
# 4  20MnNiMo55                           604.31             602.9630
# 5  20MnNiMo55                           595.35             602.9630
# 6  20MnNiMo55                           610.43             602.9630
#
#    Error (MPa)  Absolute Error (MPa)
# 0      -1.7681                1.7681
# 1      -5.2881                5.2881
# 2     -12.4152               12.4152
# 3       9.0148                9.0148
# 4       1.3470                1.3470
# 5      -7.6130                7.6130
# 6       7.4670                7.4670
# Statistics:
# Number of samples: 7
# Average Actual UTS: 617.02 MPa
# Average Predicted UTS: 618.35 MPa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# FeCrAl yield strength prediction data
fecral_yield_data = [
    ["FeCrAl", 710.0000, 565.2405, 144.7595, 144.7595],
    ["FeCrAl", 607.0000, 466.4545, 140.5455, 140.5455],
    ["FeCrAl", 725.0000, 466.4545, 258.5455, 258.5455],
    ["FeCrAl", 663.0000, 464.0017, 198.9983, 198.9983],
    ["FeCrAl", 761.0000, 464.0017, 296.9983, 296.9983],
    ["FeCrAl", 708.0000, 545.9950, 162.0050, 162.0050],
    ["FeCrAl", 705.0000, 545.9950, 159.0050, 159.0050],
    ["FeCrAl", 702.0000, 545.9950, 156.0050, 156.0050],
    ["FeCrAl", 753.0000, 545.9950, 207.0050, 207.0050],
]

# Create DataFrame
df_fecral_yield = pd.DataFrame(fecral_yield_data, columns=[
    "Material", "Yield Strength (MPa)",
    "Predicted Yield Strength (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_fecral_yield)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_fecral_yield['Yield Strength (MPa)'], 
           df_fecral_yield['Predicted Yield Strength (MPa)'], 
           alpha=0.7, s=60, color='blue', label='FeCrAl')

# Perfect prediction line (y = x)
min_val = 400
max_val = 800  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Yield Strength (MPa)', fontsize=12)
plt.ylabel('Predicted Yield Strength (MPa)', fontsize=12)
plt.title('FeCrAl: Predicted vs Actual Yield Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print some statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_fecral_yield)}")
print(f"Average Actual Yield Strength: {df_fecral_yield['Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted Yield Strength: {df_fecral_yield['Predicted Yield Strength (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_fecral_yield['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_fecral_yield['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_fecral_yield['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_fecral_yield['Absolute Error (MPa)'].mean() / df_fecral_yield['Yield Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Yield Strength (MPa)  Predicted Yield Strength (MPa)  Error (MPa)  \
# 0   FeCrAl                 710.0                        565.2405     144.7595
# 1   FeCrAl                 607.0                        466.4545     140.5455
# 2   FeCrAl                 725.0                        466.4545     258.5455
# 3   FeCrAl                 663.0                        464.0017     198.9983
# 4   FeCrAl                 761.0                        464.0017     296.9983
# 5   FeCrAl                 708.0                        545.9950     162.0050
# 6   FeCrAl                 705.0                        545.9950     159.0050
# 7   FeCrAl                 702.0                        545.9950     156.0050
# 8   FeCrAl                 753.0                        545.9950     207.0050
#
#    Absolute Error (MPa)
# 0              144.7595
# 1              140.5455
# 2              258.5455
# 3              198.9983
# 4              296.9983
# 5              162.0050
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# FeCrAl UTS prediction data
fecral_uts_data = [
    ["FeCrAl", 767.0000, 775.6503, -8.6503, 8.6503],
    ["FeCrAl", 760.0000, 779.2175, -19.2175, 19.2175],
    ["FeCrAl", 782.0000, 779.2175, 2.7825, 2.7825],
    ["FeCrAl", 796.0000, 801.1731, -5.1731, 5.1731],
    ["FeCrAl", 826.0000, 801.1731, 24.8269, 24.8269],
    ["FeCrAl", 821.0000, 782.1917, 38.8083, 38.8083],
    ["FeCrAl", 761.0000, 782.1917, -21.1917, 21.1917],
    ["FeCrAl", 822.0000, 823.9713, -1.9713, 1.9713],
    ["FeCrAl", 821.0000, 823.9713, -2.9713, 2.9713],
]

# Create DataFrame
df_fecral_uts = pd.DataFrame(fecral_uts_data, columns=[
    "Material", "Ultimate Tensile Strength (MPa)",
    "Predicted UTS (MPa)", "Error (MPa)", "Absolute Error (MPa)"
])

# Display the DataFrame
print(df_fecral_uts)

# Create square-shaped scatter plot
plt.figure(figsize=(10, 10))  # Square figure

# Scatter plot
plt.scatter(df_fecral_uts['Ultimate Tensile Strength (MPa)'], 
           df_fecral_uts['Predicted UTS (MPa)'], 
           alpha=0.7, s=60, color='blue', label='FeCrAl')

# Perfect prediction line (y = x)
min_val = 750
max_val = 850  # Adjusted to accommodate the data range
plt.plot([min_val, max_val], [min_val, max_val], 'k--', linewidth=2, label='y = x (Perfect Prediction)')

# Customize plot with equal scaling
plt.xlabel('Actual Ultimate Tensile Strength (MPa)', fontsize=12)
plt.ylabel('Predicted UTS (MPa)', fontsize=12)
plt.title('FeCrAl: Predicted vs Actual Ultimate Tensile Strength', fontsize=14)
plt.grid(True, alpha=0.3)

# Place legend inside the chart (upper right corner)
plt.legend(loc='upper right', framealpha=0.9)

# Set equal aspect ratio and same limits for true square shape
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.gca().set_aspect('equal', adjustable='box')

# Show plot
plt.tight_layout()
plt.show()

# Print statistics
print(f"\nStatistics:")
print(f"Number of samples: {len(df_fecral_uts)}")
print(f"Average Actual UTS: {df_fecral_uts['Ultimate Tensile Strength (MPa)'].mean():.2f} MPa")
print(f"Average Predicted UTS: {df_fecral_uts['Predicted UTS (MPa)'].mean():.2f} MPa")
print(f"Average Absolute Error: {df_fecral_uts['Absolute Error (MPa)'].mean():.2f} MPa")
print(f"Maximum Absolute Error: {df_fecral_uts['Absolute Error (MPa)'].max():.2f} MPa")
print(f"Minimum Absolute Error: {df_fecral_uts['Absolute Error (MPa)'].min():.2f} MPa")
print(f"Average Percentage Error: {(df_fecral_uts['Absolute Error (MPa)'].mean() / df_fecral_uts['Ultimate Tensile Strength (MPa)'].mean()) * 100:.2f}%")
# Out:
#   Material  Ultimate Tensile Strength (MPa)  Predicted UTS (MPa)  Error (MPa)  \
# 0   FeCrAl                            767.0             775.6503      -8.6503
# 1   FeCrAl                            760.0             779.2175     -19.2175
# 2   FeCrAl                            782.0             779.2175       2.7825
# 3   FeCrAl                            796.0             801.1731      -5.1731
# 4   FeCrAl                            826.0             801.1731      24.8269
# 5   FeCrAl                            821.0             782.1917      38.8083
# 6   FeCrAl                            761.0             782.1917     -21.1917
# 7   FeCrAl                            822.0             823.9713      -1.9713
# 8   FeCrAl                            821.0             823.9713      -2.9713
#
#    Absolute Error (MPa)
# 0                8.6503
# 1               19.2175
# 2                2.7825
# 3                5.1731
# 4               24.8269
# 5               38.8083
# ...
